# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import time
import requests
from bs4 import BeautifulSoup
import requests
from tqdm import tqdm
import pickle
pd.options.display.max_rows = 999

# %% [markdown]
# ## Yelp API Key

# %%
client_id = "oXRz7HWebFp6YdQ0YT3PMQ"
api_key = "Mm2MVQluEx7HWKjAMxJQT_KOSB_nKvEeQmjn19VS9PnsOBDoqtegFU1RoBXG0Lum415Eus2bKYuo-eb6mgMm1xV5nhwh3H5uhg-HJN39VFSMjIkwyRCbpLVv7ws7XXYx"

# %% [markdown]
# ## Helper Functions

# %%
#api calls
def yelp_call(url_params, api_key):

    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {'Authorization': 'Bearer {}'.format(api_key)}
    response = requests.get(url, headers=headers, params=url_params)
    data = response.json()['businesses']
    return data

# %%
#API call for 1000 restaurants
def all_results(url_params, api_key):
    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {'Authorization': 'Bearer {}'.format(api_key)}
    response = requests.get(url, headers=headers, params=url_params)
    num = response.json()['total']
    print('{} total matches found.'.format(num))
    cur = 0
    results = []
    while cur < num and cur < 1000:
        url_params['offset'] = cur
        results.append(yelp_call(url_params, api_key))
#         time.sleep(1) #Wait a second
        cur += 50
    return results

# %%
#Params
term = 'Restaurants'
location = 'New York'
url_params = {  'term': term.replace(' ', '+'),
                'location': location.replace(' ', '+'),
                'limit' : 50
             }

# %% [markdown]
# ## API Call for 1k Restaurants

# %%
#Getting info using function created previously
all_restaurants = all_results(url_params, api_key)
print(len(all_restaurants))
# Out:
# 19000 total matches found.
# 20

# %%
all_restaurants
# Out:
# [[{'id': 'nU4XBdvxDABXqZ6CnB8Dig',
#    'alias': 'clinton-street-baking-company-new-york-5',
#    'name': 'Clinton Street Baking Company',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DWHdizJ9bKbXN4yq6nbwAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/clinton-street-baking-company-new-york-5?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 4885,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.721128, 'longitude': -73.983933},
#    'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '4 Clinton St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4 Clinton St', 'New York, NY 10002']},
#    'phone': '+16466026263',
#    'display_phone': '(646) 602-6263',
#    'distance': 1950.282829638887},
#   {'id': 'ETgJqJHV7BW6pIr9Ox74sA',
#    'alias': 'amélie-new-york',
#    'name': 'Amélie',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cSDgVuPMnJgMLTrTNSEXug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/am%C3%A9lie-new-york?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 2596,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7327, 'longitude': -73.99766},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '22 W 8th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['22 W 8th St', 'New York, NY 10011']},
#    'phone': '+12125332962',
#    'display_phone': '(212) 533-2962',
#    'distance': 3038.8699032940094},
#   {'id': 'ehUuSk5gPTCQmwS_ubgKRA',
#    'alias': 'upstate-new-york-2',
#    'name': 'Upstate',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RvnUVU7MF7DT0RzNL-EebQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/upstate-new-york-2?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 1797,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7263139141197,
#     'longitude': -73.9864901976935},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '95 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['95 1st Ave', 'New York, NY 10003']},
#    'phone': '+16467915400',
#    'display_phone': '(646) 791-5400',
#    'distance': 2411.9187177986864},
#   {'id': 'C2o3Iw-DXjoUJFgQIbiqkQ',
#    'alias': 'bocaphê-new-york-3',
#    'name': 'BoCaphe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ck7z-CGvku5kJDPyRkIfew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bocaph%C3%AA-new-york-3?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 1340,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.722046, 'longitude': -73.997557},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '222 Lafayette St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['222 Lafayette St', 'New York, NY 10012']},
#    'phone': '+16468821939',
#    'display_phone': '(646) 882-1939',
#    'distance': 1866.3436634084576},
#   {'id': 's3jou_L_LVYGkNHiuhjlew',
#    'alias': 'boucherie-west-village-new-york-3',
#    'name': 'Boucherie West Village',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-5TXMVrjARsqKQHDg-hKbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boucherie-west-village-new-york-3?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 1313,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.733063, 'longitude': -74.0028772},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '99 7th Ave S',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['99 7th Ave S', 'New York, NY 10014']},
#    'phone': '+12128371616',
#    'display_phone': '(212) 837-1616',
#    'distance': 3155.0505772747442},
#   {'id': 'uoT2_Wrt1noD6kZOID7tUg',
#    'alias': 'jane-new-york-2',
#    'name': 'Jane',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Q5yrDsPb-Tb7eFQ5s_UB3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jane-new-york-2?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 3105,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72732, 'longitude': -74.00026},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '100 W Houston St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['100 W Houston St', 'New York, NY 10012']},
#    'phone': '+12122547000',
#    'display_phone': '(212) 254-7000',
#    'distance': 2489.0891583664493},
#   {'id': 'Me4TxTbPPQZQopW1wOGx5g',
#    'alias': 'jacks-wife-freda-new-york',
#    'name': "Jack's Wife Freda",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TRJ5LNNH7UAybD4TlCCf2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jacks-wife-freda-new-york?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 1840,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72213, 'longitude': -73.99756},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '224 Lafayette St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['224 Lafayette St', 'New York, NY 10012']},
#    'phone': '+12125108550',
#    'display_phone': '(212) 510-8550',
#    'distance': 1874.7368920314377},
#   {'id': 'ULt3kmA0_hbZ3j6cMORCaA',
#    'alias': 'root-and-bone-new-york',
#    'name': 'Root & Bone',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2WM96Qsx-7o11LNp1Lin9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/root-and-bone-new-york?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 1557,
#    'categories': [{'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72272, 'longitude': -73.98334},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '200 E 3rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['200 E 3rd St', 'New York, NY 10009']},
#    'phone': '+16466827080',
#    'display_phone': '(646) 682-7080',
#    'distance': 2129.537859707603},
#   {'id': 'I6KHYESZdZQz0fnMaMyIpQ',
#    'alias': 'zusik-new-york-2',
#    'name': 'Zusik',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aQ3pIzhIOox2er5fnB0Jhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zusik-new-york-2?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 94,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.73864, 'longitude': -74.00029},
#    'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '202 W14th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['202 W14th St', 'New York, NY 10011']},
#    'phone': '+16463705331',
#    'display_phone': '(646) 370-5331',
#    'distance': 3719.957729671145},
#   {'id': '4aF0F8w7yXX9o5_QFky_ig',
#    'alias': 'celestine-brooklyn',
#    'name': 'Celestine',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/J5HuHor_cmVEG6HhQtFeDw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/celestine-brooklyn?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 201,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.704676, 'longitude': -73.987975},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '1 John St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 John St', 'Brooklyn, NY 11201']},
#    'phone': '+17185225356',
#    'display_phone': '(718) 522-5356',
#    'distance': 539.4069533813018},
#   {'id': 'jjJc_CrkB2HodEinB6cWww',
#    'alias': 'lovemama-new-york',
#    'name': 'LoveMama',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bLlFKTlVuLfmF-lIDGIjZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lovemama-new-york?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 4662,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'malaysian', 'title': 'Malaysian'},
#     {'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7303859, 'longitude': -73.9860613},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '174 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['174 2nd Ave', 'New York, NY 10003']},
#    'phone': '+12122545370',
#    'display_phone': '(212) 254-5370',
#    'distance': 2858.7729410008346},
#   {'id': 'ysqgdbSrezXgVwER2kQWKA',
#    'alias': 'julianas-pizza-brooklyn-5',
#    'name': "Juliana's Pizza",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7JtwTxhWHf3YS70Ss_CfxA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/julianas-pizza-brooklyn-5?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 2103,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7026153030093,
#     'longitude': -73.9934159993549},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '19 Old Fulton St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['19 Old Fulton St', 'Brooklyn, NY 11201']},
#    'phone': '+17185966700',
#    'display_phone': '(718) 596-6700',
#    'distance': 323.20506308227306},
#   {'id': 'hmdm-dO72hLsMQwQRcGEUQ',
#    'alias': 'atrium-dumbo-brooklyn',
#    'name': 'Atrium Dumbo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TAog5s7slOJ0778OGRzuWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/atrium-dumbo-brooklyn?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 655,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7033899, 'longitude': -73.9904923},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '15 Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15 Main St', 'Brooklyn, NY 11201']},
#    'phone': '+17188581095',
#    'display_phone': '(718) 858-1095',
#    'distance': 392.6441573431464},
#   {'id': '8F81LrdFm6P5kkFpsw0n0w',
#    'alias': 'sweet-chick-new-york',
#    'name': 'Sweet Chick',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2OGtgpC5YYEZ2yOF93o45g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sweet-chick-new-york?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 1565,
#    'categories': [{'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7217399, 'longitude': -73.98739},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '178 Ludlow St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['178 Ludlow St', 'New York, NY 10002']},
#    'phone': '+16466570233',
#    'display_phone': '(646) 657-0233',
#    'distance': 1901.1018520082853},
#   {'id': 'I2lgw_7DUnwD92ND4PN-Ow',
#    'alias': 'aunt-jakes-new-york',
#    'name': "Aunt Jake's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hMhn_lnES3QWc4Gtihvr0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aunt-jakes-new-york?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 1379,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7190315, 'longitude': -73.9977161},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '149 Mulberry St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['149 Mulberry St', 'New York, NY 10013']},
#    'phone': '+16468580470',
#    'display_phone': '(646) 858-0470',
#    'distance': 1538.0627375870665},
#   {'id': 'q11TljTQd33XCWlVoPyRqg',
#    'alias': 'the-osprey-brooklyn',
#    'name': 'The Osprey',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kwlyMi4cASfqcvEl0Mmb_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-osprey-brooklyn?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 175,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.702241, 'longitude': -73.995539},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '60 Furman St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['60 Furman St', 'Brooklyn, NY 11201']},
#    'phone': '+13476962505',
#    'display_phone': '(347) 696-2505',
#    'distance': 367.7475436977597},
#   {'id': 'VvsZAnEwU4c8Xkyrzx05Nw',
#    'alias': 'anytime-new-york',
#    'name': 'Anytime',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/C1d57jfcpqLTXF9w7qm9YQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/anytime-new-york?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 973,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74779, 'longitude': -73.98674},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '23 W 32nd St',
#     'address2': 'Fl 3',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['23 W 32nd St', 'Fl 3', 'New York, NY 10001']},
#    'phone': '+16466697733',
#    'display_phone': '(646) 669-7733',
#    'distance': 4761.966725883583},
#   {'id': 'CwOAKJdX8AMz5iAoA-ZEuA',
#    'alias': 'uglyduckling-brooklyn',
#    'name': 'Uglyduckling',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sCDU8uosDuxp26wjxq4p4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/uglyduckling-brooklyn?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 463,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.686023, 'longitude': -73.991302},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '166 Smith St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['166 Smith St', 'Brooklyn, NY 11201']},
#    'phone': '+17184513825',
#    'display_phone': '(718) 451-3825',
#    'distance': 2174.2838817065267},
#   {'id': 'TGP5gbAgml0IDRLGCpFnCw',
#    'alias': 'pmf-pardon-my-french-new-york',
#    'name': 'PMF Pardon My French',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/X8eWP2AqEiktrGTr3th8JA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pmf-pardon-my-french-new-york?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 940,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72473, 'longitude': -73.98115},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '103 Ave B',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['103 Ave B', 'New York, NY 10009']},
#    'phone': '+12123589683',
#    'display_phone': '(212) 358-9683',
#    'distance': 2414.8553623569283},
#   {'id': 'nHMDOIX32dGbfpuNUwsLNQ',
#    'alias': 'almar-brooklyn-2',
#    'name': 'AlMar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_EoXWmBYT1-X--xHq0oUTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/almar-brooklyn-2?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 420,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.702662, 'longitude': -73.989177},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '111 Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['111 Front St', 'Brooklyn, NY 11201']},
#    'phone': '+17188555288',
#    'display_phone': '(718) 855-5288',
#    'distance': 530.8013177444826},
#   {'id': 'MHtbBc2np3sR7jiV9GphNg',
#    'alias': 'tribecas-kitchen-new-york',
#    'name': "Tribeca's Kitchen",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XJXRVbw9u67kfHsIlzVVfA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tribecas-kitchen-new-york?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 466,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'diners', 'title': 'Diners'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7162705535921,
#     'longitude': -74.0072225927912},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '200 Church St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['200 Church St', 'New York, NY 10013']},
#    'phone': '+12122275100',
#    'display_phone': '(212) 227-5100',
#    'distance': 1623.7772210156222},
#   {'id': '4XX-zF8h5Lvrr22_tqU6-Q',
#    'alias': 'the-river-café-brooklyn-3',
#    'name': 'The River Café',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Rxg5eDnRtIm73UEuNa3NHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-river-caf%C3%A9-brooklyn-3?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 1098,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70318, 'longitude': -73.9946499},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '1 Water St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 Water St', 'Brooklyn, NY 11201']},
#    'phone': '+17185225200',
#    'display_phone': '(718) 522-5200',
#    'distance': 254.64706598521875},
#   {'id': '0CjK3esfpFcxIopebzjFxA',
#    'alias': 'joes-shanghai-new-york-2',
#    'name': "Joe's Shanghai",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ekUo5egd4dlE7zJyb4-Leg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joes-shanghai-new-york-2?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 5978,
#    'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7146691442891,
#     'longitude': -73.9977602206654},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '9 Pell St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9 Pell St', 'New York, NY 10013']},
#    'phone': '+12122338888',
#    'display_phone': '(212) 233-8888',
#    'distance': 1066.5085498349097},
#   {'id': '16ZnHpuaaBt92XWeJHCC5A',
#    'alias': 'olio-e-più-new-york-4',
#    'name': 'Olio e Più',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/l4peUZMi7CLFcG3w3jnYvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/olio-e-pi%C3%B9-new-york-4?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 2024,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.733826, 'longitude': -73.999852},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '3 Greenwich Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3 Greenwich Ave', 'New York, NY 10014']},
#    'phone': '+12122436546',
#    'display_phone': '(212) 243-6546',
#    'distance': 3190.416616025005},
#   {'id': 'w4cFJhUpjGXqqWBd3BbY4w',
#    'alias': 'freemans-new-york-3',
#    'name': 'Freemans',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EPGiKPXVX6C4q3ID8XL5Hg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/freemans-new-york-3?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 2023,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.721988, 'longitude': -73.992466},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Freeman Alley',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Freeman Alley', 'New York, NY 10002']},
#    'phone': '+12124200012',
#    'display_phone': '(212) 420-0012',
#    'distance': 1845.9460130020204},
#   {'id': 'C-8mGN7lt5rIraO5n-15ug',
#    'alias': 'the-smith-new-york-2',
#    'name': 'The Smith',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fGAZCdyPI8qil5boCzidBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-smith-new-york-2?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 2523,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.755165, 'longitude': -73.967868},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '956 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['956 2nd Ave', 'New York, NY 10022']},
#    'phone': '+12126442700',
#    'display_phone': '(212) 644-2700',
#    'distance': 5960.16818302934},
#   {'id': '6Ct7OeTRn4caY9g0swFBsw',
#    'alias': 'la-contenta-new-york',
#    'name': 'La Contenta',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FwZAyPgdKdPGQ8aAGKh3-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-contenta-new-york?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 715,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71873, 'longitude': -73.98691},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '102 Norfolk St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['102 Norfolk St', 'New York, NY 10002']},
#    'phone': '+12124324180',
#    'display_phone': '(212) 432-4180',
#    'distance': 1602.3725010220583},
#   {'id': 'jAaVnUKLITkuhzwXIe0vLQ',
#    'alias': 'cafe-mogador-brooklyn',
#    'name': 'Cafe Mogador',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zbE8vsLW5Flpt3GMW_4UOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-mogador-brooklyn?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 1141,
#    'categories': [{'alias': 'moroccan', 'title': 'Moroccan'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.719747, 'longitude': -73.959993},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '133 Wythe Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['133 Wythe Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17184869222',
#    'display_phone': '(718) 486-9222',
#    'distance': 3299.5306167935732},
#   {'id': 'XEugUtbw4rRmGr9S1XA-aQ',
#    'alias': 'alta-new-york',
#    'name': 'Alta',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/aUWGUNBLw-mbQZOzJ9-Pdw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alta-new-york?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 1857,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7345163811398,
#     'longitude': -73.9983369619683},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$$',
#    'location': {'address1': '64 W 10th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['64 W 10th St', 'New York, NY 10011']},
#    'phone': '+12125057777',
#    'display_phone': '(212) 505-7777',
#    'distance': 3250.5152771255803},
#   {'id': 'xt4sa64WOrpJvZBDPNPNYg',
#    'alias': 'jacobs-pickles-new-york',
#    'name': "Jacob's Pickles",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/167Rl2s1oMge_2ZSDD1z0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jacobs-pickles-new-york?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 3942,
#    'categories': [{'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7866504411994,
#     'longitude': -73.9755284786224},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '509 Amsterdam Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['509 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+12124705566',
#    'display_phone': '(212) 470-5566',
#    'distance': 9166.964737863183},
#   {'id': 'N5UY113nNpeKdLPv0cbMjQ',
#    'alias': 'the-wild-son-new-york',
#    'name': 'The Wild Son',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DYgwqPcb39ihBl9dw-rpqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-wild-son-new-york?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 450,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74073, 'longitude': -74.00836},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '53 Little W 12th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['53 Little W 12th St', 'New York, NY 10014']},
#    'phone': '+12127277900',
#    'display_phone': '(212) 727-7900',
#    'distance': 4101.615140742381},
#   {'id': 'rp8S7scxOkVVeG7dNneMGQ',
#    'alias': 'l-artusi-new-york',
#    'name': "L'Artusi",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HeDloBW-SnokWblGDuPrUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-artusi-new-york?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 1770,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.733714, 'longitude': -74.005068},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '228 W 10th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['228 W 10th St', 'New York, NY 10014']},
#    'phone': '+12122555757',
#    'display_phone': '(212) 255-5757',
#    'distance': 3271.9116518313776},
#   {'id': 'LpVbI-E9C-CSp7WhU5h2Iw',
#    'alias': 'fishmarket-restaurant-new-york',
#    'name': 'Fishmarket Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BxY50B6ntFYQa8COuI1Fog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fishmarket-restaurant-new-york?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 539,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70717, 'longitude': -74.00192},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '111 South St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['111 South St', 'New York, NY 10038']},
#    'phone': '+19173638101',
#    'display_phone': '(917) 363-8101',
#    'distance': 671.0784555500173},
#   {'id': 'dzlhiEg7nE49iReUC10w_A',
#    'alias': 'jack-the-horse-tavern-brooklyn',
#    'name': 'Jack the Horse Tavern',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cGMc4G5EoTZFjMzrvX_lFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jack-the-horse-tavern-brooklyn?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 387,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.699973, 'longitude': -73.993781},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$$',
#    'location': {'address1': '66 Hicks St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['66 Hicks St', 'Brooklyn, NY 11201']},
#    'phone': '+17188525084',
#    'display_phone': '(718) 852-5084',
#    'distance': 602.6367999119216},
#   {'id': 'MaZWYgvu08NLQVRcDGGvqQ',
#    'alias': 'zhen-wei-fang-new-york',
#    'name': 'Zhen Wei Fang',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/wYvZ6PaFNqtIgZoTDCSabg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zhen-wei-fang-new-york?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 162,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'hotpot', 'title': 'Hot Pot'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72128, 'longitude': -73.99343},
#    'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#    'location': {'address1': '207 Bowery',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['207 Bowery', 'New York, NY 10002']},
#    'phone': '+16467670355',
#    'display_phone': '(646) 767-0355',
#    'distance': 1760.566981584637},
#   {'id': 'hNFe8WhCibrqT4sFcZmAgw',
#    'alias': 'kong-sihk-tong-港食堂-new-york',
#    'name': 'Kong Sihk Tong 港食堂',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/G00GzDuAyjgtBHEcjR_lLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kong-sihk-tong-%E6%B8%AF%E9%A3%9F%E5%A0%82-new-york?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 185,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'hkcafe', 'title': 'Hong Kong Style Cafe'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71542, 'longitude': -73.99813},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '65 Bayard St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['65 Bayard St', 'New York, NY 10013']},
#    'phone': '+16468506140',
#    'display_phone': '(646) 850-6140',
#    'distance': 1153.870812287678},
#   {'id': 'qm1J_dPA5IHij1oAnoZwHw',
#    'alias': 'nonono-new-york-6',
#    'name': 'nonono',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/yhZYzx5cnn8SFFF8eZdRHw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nonono-new-york-6?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 564,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'izakaya', 'title': 'Izakaya'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74545, 'longitude': -73.98499},
#    'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '118 Madison Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['118 Madison Ave', 'New York, NY 10016']},
#    'phone': '+16467073227',
#    'display_phone': '(646) 707-3227',
#    'distance': 4515.897681612123},
#   {'id': 'cTE0e96GYzet799EJeStoQ',
#    'alias': 'chama-mama-new-york',
#    'name': 'Chama Mama',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qRZaBnsI-gfyaSTEIEGzgw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chama-mama-new-york?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 163,
#    'categories': [{'alias': 'georgian', 'title': 'Georgian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7384, 'longitude': -73.99892},
#    'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '149 W 14th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['149 W 14th St', 'New York, NY 10011']},
#    'phone': '+16464389007',
#    'display_phone': '(646) 438-9007',
#    'distance': 3690.5460277554907},
#   {'id': 'kxykwx5qTWBhlMh18MQ82Q',
#    'alias': 'lukes-lobster-fidi-new-york',
#    'name': "Luke's Lobster FiDi",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/C5NV5lfsLo2nJDkx3Or9ig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lukes-lobster-fidi-new-york?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 1125,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7046213003984,
#     'longitude': -74.0107793876969},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '26 S William St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['26 S William St', 'New York, NY 10004']},
#    'phone': '+12127471700',
#    'display_phone': '(212) 747-1700',
#    'distance': 1392.7033987694713},
#   {'id': 'wouDDTacUIBaRp8YGCFTsA',
#    'alias': 'colonie-brooklyn',
#    'name': 'Colonie',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/r6Qp3GXOCdjAmFWh_GQWWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/colonie-brooklyn?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 559,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6909, 'longitude': -73.9958},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '127 Atlantic Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['127 Atlantic Ave', 'Brooklyn, NY 11201']},
#    'phone': '+17188557500',
#    'display_phone': '(718) 855-7500',
#    'distance': 1625.24899251244},
#   {'id': 'XipQLDbyTl5tsLlyzAWzug',
#    'alias': 'jajaja-new-york',
#    'name': 'Jajaja',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6HT76TsvGr6XtRVzBi4S_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jajaja-new-york?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 833,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7141530317142,
#     'longitude': -73.9904247969389},
#    'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '162 E Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['162 E Broadway', 'New York, NY 10002']},
#    'phone': '+16468835453',
#    'display_phone': '(646) 883-5453',
#    'distance': 1021.7274074140097},
#   {'id': 'ihplCj2HKWR7z-bBKf8Nzw',
#    'alias': 'post-new-york-2',
#    'name': 'POST',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lXHQtNvqo91VXU5InkIvGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/post-new-york-2?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 239,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72298, 'longitude': -73.98302},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '42 Ave B',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['42 Ave B', 'New York, NY 10009']},
#    'phone': '+16469302724',
#    'display_phone': '(646) 930-2724',
#    'distance': 2168.2348699068466},
#   {'id': '8XHbZIKDQbXhyKIGiukVeQ',
#    'alias': 'boucherie-union-square-new-york',
#    'name': 'Boucherie Union Square',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/U90cr6FAs7CRF83TkbvrZg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boucherie-union-square-new-york?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 643,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73715, 'longitude': -73.98789},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$$',
#    'location': {'address1': '225 Park Ave S',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['225 Park Ave S', 'New York, NY 10003']},
#    'phone': '+12123530200',
#    'display_phone': '(212) 353-0200',
#    'distance': 3566.795292760236},
#   {'id': 'xZ96vaoL-cQjfotmUKtjJQ',
#    'alias': 'barn-joo-35-new-york',
#    'name': 'Barn Joo 35',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1R5CgYlK5qGUhKZOvZThKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barn-joo-35-new-york?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 1780,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74964, 'longitude': -73.98582},
#    'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '34 W 35th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['34 W 35th St', 'New York, NY 10001']},
#    'phone': '+12125644430',
#    'display_phone': '(212) 564-4430',
#    'distance': 4968.473297353009},
#   {'id': 'rQpO1Eie_zmeAOQ9s-T0sQ',
#    'alias': 'hole-in-the-wall-new-york-2',
#    'name': 'Hole in the Wall',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KQwNs2HFWF0GDEGoSYgAEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hole-in-the-wall-new-york-2?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 501,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70837, 'longitude': -74.00563},
# ...
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['24 Reed St', 'Brooklyn, NY 11231']},
#    'phone': '+17186432722',
#    'display_phone': '(718) 643-2722',
#    'distance': 3845.6254067839172},
#   {'id': 'RqCMsa0IuHWhML0BEjW8_w',
#    'alias': 'boulud-sud-new-york',
#    'name': 'Boulud Sud',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/js2rok5hQcGkSWGMthFE2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boulud-sud-new-york?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 720,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7718614234522,
#     'longitude': -73.9816256082283},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '20 West 64th Street',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['20 West 64th Street', 'New York, NY 10023']},
#    'phone': '+12125951313',
#    'display_phone': '(212) 595-1313',
#    'distance': 7461.895579421484},
#   {'id': 'WewpX-p5J3sOLFNF00R-FA',
#    'alias': 'boilery-east-village-new-york',
#    'name': 'Boilery - East Village',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/umW-83QcHIoiMOUyBeGRVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boilery-east-village-new-york?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 40,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'raw_food', 'title': 'Live/Raw Food'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73112, 'longitude': -73.98898},
#    'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '58 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['58 3rd Ave', 'New York, NY 10003']},
#    'phone': '+16468385556',
#    'display_phone': '(646) 838-5556',
#    'distance': 2892.789386648123},
#   {'id': 'FFwDFLVBTQvuacl4l1ODew',
#    'alias': 'gentleman-farmer-new-york',
#    'name': 'Gentleman Farmer',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/oh3xkMJyl8_yZlB7bnAx8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gentleman-farmer-new-york?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 276,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7210141970542,
#     'longitude': -73.9910638332367},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '40 Rivington St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['40 Rivington St', 'New York, NY 10002']},
#    'phone': '+12126772172',
#    'display_phone': '(212) 677-2172',
#    'distance': 1752.4947530670433},
#   {'id': 'gvMYV5E3HyzhN_MYFIMGzg',
#    'alias': 'el-born-brooklyn',
#    'name': 'El Born',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/I0RdvEhtgC1LV_duQv5Afg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-born-brooklyn?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 285,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7243479163883,
#     'longitude': -73.9512226101037},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '651 Manhattan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['651 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+13478449295',
#    'display_phone': '(347) 844-9295',
#    'distance': 4194.692764168617},
#   {'id': 'SxKvgnkMMZdhBJcxxKQnww',
#    'alias': 'nobu-fifty-seven-new-york-2',
#    'name': 'Nobu Fifty Seven',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/INqGC_ky4oZ_rPMcSjNlQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nobu-fifty-seven-new-york-2?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 1158,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7636210840864,
#     'longitude': -73.9765048613641},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '40 W 57th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['40 W 57th St', 'New York, NY 10019']},
#    'phone': '+12127573000',
#    'display_phone': '(212) 757-3000',
#    'distance': 6640.252584385714},
#   {'id': 'vZgJyMZlpSSS_Y-duxd4_A',
#    'alias': 'kings-co-imperial-brooklyn',
#    'name': 'Kings Co Imperial',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4lu6pK6YG0ws0BA-XEuFVA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kings-co-imperial-brooklyn?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 275,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71512, 'longitude': -73.95097},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '20 Skillman Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['20 Skillman Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17186102000',
#    'display_phone': '(718) 610-2000',
#    'distance': 3805.4616982466105},
#   {'id': '3zbz9kLrLKHCBeGrNhMMGA',
#    'alias': 'l-accolade-new-york',
#    'name': "L'Accolade",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9tAqyS1eXxm2d31PkpyiYg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-accolade-new-york?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 51,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.732484, 'longitude': -74.003915},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '302 Bleecker St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['302 Bleecker St', 'New York, NY 10014']},
#    'phone': '+19174091407',
#    'display_phone': '(917) 409-1407',
#    'distance': 3114.7853924865485},
#   {'id': 'klAhw3xLQi9GF1tf_HnS7w',
#    'alias': 'izakaya-mew-new-york-3',
#    'name': 'Izakaya MEW',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/M3ZH9NJ2HRtZiOBjkQ_XWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/izakaya-mew-new-york-3?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 2191,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'izakaya', 'title': 'Izakaya'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7501853096499,
#     'longitude': -73.9863203465939},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '53 W 35th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['53 W 35th St', 'New York, NY 10001']},
#    'phone': '+16463689384',
#    'display_phone': '(646) 368-9384',
#    'distance': 5020.06416695017},
#   {'id': 'ZhbHXqkEYNKLAbamW5peJQ',
#    'alias': 'narcissa-new-york',
#    'name': 'Narcissa',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RhQo0vkKWHrMGX8skZtJJQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/narcissa-new-york?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 499,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7279081084989,
#     'longitude': -73.9909284946934},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '25 Cooper Sq',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25 Cooper Sq', 'New York, NY 10003']},
#    'phone': '+12122283344',
#    'display_phone': '(212) 228-3344',
#    'distance': 2513.8418088714016},
#   {'id': 'pcb8yK9_28uWz5CyokjwSg',
#    'alias': 'bangia-new-york-2',
#    'name': 'Bangia',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mXv72GFEMqAJPmvxHxcq-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bangia-new-york-2?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 346,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.746854, 'longitude': -73.9845201},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '11 E 32nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['11 E 32nd St', 'New York, NY 10016']},
#    'phone': '+12126796790',
#    'display_phone': '(212) 679-6790',
#    'distance': 4677.55132020009},
#   {'id': 'yFtOtTd7ncSjFF3QavQ5cA',
#    'alias': 'crispo-new-york',
#    'name': 'Crispo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4KMuxTXDVbx5H7c2pxWK1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crispo-new-york?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 942,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7392469, 'longitude': -74.0016882},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '240 W 14th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['240 W 14th St', 'New York, NY 10011']},
#    'phone': '+12122291818',
#    'display_phone': '(212) 229-1818',
#    'distance': 3809.9243323153732},
#   {'id': '8NVN6Nldm7AGoGaABBZMRw',
#    'alias': 'izakaya-nomad-new-york',
#    'name': 'Izakaya NoMad',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/s3qyS_ZDM3WXeqXjLNFPCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/izakaya-nomad-new-york?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 653,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'izakaya', 'title': 'Izakaya'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74409, 'longitude': -73.98945},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '13 W 26th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['13 W 26th St', 'New York, NY 10010']},
#    'phone': '+12122136258',
#    'display_phone': '(212) 213-6258',
#    'distance': 4324.0303176280795},
#   {'id': 'xI0H0K1MAq1U6NTp1xFreA',
#    'alias': 'midnights-brooklyn-2',
#    'name': 'Midnights',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6c4JO2oeBcIHZykj0LEuZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/midnights-brooklyn-2?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 211,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71748, 'longitude': -73.95843},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '149 N 6th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['149 N 6th St', 'Brooklyn, NY 11249']},
#    'phone': '+17183846961',
#    'display_phone': '(718) 384-6961',
#    'distance': 3307.2311132429813},
#   {'id': 'diCW3Pj1PTVRSyol_d7cZw',
#    'alias': 'chefs-table-at-brooklyn-fare-new-york',
#    'name': "Chef's Table at Brooklyn Fare",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GZyVG8iVawG7QrH5kIM2oQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chefs-table-at-brooklyn-fare-new-york?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 500,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7561930774282,
#     'longitude': -73.9966090932068},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '431 W 37th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['431 W 37th St', 'New York, NY 10018']},
#    'phone': '+17182430050',
#    'display_phone': '(718) 243-0050',
#    'distance': 5646.310638981933},
#   {'id': 'yGQT6OZ-nNIhTKj32wRlmA',
#    'alias': 'bar-bolinas-clinton-hill',
#    'name': 'Bar Bolinas',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1q0ybwr2AmnYiznbEnYDWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-bolinas-clinton-hill?adjust_creative=oXRz7HWebFp6YdQ0YT3PMQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oXRz7HWebFp6YdQ0YT3PMQ',
#    'review_count': 119,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.693499, 'longitude': -73.967389},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '455 Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Clinton Hill',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['455 Myrtle Ave', 'Clinton Hill, NY 11205']},
#    'phone': '+17189359331',
#    'display_phone': '(718) 935-9331',
#    'distance': 2630.3859320936035}]]

# %% [markdown]
# ## Parse API for Relevant Info

# %%
#function to parse the data and keep only the parts of each entry that we need
def parse_api(data):
    parsed_data = []
    final_parsed_restaurants = []
    for i in range(len(data)):
        for j in range(50):
            parsed_data.append(data[i][j])
    
    #create a list with SQL tables columnns names
    for parsed_restaurant in parsed_data:
        if 'price' in parsed_restaurant.keys():
            final_parsed_restaurants.append({'restaurant_id': parsed_restaurant['id'],'restaurant_name': parsed_restaurant['name'],
                         'price': parsed_restaurant['price'],'rating': parsed_restaurant['rating'],
                         'review_count': parsed_restaurant['review_count']})
        else:
            final_parsed_restaurants.append({'restaurant_id': parsed_restaurant['id'],'restaurant_name': parsed_restaurant['name'],
                         'price': "",'rating': parsed_restaurant['rating'],
                         'review_count': parsed_restaurant['review_count']})
    return final_parsed_restaurants

# %%
#call the function and return a list with only the columns names we need
parsed_restaurants_v1 = parse_api(all_restaurants)

# %%
len(parsed_restaurants_v1)

# %%
parsed_restaurants_v1

# %%
df = pd.DataFrame.from_dict(parsed_restaurants_v1)

# %%
df.head()

# %%
#exporting data to excel for partner to use
# df.to_excel("Restaurant_1.xlsx")

# %%
df.hist()
plt.show()

# %%
restaurant_id_list = list(df.restaurant_id)

# %%
restaurant_id_list

# %% [markdown]
# ## Test Scrape for 1 Restaurant

# %%
# creating the link to access the reviews
url_prefix = 'https://www.yelp.com/biz/'
url_suffix = '?rh_type=phrase'
test_id = 'ETgJqJHV7BW6pIr9Ox74sA'
full_url = url_prefix+test_id+url_suffix

# %%
full_url

# %%
source = requests.get(full_url).text

# %%
source

# %%
soup = BeautifulSoup(source,'lxml')

# %%
print(soup.prettify())

# %%
reviews_section = soup.find(class_='lemon--span__373c0__3997G',lang='en')

# %%
reviews_section

# %%
reviews_section.text

# %%
all_reviews_section = soup.find_all(class_='lemon--span__373c0__3997G',lang='en')
all_reviews_section

# %% [markdown]
# ## Scrape 100 Reviews

# %%
reviews=[]
for i in range(len(all_reviews_section)):
    reviews.append({i:all_reviews_section[i].text})

# %%
reviews

# %%
def scrape_list(list_id):
    reviews=[]
    for resto_id in tqdm(list_id):
        url_prefix = 'https://www.yelp.com/biz/'
        url_suffix = ['?rh_type=phrase','?start=20', '?start=40', '?start=60', '?start=80', '?start=100']
        for suf in url_suffix:
            test_id = resto_id
            full_url = url_prefix+test_id+suf
        
            source = requests.get(full_url).text
            soup = BeautifulSoup(source,'html')
            all_reviews_section = soup.find_all(class_='lemon--span__373c0__3997G',lang='en')
            time.sleep(1)
            for i in range(len(all_reviews_section)):
                reviews.append((test_id,all_reviews_section[i].text))
            with open('reviews_loop.pkl', 'wb') as f:
                pickle.dump(reviews, f)
    return reviews

# %%
full_reviews = scrape_list(restaurant_id_list)

# %%
len(full_reviews)

# %%
full_reviews

# %%
import pickle
 
with open('reviews_v2.pkl', 'wb') as f:
    pickle.dump(full_reviews, f)

# %%
len(tuple_reviews)

# %%
data = pd.DataFrame(full_reviews,columns=['Restaurant_Id','Review'])

# %%
data.to_csv('reviews.csv')
