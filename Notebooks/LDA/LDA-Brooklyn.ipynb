# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import nltk
from nltk import punkt
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from math import log, sqrt
import pandas as pd
import numpy as np
import re
# %matplotlib inline
from nltk.tokenize import word_tokenize
from nltk import sent_tokenize
from nltk.corpus import stopwords
stop = set(stopwords.words('english'))
from nltk.stem import WordNetLemmatizer 
from tqdm import tqdm
pd.options.display.max_columns = 999
from tqdm import tqdm
tqdm.pandas()
from tqdm import tqdm_notebook
from sklearn.decomposition import LatentDirichletAllocation

# %%
lemmatizer = WordNetLemmatizer()

# %%
morestops = ['light', 'main', 'appetizer', 'city', 'left', 'felt', 'pot', 'chinese', 'hot', 'name', 'sure', 'walked',
            'sit', 'door', 'yelp', 'group', 'options', 'portions', 'find', 'absolutely', 'neighborhood','ice',
            'desserts', 'enjoyed', 'courses', 'busy', 'large', 'friday', '4', 'able', 'packed', 'reservations',
            'saturday', 'reservation', 'full', 'average', 'feel', 'looking', 'gave', 'brought', 'must', 'york',
            'michelin', 'not', 'can', 'tell', 'home', 'awesome', 'different', 'bbq', 'lot', 'size', 'amount', 'plate',
            'long', 'theres', 'open', 'line', 'big', 'crowded', 'seated', 'lovely', 'cozy', 'waiting', 'sat', 'seats',
            'inside', 'cool', 'wall', 'walk', 'front', 'free', 'old', 'sometimes', 'usually', 'yes', 'theyre', 'youll',
            'often', 'isnt', 'things', 'gem', 'bill', 'cash', 'bland', 'room', 'end', 'view', 'evening','waited', 
            '20', '5', 'friendly', 'loud', 'fun', 'mexican', 'coming', 'enjoy', 'greek', 'outdoor', 'warm', 'not',
            'can', 'oh', 'wrong', 'na', 'street', 'cocktail', 'beers', 'glass', 'brooklyn', 'manhattan', 'may', 'bottle',
            'started', 'tender', 'slow', 'sauce', 'sweet', 'seating', 'lunch', 'menu', 'stars', 'quality', 'nothing', 
            'worth', 'reservation', 'recommend', 'spot', 'happy', 'everything', 'cooked', 'bread', 'outside', 'tables', 
            'location', 'mac', 'course', 'made', 'never', 'another', 'know', 'take', 'korean', 'french', 'italian', 
            'sauce', 'area', 'even', 'said', 'took', 'people', 'could', 'wait', 'first', 'always', 'go', 'love', 'new', 'im', 
            'come', 'favorite', 'times', 'excellent', 'night','hour', 'pretty', 'bit', 'small', 'little', 
            'though', 'much', 'think', 'better', 'quite', 'spicy','side', 'time', 'definitely', 'would', 'delicious', 
            'dont', 'dish', 'ordered', 'table', 'place', 'nice', 'bar', 'also', 'came', 'great', 'good', 'amazing', 
            'restaurant', 'really', 'well', 'bad', 'minutes', 'nice', 'back', 'best', 'ive', 'like','dont','get', 'us', 
            'came', 'order','minutes','one', 'asked', 'got', 'didnt', 'perfectly', 'meal', 'dishes', 'cream', 'want',
            'make', 'youre', 'eat', 'way', 'thats', 'say', 'need', 'see', 'something', 'dinner', 'every', 'highly', 
            'wonderful', 'nyc', 'perfect', 'told', 'drinks', 'wanted', 'went', 'wasnt', 'taste', 'overall', '2', '3', 
            'around', 'japanese', 'flavor', 'rib', 'can', 'not', 'oh', 'lol', 'point', 'wife', 'brooklyn',' vietnamese', 
            'bite', 'n', 'enough', 'although', 'expect', 'per', 'person', 'tender', 'flavorful', 'green', 'tasted',
            'texture', 'give', 'going', 'still', 'ever', 'reviews', 'review', 'cant', 'many', 'restaurants', 'wine',
            'dining', 'top', 'beautiful', 'special', 'tasting', 'birthday', 'incredible', 'fried', 'sunday', 'water', 
            'friend', 'drink', 'friends', 'super', 'music', 'cocktails', 'vibe', 'space', 'coffee', 'medium', 'meat',
            'rare', 'grill', 'cut', 'bone', 'roasted', 'fresh', 'brunch', 'breakfast', 'dessert', 'toast', 'two', 'dessert',
            'seafood', 'perfectly', 'meal', 'dishes', 'cream', 'want', 'make', 'youre', 'eat', 'way', 'thats', 'say', 'need', 
            'see', 'something', 'dinner', 'every', 'highly', 'wonderful', 'nyc', 'perfect', 'told', 'drinks', 'wanted', 
            'went', 'wasnt', 'taste', 'overall', '2', '3', 'around', 'japanese', 'flavor', 'rib', 'can', 'not', 'oh', 'lol',
            'point', 'wife', 'brooklyn', 'vietnamese', 'bite', 'n', 'enough', 'although', 'expect', 'per', 'person', 'tender',
            'flavorful', 'green', 'tasted', 'texture', 'tea', 'thai', 'ask', 'arrived', 'party', 'cake', 'date', 'selection',
            'cute', 'try', 'bowl', 'probably', 'high', 'however', 'id', 'decent', 'maybe', 'places', 'village', 'east', 'tapas', 
            'west', 'sangria', 'de', 'margaritas', 'dan', 'visit', 'last', 'family', 'years', 'everyone', 'thank', 'hearing',
            'tons','rave','finally','decided','actually','second','puts','bring','youd','impress','list', 'personally', 
            'neighborhood', 'loved', 'fantastic', 'absolutely', 'grilled', 'tasty', 'crispy', 'portion', 'served', 'day', 
            'right', 'party', 'next', 'since', 'away', 'arrived', 'ok', 'however', 'maybe', 'tip', 'star', 'okay', 'short', 
            'flavors', 'vegan', 'la', 'unique', 'ingredients', 'interesting', 'cuisine', 'time', 'definitely', 'would', 
            'delicious', 'dont', 'dish', 'ordered', 'table', 'place', 'nice', 'bar', 'also', 'came', 'great', 'good', 
            'amazing', 'restaurant', 'really', 'well', 'bad', 'minutes', 'nice', 'back', 'best', 'ive', 'like','dont',
            'get', 'us', 'came', 'order','minutes','one', 'asked', 'got', 'didnt','thing', 'might', 'makes', 'eating', 
            'real', 'let', 'tried', 'far', 'reasonable', 'husband', 'truly', 'pm', 'am', 'else', 'seemed', 'someone', 
            'good', 'like', 'really', 'place', 'would', 'pretty', 'bit', 'much', 'better', 'great', 'amazing', 'place', 
            'delicous', 'back', 'good', 'definitely', 'best', 'love', 'recommend', 'good', 'great', 'place', 'nice', 
            'really', 'bar', 'back', 'definitely', 'came', 'pretty', 'dish', 'ordered', 'dessert', 'happy', 'hour', 
            'drinks', 'beer', 'bar', 'new', 'always', 'one', 'go', 'location', 'get', 'place', 'york', 'us', 'time',
            'table', 'one', 'order', 'get', 'came', 'would', 'back', 'even', 'course', 'wine', 'dining', 'meal', 'course',
            'dishes', 'impeccable', 'juicy', 'later', 'margarita', 'fine', 'hard', 'less', 'especially', 'items', 'given',
            'vietnamese', 'late', 'not', 'can', 'here', 'there', 'yummy', 'can', 'din', 'seat', 'look', 'crowd', 'work', 
            'amaze', 'pay', 'seem', 'share', 'start', 'wan', 'hangout', 'chez', 'anthony', 'mouse', 'moi', 'adresse', 
            'louisiana', 'fab', 'gopchang', 'flavours', 'flavors', 'plaza', 'mondays', 'tuesdays', 'wednesdays', 
            'thursdays', 'fridays', 'saturdays', 'sundays', 'rules', 'jun', 'bellinis', 'court', 'chrysanthemum', 
            'lincoln', 'healthier', 'chang', 'loco', 'viet']

# %%
stops = ['thing', 'might', 'makes', 'eating', 'real', 'let', 'tried', 'far', 'reasonable', 'husband', 'truly',
        'pm', 'am', 'else', 'seemed', 'someone', 'good', 'like', 'really', 'place', 'would', 'pretty', 'bit', 'much',
        'better', 'great', 'amazing', 'place', 'delicous', 'back', 'good', 'definitely', 'best', 'love', 'recommend',
        'good', 'great', 'place', 'nice', 'really', 'bar', 'back', 'definitely', 'came', 'pretty', 'dish', 'ordered',
        'dessert', 'happy', 'hour', 'drinks', 'beer', 'bar', 'new', 'always', 'one', 'go', 'location', 'get', 'place',
        'york', 'us', 'time', 'table', 'one', 'order', 'get', 'came', 'would', 'back', 'even', 'course', 'waaaine',
        'dining', 'meal', 'course', 'dishes', 'impeccable', 'juicy', 'later', 'margarita', 'fine', 'hard', 'less',
        'especially', 'items', 'given', 'vietnamese', 'late', 'not', 'can', 'astoria', 'steakhouse', 'terrible', 'empty',
        'like', 'boat', 'leave', 'call', 'offer', 'consider', 'disappoint', 'without', 'stop', 'delivery', 'patio', 'smoke',
        'dress', 'keep', 'market', 'park', 'floor', 'hotel', 'th', 'upstairs', 'locate', 'near', 'pair', 'piece', 'solid', 
        'set', 'fill', 'interior', 'put', 'chinatown', 'piece', 'shop', 'solid', 'season', 'boy', 'welcome', 'return',
        'price', 'expensive', 'chea', 'overprice', 'cost', 'money', 'spend', 'receive', 'include', 'quick', 'fast', 'black',
        'salt', 'add', 'charge', 'sum', 'bottomless', 'poach', 'kitchen', 'plat', 'mean', 'anything', 'three', 'tiny', 'level',
        'dry', 'half', 'use', 'anything', 'mean', 'honestly', 'almost', 'summer', 'close', 'rich', 'salty', 'red', 'couple', 
        'plat', 'show', 'occasion', 'least', 'lack', 'reason', 'either', 'miss', 'hours', 'rat', 'guess', 'instead',
        'understand', 'mind', 'outstanding', 'platter', 'rude', 'greet', 'guy', 'girl', 'woman', 'man', 'cold',
        'soft', 'white', 'fixe', 'pre', 'prix', 'refresh', 'le', 'range', 'terrific', 'craft', 'hill', 'non', 'pot',
        'win', 'live', 'weekend', 'surprise', 'shack', 'po', 'raw', 'dozen', 'extra', 'finish', 'care', 'extremely', 
        'spring', 'bag', 'cheap', 'card', 'plan', 'kid', 'credit', 'card', 'gluten', 'today', 'counter', 'chelsea', 
        'daughter', 'nephew', 'niece', 'son', 'father', 'mother', 'aunt', 'uncle', 'father', 'mother', 'ago', 'morning', 
        'sister', 'brother', 'kind', 'yet', 'prepare', 'present', 'creative', 'beautifully', 'presentation', 'appetizers',
        'house', 'upon', 'stumble', 'ny', 'square', 'station', 'deal', 'option', 'number', 'note', 'minute', 'early', 
        'private', 'run', 'hand', 'establishment', 'type', 'cook', 'box', 'fact', 'rather', 'remember', 'dollars', 'forget'
        'refill', 'ready', 'mins', 'blue', 'farm', 'freeze', 'strong', 'lady', 'man', 'tap', 'hell', 'eye', 'b', 'watch', 
        'game', 'meet', 'hh', 'town', 'grab', 'c', 'exceptional', 'celebrate', 'treat', 'beyond', 'year', 'please', 
        'anniversary', 'birthday', 'week', 'certainly', 'expectations', 'note', 'book', 'four', 'choose', 'balance', 
        'simply', 'perhaps', 'rather', 'together', 'mediocre', 'unfortunately', 'rather', 'meh', 'mehhhhh', 'buy', 'con',
        'expectations', 'store', 'hype', 'suppose', 'despite', 'unless', 'forget', 'event', 'baby', 'partner', 'scene',
        'photo', 'days', 'locations', 'bc', 'frequent', 'hair', 'pitcher', 'utensils','fly', 'fiancé', 'brown', 'chic', 
        'tart', 'savory', 'specials', 'low', 'notch', 'dark', 'combo', 'saw', 'mom', 'already', 'poor', 'worst', 'save',
        'horrible', 'business', 'ruin', 'happen', 'smell', 'sorry', 'immediately', 'help', 'stand', 'huge', 'w', 'soon',
        'casual', 'district', 'unlimited', 'board', 'stay', 'upper', 'par', 'part', 'garden', 'stand', 'somewhat', 'term',
        'style', 'fan', 'write', 'read', 'literally', 'change', 'mention', 'pick', 'send', 'weird', 'whole', 'basically',
        'annoy', 'delish', 'mouth', 'question', 'refill', 'question', 'boyfriend', 'bf', 'girlfriend', 'gf', 'wow', 'stuff',
        'complimentary', 'superb', 'pleasant', 'reasonably', 'provide', 'entire', 'rush', 'forever', 'fabulous', 'strange',
        'middle', 'phone', 'world', 'phenomenal', 'appreciate', 'entree', 'past', 'across', 'st', 'seriously', 'months', 
        'post', 'local', 'online', 'dog', 'chair', 'cup', 'etc', 'limit', 'worry', 'paper', 'move', 'cajun', 'downstairs', 
        'mix', 'advance', 'upscale', 'shoot', 'available', 'single', 'chance', 'weeks', 'word', 'wish', 'somewhere', 
        'moment', 'request', 'issue', 'turn', 'spectacular', 'twice', 'recently', 'story', 'enjoyable', 'variety', 'fusion', 
        'authentic', 'unmemorable', 'diner', 'touch', 'vegetarian', 'plus', 'hit', 'become', 'easily', 'round', 'entrees',
        'app', 'meals', 'answer', 'apps', 'five', 'def', 'choices', 'hang', 'play', 'typical', 'mostly', 'hear', 'explain',
        'speak', 'boil', 'min', 'problem', 'awful' 'consistently', 'hide', 'team', 'forward', 'lay', 'williamsburg', 
        'clearly', 'gorgeous', 'blow', 'several', 'flag,' 'delight', 'tonight', 'snack', 'venue', 'job', 'suck', 'totally',
        'memorable', 'art', 'design', 'pros', 'mistake', 'sea', 'prime', 'starters', 'die', 'girls', 'boys', 'hubby',
        'husband', 'wife', 'wifey', 'yesterday', 'today', 'persian', 'alice', 'rw', 'greenpoint', 'harlem', 'amuse', 
        'alex', 'snow', 'piano', 'vine', 'georgian', 'spain', 'spanish', 'halal', 'bohemian', 'omakase', 'phobar', 'deer', 
        'cottage', 'none', 'dober', 'porto', 'midday', 'shepard', 'price', 'loveeee', 'seasons', 'lovee', 'loveee', 
        'yard', 'eastern', 'views', 'inn', 'cuban', 'peruvian', 'brazilian', 'israeli', 'malaysian', 'del', 'mao',
        'indonesian', 'path', 'healthy', 'mediterranean', 'daniel', 'tar', 'deluxe', 'aperol', 'located', 'food', 
        'gotham', 'speakeasy', 'stalls', 'scotch', 'nomad', 'filipino', 'bo', 'totto', 'peking', 'margarita', 'tequila',
        'mary', 'bloody','puerto', 'lomo', 'skirt', 'ethiopian', 'saigon', 'vendors', 'san', 'gopchan', 'tim', 'hush',
        'peter', 'yum', 'tater', 'games', 'playing', 'dj', 'greece', 'puppies', 'mighty', 'greene', 'green', 'anna',
        'quinn', 'dekalb', 'museum', 'label', 'kaku', 'jackson', 'retro', 'madame', 'ichiran', 'groupon', 'scottish',
        'distilled', 'frose', 'babbo', 'chloe', 'roses', 'venezuelan', 'jian', 'deff', 'intestine', 'laptop', 'soccer',
        'taps', 'emily', 'rican', 'vietname', 'dole', 'cheek', 'defiantly', 'ume', 'army', 'wtc', 'matt', 'discovery',
        'press', 'poo', 'david', 'tableside', 'baja', 'reunion', 'categories', 'entertainment', 'gramercy', 'restaurant',
        'minetta', 'library', 'engagement', 'supper', 'colombian', 'flies', 'hero', 'nite', 'fishes', 'liberty', 'statue',
        'momofuku', 'pint', 'automatically', 'shoes', 'sam', 'vietnam', 'tony', 'african', 'born', 'unacceptable',
        'fairy', 'surf', 'british', 'australian', 'june', 'indian', 'kevin', 'lebanese', 'kevin', 'mealpal', 'ube',
        'dynasty', 'flawless', 'overcharged', 'shanghainese', 'decoration', 'naked', 'taverna', 'tails', 'hue', 'shower',
        'resturant', 'columbus', 'unmatched', 'battery', 'waterfront', 'florentine', 'mandatory', 'pairings', 'seed',
        'ruby', 'unreal', 'colors', 'trash', 'ho', 'gatsby', 'madison', 'henry', 'bryant', 'reflect', 'lic', 
        'steakhouses', 'nom', 'scenery', 'polish', 'cellar', 'bouche', 'roberta', 'locally', 'racist', 'seoul', 'nancy', 
        'miserable', 'tribeca', 'boyfriends', 'girlfriends', 'grab', 'fort', 'bam', 'drawback', 'secondly', 'nonna', 
        'zest', 'email', 'daughters', 'sons', 'son', 'daughter', 'boy', 'girl', 'boys', 'girls', 'era', 'knowledge',
        'cruise', 'sheep', 'mo', 'detailed', 'ferry', 'deck', 'og', 'happiness', 'il', 'cart', 'thru', 'voice', 'enjoys',
        'owns', 'angie', 'largest', 'answering', 'jewel', 'ryan', 'control', 'plancha', 'cutest', 'jose', 'aussie', 
        'nowadays', 'pina', 'dinning', 'alaska', 'movies', 'james', 'dante', 'colada', 'shockingly', 'shaking', 'jewelry',
        'artistic', 'ivan', 'citizens', 'freak', 'supplement', 'whisky', 'hanoi', 'farmers', 'turkish', 'grey', 'earl',
        'sazerac', 'portuguese', 'wrapper', 'wont', 'tuck', 'supreme', 'patches', 'cosy''grass', 'creamed', 'malbec',
        'whip', 'gift', 'drag', 'argentinian', 'intestines', 'garage', 'xi', 'bake', 'ears', 'meze', 'nye' 'viet', 
        'moscow', 'mule', 'latin', 'granita', 'xian', 'performers', 'voucher', 'upland', 'audience', 'kobe', 'marg',
        'interactive', 'march', 'crawl', 'extravagant', 'hawaii', 'clients', 'hire', 'dust', 'critical', 'cc', 
        'brekkie', 'wavy', 'samurai', 'interact', 'grubhub', 'sake', 'dissapoints', 'bon', 'gardens', 'loyal', 
        'di', 'oven', 'hosted', 'george', 'kura', 'nata', 'hells', 'portugal', 'walks','amy', 'gee', 'imaginative',
        'valentines', 'birthday', 'cheeseboat', 'tuscan', 'pao', 'chris', 'effective', 'emphasis', 'umbrella', 'yoga',
        'vip', 'crabby', 'seattle', 'catered', 'hesitation', 'negroni', 'pinot', 'xiao', 'maya', 'passionate', 'jin',
        'kings', 'precious', 'incident', 'pacing', 'performance', 'tom', 'nasi', 'co', 'nasty', 'fidi', 'paner', 
        'pub', 'tonic', 'tendon', 'uncooked', 'sarabeth', 'nauseous', 'prefect', 'trader', 'converse', 'benny', 'skinny',
        'causal', 'toilet', 'muscles', 'frank', 'equal', 'diver', 'dancers', 'hunan', 'bachelorette', 'bachelor', 'stuy',
        'hangar', 'rubber', 'maze', 'miriam', 'smorgasburg', 'israel', 'singer', 'esque', 'potatoe', 'lake', 'breathtaking',
        'drew', 'dismissive', 'tos', 'impromptu', 'ash', 'neighborhood', 'neighbourhood', 'raise', 'bouncer', 'sproject',
        'unbelievably', 'collection', 'penn', 'relax', 'bronzino', 'yards', 'celebratory', 'celebrate', 'celebration',
        'fri', 'mon', 'tue', 'wed', 'thurs', 'sat', 'sun', 'izakaya', 'ippudo', 'spritz', 'environment', 'claw', 'daddy',
        'tower', 'miznon', 'thunder', 'strormy', 'carroll', 'champs', 'freedom', 'peep', 'arabic', 'mixologist', 'swanky',
        'events', 'warren', 'lager', 'children', 'kids', 'nick', 'siracha', 'brews', 'horrendous', 'horrendos', 'oscar',
        'hutong', 'paloma', 'comedy']

# %%
newstops = ['grass', 'baker', 'newer', 'traif', 'curries', 'lousy', 'secluded', 'maize', 'iranian',
            'cheryl', 'roach', 'offensive', 'ipas', 'dietary', 'restrictions', 'pregnant', 'sweetheart',
            'suggesting', 'attitudes', 'serviced', 'tokyo', 'mai', 'coupon', 'victorian', 'prospect', 
            'player', 'ram', 'terrace', 'heights', 'mono', 'selecting', 'washu', 'pio', 'talented',
            'tunes', 'outrageous', 'irish', 'mall', 'bowery', 'jason', 'smoking', 'football', 'sexy',
            'recption', 'policy', 'deserve', 'confirmed', 'ur', 'tres', 'acoustics', 'dissapoints', 
            'celiac', 'russian', 'ceremony', 'flamenco', 'breweries', 'guinness', 'excuses', 
            'dissapointed', 'wheelchair', 'kee', 'prince', 'hankering', 'grille', 'intolerant', 
            'carlos', 'pool', 'tex', 'durian', 'mi', 'xeo', 'whimsical', 'michael', 'pet', 'slope',
            'hawaiian', 'zen', 'wheelchair', 'beijing', 'yummmm', 'yuck', 'register', 'smash', 
            'barcelona', 'tradition', 'hustle', 'closes', 'close', 'exclusivity', 'attracted', 
            'indifferent', 'baba', 'underrated', 'underground', 'gratuity', 'wifi', 'uptown', 
            'downtown', 'introduce', 'refused', 'frustrated', 'updates', 'updated', 'roomy', 
            'program', 'bougie', 'cans', 'inform', 'beefy', 'browns', 'doubles', 'bubble', 'hanco',
            'trini', 'windsor', 'bareburger', 'connected', 'severely', 'mmm', 'mm', 'crossing', 
            'pizzeria', 'pizzerias', 'liman', 'chana', 'lilia', 'cioppino', 'products', 'hung', 
            'flexible', 'hungover', 'seasonally', 'vivid', 'boba', 'haitian', 'costumer', 'olivier', 
            'rooftop', 'pastor', 'hk', 'zona', 'bonnie', 'security', 'lunches', 'slice', 'crust', 
            'bowling', 'vanessa', 'ali', 'alcove', 'poisoning', 'tots', 'paulie', 'trinidad', 
            'bensonhurst', 'dutch', 'meme', 'wangs', 'woodland', 'movie', 'blanca', 'knots', 
            'archie', 'theater', 'tickets', 'kbbq', 'stumptown', 'hospital', 'bless', 'palace', 
            'blessing', 'wedding', 'adam', 'bumped', 'tan', 'thanksgiving', 'mill', 'christmas', 
            'kindness', 'nan', 'flights', 'jazz', 'tipsy', 'bug', 'skyline', 'descent', 'creams', 
            'mister', 'bklyn', 'feeds', 'santa', 'percent', 'fra', 'blackened', 'brewing', 'grandma', 
            'slices', 'latte', 'chai', 'ew', 'goat', 'saltfish', 'buss', 'jackfruit', 'exchange', 
            'caffe', 'kong', 'hong', 'italy', 'temple', 'italians', 'confirmation', 'mesa', 'marissa', 
            'microwaved', 'gigli', 'cancel', 'fdny', 'banchan', 'doesnt', 'katsu', 'leches', 'lo', 
            'mein', 'bella', 'brighton', 'bison', 'napoleon', 'mocha', 'outback', 'rooms', 'ops', 
            'kensington', 'buon', 'amex', 'mock', 'austrian', 'dram', 'soi', 'gioia', 'coney', 
            'trucks', 'reccomend', 'compelled', 'sichuan', 'wheated', 'lucali', 'buck', 'romeo', 
            'lula', 'cumin', 'lassi', 'samsa', 'boiling', 'addicted', 'jenga', 'staten', 'wear', 
            'cali', 'sports', 'sport', 'clara', 'ikea', 'updating', 'corkage', 'bombay', 'ie', 
            'loyalty', 'limoncello', 'unpretentious', 'microwave', 'yemeni', 'plov', 'fanfare', 
            'river', 'cobb', 'zone', 'serene', 'lied', 'appointment', 'hog', 'chill', 'bahn', 
            'sicilian', 'disappoints', 'msg', 'definately', 'cesar', 'belgian', 'answers', 
            'peru', 'mixto', 'trattoria', 'barista', 'baristas', 'breadcrumbs', 'nicest', 
            'science', 'tail', 'luke', 'cancelled', 'clay', 'driver', 'guac', 'rasta', 'footprints', 
            'alley', 'deliveries', 'soooooooo', 'utica','humongous', 'orleans', 'unwind', 'angus', 
            'antipasti', 'carolina', 'succeed', 'tourist', 'reviewer', 'human', 'critic', 'oreo', 
            'milkshakes', 'karaoke', 'tibs', 'nam', 'cent', 'ktown', 'desperate', 'philly', 'pricy',
            'churrasco', 'della', 'extreme', 'panang', 'thoughtfully', 'kao', 'misi', 'caribbean', 
            'tamarind', 'tso', 'rum', 'legs', 'thin', 'margherita', 'thin', 'toppings', 'dough', 
            'acknowledge', 'tipped', 'awash', 'concerned', 'concerned', 'wat', 'sporting', 'warms',
            'istanbul', 'proportions', 'completed', 'peeps', 'llama', 'llamas', 'fucking', 'pratt',
            'deals', 'amber', 'junk', 'roaster', 'cinco', 'crusts', 'myrtle', 'patsy', 'blonde',
            'deco', 'contemporary', 'bumping', 'cure', 'urban', 'apt', 'wok', 'birds', 'promotion',
            'griot', 'phones', 'dreamy', 'boats', 'crowed', 'fin', 'witch', 'reached', 'faun', 
            'squares', 'incompetent', 'hookah', 'jerk', 'channa', 'frog', 'someplace', 'backyard', 
            'lots', 'smoothies', 'bee', 'prefix', 'calls', 'maria', 'mornings', 'rotten', 'timely', 
            'cupcakes', 'arm', 'leg', 'screens', 'atrocious', 'european', 'timer', 'recommended',
            'ribbon', 'batata', 'ethnic', 'cosy', 'rogers', 'unhelpful', 'doctor', 'remote', 
            'floating', 'angel', 'reliable', 'reply', 'lowkey', 'dumbo', 'lying', 'affordable',
            'ubereats', 'pricey', 'jersey', 'shake', 'shakes', 'ki' 'study', 'vegans', 'vegetarians',
            'tvs', 'setup', 'oasis', 'definetly', 'separated', 'sue', 'swan', 'szechuan', 'za', 
            'canceled', 'cashiers', 'computer', 'cacio', 'pepe', 'endless', 'increase', 'yuji', 
            'incorrect', 'consistently', 'godfather', 'cappuccino', 'respectful', 'chains', 'lefferts', 
            'automatic', 'rotate', 'açaí', 'sunset', 'services', 'oaxacan', 'downright', 'antipasto', 
            'ciabatta', 'swiss', 'buffet', 'petite', 'shitty', 'fi', 'wi', 'jay', 'bacchus', 'bands', 
            'trinidadian', 'carte', 'triple', 'laws', 'banquet', 'eric', 'ki', 'bombs', 'gateway', 
            'sandwhich', 'sleek', 'falafels', 'schwarma', 'screwed', 'theatre', 'reggae', 'soca', 
            'rehearsal', 'boom', 'buzzing', 'nargis', 'fonda', 'tripe', 'walter', 'oat', 'expansive',
            'specialties', 'da', 'flare', 'sizeable', 'rosa', 'korea', 'fountain', 'jani', 'moo', 
            'film', 'graham', 'decade', 'goto', 'disorganized', 'bridal', 'gen', 'jake', 'saint', 
            'nabe', 'outlets', 'entree', 'entrees', 'entrée', 'entrées', 'yrs', 'inventive', 
            'disrespectful', 'stroller', 'paris', 'nerve', 'william', 'tries', 'calming', 
            'starred', 'star', 'stars', 'macho', 'jobs', 'opera', 'tv', 'jajaja', 'friggin', 
            'india', 'luis', 'bubbles', 'res', 'pit', 'unorganized', 'gooood', 'halo', 'hotpot',
            'unprofessional', 'ayce', 'respect', 'marked', 'lifetime', 'santo', 'sooooooo', 
            'piccante', 'schedule', 'poblano', 'guilty', 'hub', 'ciders', 'frite', 'hockey', 
            'steady', 'dudes', 'ehh', 'ridgewood', 'grande', 'avo', 'power', 'yorker', 'warmly',
            'vast', 'forgetting', 'starbucks', 'fails', 'arrogant', 'studying', 'moderate', 'toro',
            'ownership', 'dal', 'sammy', 'aita', 'shepherds', 'fu', 'nuff', 'burg', 'paul', 'blamed',
            'mission', 'listened', 'couples', 'imani', 'patronize', 'length', 'overcrowded', 'bronx', 
            'honor', 'mature', 'munch', 'trap', 'tastey', 'kha', 'advertising', 'arrangements', 'storm',
            'argument', 'liquor', 'license', 'mex', 'traveled', 'restrooms', 'thailand', 'northern',
            'cha', 'diavolo', 'emailed', 'miti', 'stores', 'gathering', 'bang', 'americano', 'generic',
            'oriented', 'tiki', 'ala', 'client', 'filthy', 'renovated', 'religiously', 'maitre', 'drain',
            'chief', 'tavern', 'individually', 'celebrated', 'overpriced', 'ten', 'afterwork', 'sincerely',
            'pier', 'relief', 'heating', 'study', 'sisters', 'brothers']

# %%
stop.update(newstops)

# %%
stop.update(stops)

# %%
stop.update(morestops)

# %%
tokenizer = word_tokenize

# %%
df = pd.read_csv('../../Data/Fullsets/cleanedBrooklynfull.csv')

# %%
import string 
def remove_punctuations(text):
    for punctuation in string.punctuation:
        text = text.replace(punctuation, ' ')
    return text

# %%
df.head()
# Out:
#    Unnamed: 0 price  rating           restaurant_id   restaurant_name  \
# 0           2    $$     4.0  49ST--X1jcIPzUIM1O3K6w         Mominette
# 1           3    $$     4.0  GA5msU6NO9rQRctPfDJCBg  Peaches HotHouse
# 2           4    $$     4.5  GxMhN2PEttvw7CRGIzB6Gg           Baron's
# 3           6    $$     4.5  swKXaURwqdSrSTcpHsxdbA         Lowerline
# 4           7    $$     4.0  1x2hn3e9sCCZca1cnRTpEg      Claw Daddy's
#
#    review_count                                           review_1  \
# 0           652  Came here for a dinner and first thing I want ...
# 1          1117  How did they get it so perfectly crispy?? What...
# 2           268  A GEM. This restaurant was, simply put, amazin...
# 3           132  Came here before a comedy show nearby in an ex...
# 4           364  SO much fun!  Went with 4 people for the Claw ...
#
#                                             review_2  \
# 0  So, after my large party experience here, I am...
# ...

# %% [markdown]
# ## Full Run

# %%
rva
# Out:
# ['review_1',
#  'review_2',
#  'review_3',
#  'review_4',
#  'review_5',
#  'review_6',
#  'review_7',
#  'review_8',
#  'review_9',
#  'review_10',
#  'review_11',
#  'review_12',
#  'review_13',
#  'review_14',
#  'review_15',
#  'review_16',
#  'review_17',
#  'review_18',
#  'review_19',
#  'review_20',
#  'review_21',
#  'review_22',
#  'review_23',
#  'review_24',
#  'review_25',
#  'review_26',
#  'review_27',
#  'review_28',
#  'review_29',
#  'review_30',
#  'review_31',
#  'review_32',
#  'review_33',
#  'review_34',
#  'review_35',
#  'review_36',
#  'review_37',
#  'review_38',
#  'review_39',
#  'review_40',
#  'review_41',
#  'review_42',
#  'review_43',
#  'review_44',
#  'review_45',
#  'review_46',
#  'review_47',
#  'review_48',
#  'review_49',
#  'review_50',
#  'review_51',
#  'review_52',
#  'review_53',
#  'review_54',
#  'review_55',
#  'review_56',
#  'review_57',
#  'review_58',
#  'review_59',
#  'review_60',
#  'review_61',
#  'review_62',
#  'review_63',
# ...

# %%
rva = ['review_'+ str(x+1) for x in range(138)]

# %%
df = df.fillna(value=str('none'))

# %%
df.drop(columns=['Unnamed: 0', 'price', 'rating', 'restaurant_id', 'review_count'], axis=1, inplace=True)

# %%
for y in rva:
    df[y] = df[y].apply(remove_punctuations)

# %%
for y in rva:
    df[y] = df[y].str.replace('\d+', ' ')

# %%
for y in rva:
    df[y] = df[y].apply(lambda x: [word.lower() for word in x.split() if word.lower() not in (stop)])

# %%
for y in tqdm(rva):
    df['lem_'+y] = df[y].apply(lambda x: [lemmatizer.lemmatize(word, pos = 'r') for word in x])
# Out:
# 100%|██████████| 138/138 [00:09<00:00, 15.08it/s]

# %%
# for y in tqdm(rva):
#     df['token_'+y]= df[y].apply(tokenizer)
# Out:
#  53%|█████▎    | 74/139 [00:14<00:12,  5.34it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-f9800d88297a> in <module>
#       1 for y in tqdm(rva):
# ----> 2     df['token_'+y]= df[y].apply(tokenizer)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# ~/.local/lib/python3.7/site-packages/nltk/tokenize/__init__.py in word_tokenize(text, language, preserve_line)
#     144     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     145     return [
# ...

# %%
df.head()
# Out:
#                  restaurant_name  \
# 0                        Upstate
# 1                         Amélie
# 2  Clinton Street Baking Company
# 3                       LoveMama
# 4                        BoCaphe
#
#                                             review_1  \
# 0  [oysters, tuna, tartare, oysters, tuna, tartar...
# 1  [flight, mussels, tuna, tartare, salmon, moist...
# 2  [stopped, normally, cause, allowed, annoying, ...
# 3  [happier, mark, wiens, youtube, videos, pictur...
# 4  [nearby, noon, bocaphe, young, hip, decoration...
#
#                                             review_2  \
# 0  [liked, turned, case, straight, turf, steak, s...
# 1  [earlier, month, typically, favor, american, c...
# 2  [spoiled, syrup, pancake, blueberry, unostenta...
# 3  [checked, lovemama, halfway, ambiance, matches...
# 4  [found, noodles, server, service, forgot, serv...
#
#                                             review_3  \
# 0  [overrated, opinion, prob, surrounding, lucky,...
# ...

# %%
df1 = df[df.columns[139:280]]

# %%
df1.head()
# Out:
#                                         lem_review_1  \
# 0  [information, check, kinda, unfair, customers,...
# 1  [aioli, buns, soggy, sandwich, adult, capable,...
# 2  [service, ambiance, decor, god, blowing, edit,...
# 3  [nearby, luckily, oyster, abundance, oysters, ...
# 4  [feast, crack, splash, stains, clothes, damnnnnn]
#
#                                         lem_review_2  \
# 0  [experience, dear, bridal, poorly, organized, ...
# 1  [promptly, service, throughout, attentive, bre...
# 2           [service, ambiance, decor, god, blowing]
# 3  [windoowww, walllll, damn, hands, ohh, shrimp,...
# 4  [interested, adult, capri, suns, albeit, sneak...
#
#                                         lem_review_3  \
# 0  [intimidating, courtyard, greenery, exposed, b...
# 1  [nashville, chicken, loves, ya, chicken, split...
# 2  [fiancée, specifically, dot, oysters, self, re...
# 3  [trying, fits, bomb, following, oysters, oyste...
# ...

# %%
temps = df1.values.tolist()

# %% [markdown]
# ### Final Clean

# %%
#flatten temps for doc2bow
temp = []
for row in temps:
    if type(row) == list:
        temp.extend(row)

# %%
#getting rid of nones
def deleting(list_1,del_name):
    for sub_list in tqdm(list_1):
        if del_name in sub_list:
            list_1.remove(sub_list)
    return list_1

deleting(temp, 'none')
# Out:
# 100%|██████████| 98256/98256 [00:00<00:00, 328522.89it/s]
# [['information',
#   'check',
#   'kinda',
#   'unfair',
#   'customers',
#   'anywhere',
#   'ppl',
#   'planning',
#   'ppl',
#   'sign',
#   'welcomed',
#   'host',
#   'earlier',
#   'offered',
#   'bartender',
#   'attentive',
#   'skilled',
#   'signature',
#   'mezcal',
#   'smoky',
#   'goes',
#   'rose',
#   'escargot',
#   'mushy',
#   'chewy',
#   'done',
#   'balanced',
#   'garlic',
#   'herbs',
#   'oil',
#   'salmon',
#   'tartar',
#   'goes',
#   'potato',
#   'chips',
#   'arugula',
#   'salad',
#   'seasoned',
#   'fish',
#   'lobster',
#   'bisque',
#   'goes',
#   'pieces',
#   'lobsters',
#   'found',
#   'fishy',
#   'pesto',
#   'pasta',
#   'portobello',
#   'mushrooms',
#   'mushrooms',
#   'ton',
#   'pesto',
#   'parmesan',
#   'sharpness',
#   'burger',
#   'brag',
#   'shared',
#   'creme',
#   'brulee',
#   'fire',
#   'prefer',
#   'bigger',
#   'greedy',
#   'experience',
#   'surprised',
# ...

# %% [markdown]
# ### Remove Stop Words

# %%
#final stop word removal
tempi=[]
for review in temp:
    wr=[]
    for word in review:
        if word not in stop:
            wr.append(word)
    tempi.append(wr)

# %%
temp = []
for row in temps:
    if type(row) == list:
        temp.extend(row)

# %%
from gensim import corpora
import gensim
from gensim.models import LdaModel

# %%
#710083
len(tempi)
# Out:
# 98256

# %% [markdown]
# ### LDA

# %%
import gensim
from gensim import corpora
import gensim
from gensim.models import LdaMulticore 
from gensim import corpora, models
from gensim.sklearn_api import TfIdfTransformer

# get all of the words in our corpus & create a bag of words
dictionary = gensim.corpora.Dictionary(tempi)
bow_corpus = [dictionary.doc2bow(doc) for doc in tempi]

# get the tf-idf (gensim-style, using their implementation of 
# sklearn's tf-idf model) of our data
model = TfIdfTransformer()
corpus_tfidf = model.fit_transform(bow_corpus)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
no_features = 1000

# %%
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2, max_features=no_features, stop_words='english')
tf = tf_vectorizer.fit_transform(tempi)
tf_feature_names = tf_vectorizer.get_feature_names()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-0c5a86a620cf> in <module>
#       1 tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2, max_features=no_features, stop_words='english')
# ----> 2 tf = tf_vectorizer.fit_transform(tempi)
#       3 tf_feature_names = tf_vectorizer.get_feature_names()
#
# /anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1056
#    1057         vocabulary, X = self._count_vocab(raw_documents,
# -> 1058                                           self.fixed_vocabulary_)
#    1059
#    1060         if self.binary:
#
# /anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#     968         for doc in raw_documents:
#     969             feature_counter = {}
# ...

# %%
# use LDA to get 10 topics to split up our descriptions into
lda_model_tfidf = LdaMulticore(corpus_tfidf, num_topics=15, id2word=dictionary, passes=20, workers=4)

for idx, topic in lda_model_tfidf.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))
# Out:
# Topic: 0 Word: 0.012*"crepes" + 0.005*"shark" + 0.004*"honor" + 0.004*"gumbo" + 0.004*"fettuccini" + 0.003*"mature" + 0.003*"biryani" + 0.003*"whitefish" + 0.003*"munch" + 0.002*"trap"
# Topic: 1 Word: 0.007*"bibimbap" + 0.005*"satay" + 0.004*"samosa" + 0.002*"tastey" + 0.002*"kha" + 0.002*"advertising" + 0.002*"arrangements" + 0.002*"puffs" + 0.002*"storm" + 0.002*"argument"
# Topic: 2 Word: 0.011*"masala" + 0.005*"liquor" + 0.004*"license" + 0.003*"mex" + 0.003*"asada" + 0.003*"traveled" + 0.003*"restrooms" + 0.003*"pretzels" + 0.002*"carne" + 0.002*"okonomiyaki"
# Topic: 3 Word: 0.006*"thailand" + 0.004*"aloo" + 0.004*"vindaloo" + 0.004*"zeppoles" + 0.003*"northern" + 0.002*"cha" + 0.002*"diavolo" + 0.002*"emailed" + 0.002*"miti" + 0.002*"hotdogs"
# Topic: 4 Word: 0.004*"stores" + 0.004*"gathering" + 0.004*"bang" + 0.003*"yellowtail" + 0.003*"americano" + 0.003*"generic" + 0.003*"oriented" + 0.003*"tiki" + 0.002*"ala" + 0.002*"client"
# ...

# %%
'honor', 'mature', 'munch', 'trap', 'tastey', 'kha', 'advertising', 'arrangements', 'storm', 'argument', 'liquor', 'license', 'mex', 'traveled', 'restrooms', 'thailand', 'northern', 'cha', 'diavolo', 'emailed', 'miti', 'stores', 'gathering', 'bang', 'americano', 'generic', 'oriented', 'tiki', 'ala', 'client', 'filthy', 'renovated', 'religiously', 'maitre', 'drain', 'chief', 'tavern', 'individually', 'celebrated', 'overpriced', 'ten', 'afterwork', 'sincerely', 'pier', 'relief', 'heating', 'study', 'sisters', 'brothers'

# %%
from gensim.test.utils import datapath

 # Save model to disk.
temp_file = ("newbestldamulticore2")
lda_model_tfidf.save(temp_file)

# %%
lda = LdaModel.load('newbestldamulticore')

# %% [markdown]
# ### Function to add Topic Categories to Reviews

# %%
def get_lda_category(lemmetized):
    try:
        item_tfidf = model.transform(dictionary.doc2bow(lemmetized))
    except IndexError:
        print('Index Error:', lemmetized)
        item_tfidf=[(0, 0)]
    try: 
        cat = sorted([x for x in lda_model_tfidf.get_document_topics(item_tfidf)][0], key=lambda x:x[1])[-1][0]
    except TypeError:
        print('Type Error:', lemmetized)
        cat = 50
    return cat

# %% [markdown]
# #### Run function

# %%
#print topics
for idx, topic in lda.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))
# Out:
# Topic: 0 Word: 0.019*"lobster" + 0.013*"oysters" + 0.013*"sushi" + 0.012*"crab" + 0.011*"roll" + 0.009*"fish" + 0.008*"shrimp" + 0.006*"uni" + 0.006*"rolls" + 0.006*"tuna"
# Topic: 1 Word: 0.019*"service" + 0.015*"staff" + 0.014*"atmosphere" + 0.008*"attentive" + 0.008*"ambiance" + 0.008*"experience" + 0.006*"prices" + 0.006*"decor" + 0.005*"ambience" + 0.005*"environment"
# Topic: 2 Word: 0.012*"steak" + 0.009*"empanadas" + 0.007*"ceviche" + 0.005*"paella" + 0.005*"skirt" + 0.005*"service" + 0.004*"lomo" + 0.004*"mojitos" + 0.004*"puerto" + 0.004*"polenta"
# Topic: 3 Word: 0.007*"service" + 0.005*"experience" + 0.005*"waiter" + 0.005*"server" + 0.005*"waitress" + 0.004*"check" + 0.004*"staff" + 0.004*"manager" + 0.004*"customer" + 0.003*"hostess"
# Topic: 4 Word: 0.015*"eggs" + 0.009*"pancakes" + 0.008*"chicken" + 0.008*"waffles" + 0.007*"egg" + 0.007*"benedict" + 0.006*"avocado" + 0.006*"bacon" + 0.006*"sandwich" + 0.005*"cheese"
# ...

# %%
#List Comprehension to run function
for y in rva:
    df1['lda_'+y] = df1['lem_'+y].apply(lambda x: get_lda_category(x))
# Out:
# Index Error: []
# Type Error: []
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Index Error: []
# Type Error: []
# Index Error: []
# Type Error: []
# Index Error: []
# Type Error: []
# Index Error: ['heights']
# Type Error: ['heights']
# Index Error: []
# Type Error: []
# Index Error: []
# Type Error: []
# Index Error: []
# Type Error: []
# Index Error: []
# Type Error: []
# Index Error: []
# Type Error: []
# Index Error: []
# Type Error: []
# Index Error: []
# Type Error: []
# Index Error: []
# Type Error: []
# Index Error: []
# Type Error: []
# Index Error: []
# Type Error: []
# Index Error: []
# Type Error: []
# Index Error: []
# Type Error: []
# Index Error: []
# Type Error: []
# ...

# %%
df1.head(20)
# Out:
#                                          lem_review_1  \
# 0   [oysters, tuna, tartare, oysters, tuna, tartar...
# 1   [flight, mussels, tuna, tartare, salmon, moist...
# 2   [stopped, normally, cause, allowed, annoying, ...
# 3   [happier, mark, wiens, youtube, videos, pictur...
# 4   [nearby, noon, bocaphe, young, hip, decoration...
# 5   [service, anytime, pointdrinks, pointvibes, po...
# 6   [modern, presented, multiple, soju, flight, ch...
# 7   [surprised, eaten, life, separated, regular, r...
# 8   [rating, reviewing, wonderfully, december, che...
# 9   [udon, chicken, heard, multiple, niku, udon, n...
# 10  [unbeatable, prices, qualityhighly, classics, ...
# 11  [service, server, akin, attentive, ate, prior,...
# 12  [layout, uglyduckling, tall, window, entrance,...
# 13  [pasta, united, states, surpassed, italy, jake...
# 14  [included, soup, dumplings, expected, process,...
# 15  [discovered, nonono, opening, grateful, penn, ...
# ...

# %%
df1.to_csv('ldaManhattan.csv')

# %%
df1.to_excel('ldamanhattan2.xlsx')

# %%
import pickle
# your code
lda_model_tfidf.save('ldapickle.pkl','w')
# you may load it back again
#lda_copy = pickle.load(file(filename))

# %%
df1.to_excel('ldamanhattan3.xlsx')

# %%
review1 = ['unfortunately', 'dinner', 'pretty', 'disappointing', 'maybe', 'ordered', 'wrong', 'thing', 
           'restaurant', 'overall', 'rating', 'surprised', 'left', 'feeling', 'underwhelmed', 'setting', 
           'reservation', 'dinner', 'friday', 'night', 'pm', 'restaurant', 'dark', 'tight', 'squeeze', 
           'tables', 'quite', 'close', 'together', 'good', 'ambiance', 'date', 'completely', 'full', 
           'friday', 'night', 'food', 'ordered', 'oysters', 'east', 'coast', 'west', 'coast', 'probably', 
           'highlight', 'meal', 'great', 'also', 'ordered', 'uni', 'served', 'pieces', 'bread', 'salmon', 
           'roe', 'raw', 'egg', 'burrata', 'served', 'big', 'pieces', 'pasta', 'sweet', 'tomato', 'sauce', 
           'uni', 'great', 'dish', 'love', 'uni', 'extremely', 'fishy', 'understanding', 'maine', 'mild', 
           'uni', 'japan', 'taste', 'fresh', 'go', 'well', 'would', 'think', 'raw', 'egg', 'broken', 'top',
           'mixed', 'salmon', 'roe', 'carrot', 'purée', 'burrata', 'creamy', 'soft', 'also', 'quite', 
           'small', 'served', 'big', 'pieces', 'pasta', 'nothing', 'burrata', 'left', 'dish', 'half', 
           'eaten', 'verdict', 'amazing', 'seafood', 'restaurants', 'city', 'think', 'upstate', 'par', 
           'friend', 'agreed', 'would', 'also', 'give', 'stars', 'food', 'probably', 'back']
review2 = ['friends', 'came', 'dinner', 'sunday', 'evening', 'reservation', 'wait', 'outside', 'line', 
           'forming', 'get', 'since', 'restaurant', 'opened', 'yet', 'got', 'seated', 'looked', 'menu',
           'bit', 'overwhelmed', 'much', 'food', 'choose', 'ended', 'ordering', 'bunch', 'skewers', 
           'yakitori', 'share', 'like', 'chicken', 'wing', 'steak', 'shishito', 'peppers', 'tofu', 
           'also', 'got', 'stuffed', 'mushroom', 'pesto', 'scallops', 'think', 'mackerel', 'also', 
           'sashimi', 'special', 'got', 'good', 'believe', 'included', 'tuna', 'scallop', 'sort', 'fish',
           'everything', 'ordered', 'delicious', 'portions', 'small', 'enough', 'room', 'stomachs', 'entrees', 
           'tori', 'tantan', 'ramen', 'requested', 'little', 'bit', 'spicy', 'took', 'initial', 'bites', 'mouth',
           'fire', 'got', 'used', 'enjoyed', 'much', 'broth', 'creamy', 'almost', 'peanut', 'butter', 'like', 
           'ground', 'pork', 'perfect', 'waitress', 'sweet', 'attentive', 'prices', 'reasonable', 'would', 
           'definitely', 'come', 'area']
lems = ['reservation', 'saturday', 'night', 'dinner', 'everything', 'ordered', 'incredible', 'started', 
        'half', 'dozen', 'oysters', 'tuna', 'tartare', 'oysters', 'fresh', 'tasty', 'tuna', 'tartare', 
        'really', 'yummy', 'came', 'served', 'bread', 'would', 'enjoyed', 'plantain', 'chips', 'entrees', 
        'split', 'scallops', 'grilled', 'octopus', 'flavorful', 'cooked', 'perfection', 'want', 'come', 'back', 
        'happy', 'hour']

# %%
lda_model_tfidf.print_topics()
# Out:
# [(0,
#   '0.019*"lobster" + 0.013*"oysters" + 0.013*"sushi" + 0.012*"crab" + 0.011*"roll" + 0.009*"fish" + 0.008*"shrimp" + 0.006*"uni" + 0.006*"rolls" + 0.006*"tuna"'),
#  (1,
#   '0.019*"service" + 0.015*"staff" + 0.014*"atmosphere" + 0.008*"attentive" + 0.008*"ambiance" + 0.008*"experience" + 0.006*"prices" + 0.006*"decor" + 0.005*"ambience" + 0.005*"environment"'),
#  (2,
#   '0.012*"steak" + 0.009*"empanadas" + 0.007*"ceviche" + 0.005*"paella" + 0.005*"skirt" + 0.005*"service" + 0.004*"lomo" + 0.004*"mojitos" + 0.004*"puerto" + 0.004*"polenta"'),
#  (3,
#   '0.007*"service" + 0.005*"experience" + 0.005*"waiter" + 0.005*"server" + 0.005*"waitress" + 0.004*"check" + 0.004*"staff" + 0.004*"manager" + 0.004*"customer" + 0.003*"hostess"'),
#  (4,
#   '0.015*"eggs" + 0.009*"pancakes" + 0.008*"chicken" + 0.008*"waffles" + 0.007*"egg" + 0.007*"benedict" + 0.006*"avocado" + 0.006*"bacon" + 0.006*"sandwich" + 0.005*"cheese"'),
#  (5,
# ...

# %%
lem1 = dictionary.doc2bow(review1)

# %%
lda_model_tfidf.get_document_topics(lem1)
# Out:
# [(0, 0.5354153), (9, 0.446523)]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 896 entries, 0 to 895
# Columns: 278 entries, lem_review_1 to lda_review_139
# dtypes: object(278)
# memory usage: 1.9+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 896 entries, 0 to 895
# Columns: 279 entries, restaurant_name to lem_review_139
# dtypes: object(279)
# memory usage: 1.9+ MB

# %%
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(ldamodel, doc_term_matrix, dictionary)
vis
