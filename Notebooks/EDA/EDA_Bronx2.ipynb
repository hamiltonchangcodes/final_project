# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
pd.options.display.max_rows = 999
pd.options.display.max_columns = 999
# %matplotlib inline

# %%
df = pd.read_csv('../../Data/bronxfullreview.csv', lineterminator='\n')

# %%
df.head()
# Out:
#    Unnamed: 0   city price  rating           restaurant_id  \
# 0           0  Bronx    $$     4.0  ba-MPbYnM6T30RNgPdUvtQ
# 1           1  Bronx   NaN     4.5  03RL_VcRGXuICl2R6Luu_Q
# 2           2  Bronx    $$     4.0  P8PGGzxZeMm6Na5gYqvudw
# 3           3  Bronx    $$     4.0  2f-qNpdVJl2h9L6SHYuICA
# 4           4  Bronx    $$     4.5  b6jOwyX4iaagw8YjXqq1sA
#
#                    restaurant_name  review_count  \
# 0  Shanghai Red Asian Latin Bistro            54
# 1               The Waterfront NYC            11
# 2                        Travesias           470
# 3                      Havana Cafe           767
# 4              Antonio's Trattoria           744
#
#                                             review_1  \
# 0  Ok so imma start with a Thank You to my waitre...
# 1  New season, new clubhouse, and new menu from T...
# 2  I came here with family, a large group at that...
# 3  on a consistent basisI can ALWAYS say I have a...
# ...

# %%
df = df.drop(columns=['Unnamed: 0', 'price'])

# %%
df.head()
# Out:
#     city  rating           restaurant_id                  restaurant_name  \
# 0  Bronx     4.0  ba-MPbYnM6T30RNgPdUvtQ  Shanghai Red Asian Latin Bistro
# 1  Bronx     4.5  03RL_VcRGXuICl2R6Luu_Q               The Waterfront NYC
# 2  Bronx     4.0  P8PGGzxZeMm6Na5gYqvudw                        Travesias
# 3  Bronx     4.0  2f-qNpdVJl2h9L6SHYuICA                      Havana Cafe
# 4  Bronx     4.5  b6jOwyX4iaagw8YjXqq1sA              Antonio's Trattoria
#
#    review_count                                           review_1  \
# 0            54  Ok so imma start with a Thank You to my waitre...
# 1            11  New season, new clubhouse, and new menu from T...
# 2           470  I came here with family, a large group at that...
# 3           767  on a consistent basisI can ALWAYS say I have a...
# 4           744  Love the food in this off Arthur Street spot. ...
#
#                                             review_2  \
# 0  I was really conflicted in writing this review...
# ...

# %%
df.isnull().sum()
# Out:
# city                 0
# rating               0
# restaurant_id        0
# restaurant_name      0
# review_count         0
# review_1             9
# review_2            50
# review_3            84
# review_4           115
# review_5           136
# review_6           157
# review_7           174
# review_8           196
# review_9           214
# review_10          231
# review_11          247
# review_12          253
# review_13          261
# review_14          274
# review_15          283
# review_16          291
# review_17          302
# review_18          311
# review_19          320
# review_20          331
# review_21          348
# review_22          357
# review_23          369
# review_24          381
# review_25          390
# review_26          396
# review_27          400
# review_28          413
# review_29          418
# review_30          422
# review_31          427
# review_32          433
# review_33          441
# review_34          448
# review_35          457
# ...

# %%
df = df.dropna(thresh=df.shape[1]-250)

# %%
df.isnull().sum()
# Out:
# city                 0
# rating               0
# restaurant_id        0
# restaurant_name      0
# review_count         0
# review_1             0
# review_2             0
# review_3             0
# review_4             0
# review_5             0
# review_6             0
# review_7             0
# review_8             0
# review_9             0
# review_10            0
# review_11           16
# review_12           22
# review_13           30
# review_14           43
# review_15           52
# review_16           60
# review_17           71
# review_18           80
# review_19           89
# review_20          100
# review_21          117
# review_22          126
# review_23          138
# review_24          150
# review_25          159
# review_26          165
# review_27          169
# review_28          182
# review_29          187
# review_30          191
# review_31          196
# review_32          202
# review_33          210
# review_34          217
# review_35          226
# ...

# %%
df.head(25)
# Out:
#              city  rating           restaurant_id  \
# 0           Bronx     4.0  ba-MPbYnM6T30RNgPdUvtQ
# 1           Bronx     4.5  03RL_VcRGXuICl2R6Luu_Q
# 2           Bronx     4.0  P8PGGzxZeMm6Na5gYqvudw
# 3           Bronx     4.0  2f-qNpdVJl2h9L6SHYuICA
# 4           Bronx     4.5  b6jOwyX4iaagw8YjXqq1sA
# 5           Bronx     4.0  m6p_huTMlmMvUNkxDL1YCQ
# 6           Bronx     3.5  BiOgIv7Nj3oDrJTHiDt45g
# 7           Bronx     4.0  hVIejxln5ouANt854EdeYQ
# 8           Bronx     4.5  ZZxYVgodx2TxbYwh-0YU1w
# 9           Bronx     4.0  By2Zl1imtu0SpA4IBziN1g
# 10      The Bronx     4.5  7Qv-M5VzwxBkpH7ZOeoJgQ
# 11       New York     5.0  CY1lJBQatCNo4-_ljlS1rA
# 12  College Point     4.5  uthkinOdYCrM0j-5tYC63w
# 13          Bronx     4.5  LXOvAoDO9QomXlvYdc0rrQ
# 14          Bronx     2.5  -5JwknVLIT36YTGhvkuBaw
# 15          Bronx     4.5  9CMlqg0iZgYMlyUN9iroeg
# 16          Bronx     4.0  KAxYFGyOQ7ysCmYmh8jKtw
# 17          Bronx     4.5  DLnn2qw-KJAmazB-hMmSEw
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 769 entries, 0 to 999
# Columns: 265 entries, city to review_260
# dtypes: float64(1), int64(1), object(263)
# memory usage: 1.6+ MB

# %%
len(df)
# Out:
# 769

# %%
sns.distplot(df.rating)

# %%
sns.distplot(df.review_count)

# %%
sns.scatterplot(x=df.review_count, y=df.rating)

# %%
df.review_count.value_counts()
# Out:
# 22      18
# 13      15
# 10      13
# 19      12
# 34      12
# 21      12
# 20      12
# 39      11
# 15      11
# 17      11
# 18      10
# 27      10
# 28       9
# 16       9
# 11       9
# 31       8
# 37       8
# 35       8
# 24       8
# 32       8
# 33       8
# 45       7
# 59       7
# 23       7
# 85       6
# 12       6
# 57       6
# 134      6
# 46       6
# 29       6
# 36       6
# 14       6
# 38       5
# 47       5
# 26       5
# 135      5
# 48       5
# 62       5
# 73       5
# 86       5
# 181      4
# 25       4
# 113      4
# 145      4
# 80       4
# 67       4
# 108      4
# 52       4
# 68       4
# 69       4
# 56       4
# 58       4
# 9        4
# 64       3
# 153      3
# 215      3
# 155      3
# 230      3
# 118      3
# 99       3
# 144      3
# 143      3
# 105      3
# 109      3
# 112      3
# 128      3
# 268      3
# 120      3
# 123      3
# 84       3
# 122      3
# 61       3
# 55       3
# 60       3
# 78       3
# 63       3
# ...

# %%
df.city.value_counts()
# Out:
# Bronx                      425
# New York                   142
# Flushing                    38
# New Rochelle                29
# Astoria                     19
# East Bronx                  11
# Yonkers                     10
# Mount Vernon                 9
# Pelham                       8
# College Point                8
# Whitestone                   7
# The Bronx                    6
# West Bronx                   5
# Pelham Manor                 5
# Long Island City             4
# Bronxville                   4
# Jackson Heights              4
# Corona                       3
# Larchmont                    3
# Bayside                      2
# Queens                       2
# Middletown - Pelham Bay      2
# Woodside                     2
# City Island                  2
# Sunnyside                    2
# Rego Park                    1
# Norwood                      1
# Douglaston                   1
# Village of Pelham            1
# Manhattan                    1
# ...

# %%
df = df[df['city'].isin(['Bronx', 'New York', 'New Rochelle', 'East Bronx', 'Yonkers', 'Mount Vernon', 'Pelham', 'The Bronx', 'West Bronx', 'Pelham Manor', 'Bronxville', 'Larchmont', 'Middletown - Pelham Bay', 'City Island', 'Norwood', 'Village of Pelham', 'Eastchester', 'Mount Eden', 'Mamaroneck', 'South Bronx', 'Riverdale'])]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 668 entries, 0 to 999
# Columns: 265 entries, city to review_260
# dtypes: float64(1), int64(1), object(263)
# memory usage: 1.4+ MB

# %%
df.head()
# Out:
#     city  rating           restaurant_id                  restaurant_name  \
# 0  Bronx     4.0  ba-MPbYnM6T30RNgPdUvtQ  Shanghai Red Asian Latin Bistro
# 1  Bronx     4.5  03RL_VcRGXuICl2R6Luu_Q               The Waterfront NYC
# 2  Bronx     4.0  P8PGGzxZeMm6Na5gYqvudw                        Travesias
# 3  Bronx     4.0  2f-qNpdVJl2h9L6SHYuICA                      Havana Cafe
# 4  Bronx     4.5  b6jOwyX4iaagw8YjXqq1sA              Antonio's Trattoria
#
#    review_count                                           review_1  \
# 0            54  Ok so imma start with a Thank You to my waitre...
# 1            11  New season, new clubhouse, and new menu from T...
# 2           470  I came here with family, a large group at that...
# 3           767  on a consistent basisI can ALWAYS say I have a...
# 4           744  Love the food in this off Arthur Street spot. ...
#
#                                             review_2  \
# 0  I was really conflicted in writing this review...
# ...

# %%
df.loc[df['review_count']>2000]
# Out:
#          city  rating           restaurant_id     restaurant_name  \
# 291  New York     3.5  fxGpXRxFUDzlU3Cyszu4uQ  Red Rooster Harlem
# 393  New York     4.0  tsiC3VpO-hZEb98Qk3p-DQ          Amy Ruth's
# 836  New York     4.0  OAqsZMbjv66nOMqlimnYuQ                 Uva
# 950  New York     4.5  -OixbLnFLCzQclxCSbUQ8w             Up Thai
#
#      review_count                                           review_1  \
# 291          3130  This has very quickly become a favorite brunch...
# 393          2543  Tasha (the little one ;) has an amazing energy...
# 836          2283  My husband and I came here last month after a ...
# 950          2139  After walking past Up Thai all the time and se...
#
#                                               review_2  \
# 291  My boyfriend and I have been meaning to try th...
# 393  WHAT'S WITH THE HYPE? I can tolerate to some d...
# 836  This was a nice night!! The calamari and the r...
# 950  We had fabulous dinner at Up Thai. We started ...
#
# ...

# %%
df = df.drop([291, 393, 836, 950])

# %%
df.loc[df['review_count']>900]
# Out:
#          city  rating           restaurant_id           restaurant_name  \
# 224  New York     4.0  4rWJGwb3rjDoZHA0AECa5A                   Melba's
# 380  New York     3.5  RI-tVET-wKFeRNKm4cg0wQ       Sylvia's Restaurant
# 508  New York     4.0  IJg3TdXz8IzKTfcspmr8MQ            Seasoned Vegan
# 533  New York     4.0  J9xVQScnr0lYWl61_mLXMA                      Lido
# 671  New York     4.5  9pMhRYYgV7E9L7pzECtJKA  The Drunken Munkey - UES
# 770  New York     3.5  Z8pm4rLTBki7OLgtbcTXEg             Corner Social
# 991  New York     4.0  mWS4umRg2AyykyAClMrIRw               The Penrose
#
#      review_count                                           review_1  \
# 224           998  Myself, my husband, aunt and uncle had a 5 p.m...
# 380          1773  Went on a Saturday for lunch and noticed it wa...
# 508          1093  I've heard so many amazing things about this p...
# 533           945  Perfect Brunch! It's great to know that I don'...
# ...

# %%
df = df.drop([224, 380, 508, 533, 671, 770, 991])

# %%
df.loc[df['review_count']>500]
# Out:
#              city  rating           restaurant_id  \
# 3           Bronx     4.0  2f-qNpdVJl2h9L6SHYuICA
# 4           Bronx     4.5  b6jOwyX4iaagw8YjXqq1sA
# 8           Bronx     4.5  ZZxYVgodx2TxbYwh-0YU1w
# 37          Bronx     3.5  oexDsgqmXc9Qe3fy3uYx7g
# 40          Bronx     4.0  tLZfepIfSf0a80zHQTbTGQ
# 41          Bronx     3.5  KNEDp6x3J6lSK-8HD-pGIQ
# 42          Bronx     3.5  _z52AlCKEU2Lc-CB1j6Kaw
# 75          Bronx     4.0  ciHt5n5rmpby1YcC_6JVrg
# 89          Bronx     3.0  tvsllkjgQqMaa7Z1gUkC3A
# 118      New York     4.0  Z-hDHjP4Eza6BA4G97tzVA
# 127      New York     4.0  ej_pg-wc-ZtexQKPPiQ_5w
# 213      New York     4.0  XOnspIaW6mYVmrvgqOaYSQ
# 227  New Rochelle     4.0  6EskvVuvoQVyJ1CcRonIBQ
# 272      New York     4.0  hw8ziubXsFocun6KR04VVg
# 373         Bronx     3.0  fyVLkWQ5CP5q1yP8nnsj5g
# 388       Yonkers     4.0  P4iD0CGBWbLAErbWP9uIDQ
# 481      New York     4.0  2IrwjU67gguqLqQqZ1nFPg
# 521      New York     4.0  NebgteFykeM1gwiVgPcCHw
# ...

# %%
df = df.drop([118, 127, 213, 272, 481, 521, 580, 605, 645, 841, 888, 915, 921])

# %%
df.loc[df['review_count']>300]
# Out:
#              city  rating           restaurant_id  \
# 2           Bronx     4.0  P8PGGzxZeMm6Na5gYqvudw
# 3           Bronx     4.0  2f-qNpdVJl2h9L6SHYuICA
# 4           Bronx     4.5  b6jOwyX4iaagw8YjXqq1sA
# 6           Bronx     3.5  BiOgIv7Nj3oDrJTHiDt45g
# 8           Bronx     4.5  ZZxYVgodx2TxbYwh-0YU1w
# 9           Bronx     4.0  By2Zl1imtu0SpA4IBziN1g
# 14          Bronx     2.5  -5JwknVLIT36YTGhvkuBaw
# 16          Bronx     4.0  KAxYFGyOQ7ysCmYmh8jKtw
# 23          Bronx     4.0  eQdjZQaLnjItmn9suEEeIA
# 24          Bronx     4.0  D8z7FS2SB48zTjvch4bc0g
# 31          Bronx     3.0  Km_hSBftgdYcGL1TzZnwlQ
# 37          Bronx     3.5  oexDsgqmXc9Qe3fy3uYx7g
# 40          Bronx     4.0  tLZfepIfSf0a80zHQTbTGQ
# 41          Bronx     3.5  KNEDp6x3J6lSK-8HD-pGIQ
# 42          Bronx     3.5  _z52AlCKEU2Lc-CB1j6Kaw
# 48          Bronx     3.0  YmAPpKeMuly7IIjpYcFhHw
# 58          Bronx     4.0  3uyBZNbDk2vRFBBWZOdIUA
# 61          Bronx     4.0  C3spvfEd8JQJie-yixRgpQ
# ...

# %%
df = df.drop([153, 212, 306, 390, 400, 489, 637, 653, 721, 733, 737, 782, 884, 936, 956, 973, 995])

# %%
sns.distplot(df.rating)

# %%
sns.distplot(df.review_count)

# %%
sns.scatterplot(x=df.review_count, y=df.rating)

# %%
df.to_csv('cleanedBronxfull.csv')
