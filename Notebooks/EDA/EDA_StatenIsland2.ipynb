# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
pd.options.display.max_rows = 999
pd.options.display.max_columns = 999
# %matplotlib inline

# %%
df = pd.read_csv('statenislandfullreview.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 price  rating           restaurant_id  \
# 0           0   NaN     4.0  rcXD-hf7KTsY28ikeVJMuw
# 1           1    $$     4.0  qzxSdHp31nOFvrftOM3p2g
# 2           2    $$     4.0  CExfaNN6avB7U_JSRXK0Jw
# 3           3   NaN     4.0  1zdtxNVUsjkOI0pzXg0RKw
# 4           4   NaN     4.5  YOOZjCcC4s1MOBtFsaMB8w
#
#              restaurant_name  review_count  \
# 0             Thali Bar Baar            41
# 1  West Shore Inn Steakhouse           257
# 2       Tommy's Tavern + Tap           246
# 3           Lil M Bubble Tea             2
# 4               The Richmond            90
#
#                                             review_1  \
# 0  So usually me and my boyfriend order take out ...
# 1  Wow this place was straight up out of a movie....
# 2  Great bar space with plenty of games on.  Food...
# 3  Staten Island really needs to up their food sc...
# 4  Sam, the General Manager is amazing. When it c...
#
#                                             review_2  \
# ...

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df.head()
# Out:
#   price  rating           restaurant_id            restaurant_name  \
# 0   NaN     4.0  rcXD-hf7KTsY28ikeVJMuw             Thali Bar Baar
# 1    $$     4.0  qzxSdHp31nOFvrftOM3p2g  West Shore Inn Steakhouse
# 2    $$     4.0  CExfaNN6avB7U_JSRXK0Jw       Tommy's Tavern + Tap
# 3   NaN     4.0  1zdtxNVUsjkOI0pzXg0RKw           Lil M Bubble Tea
# 4   NaN     4.5  YOOZjCcC4s1MOBtFsaMB8w               The Richmond
#
#    review_count                                           review_1  \
# 0            41  So usually me and my boyfriend order take out ...
# 1           257  Wow this place was straight up out of a movie....
# 2           246  Great bar space with plenty of games on.  Food...
# 3             2  Staten Island really needs to up their food sc...
# 4            90  Sam, the General Manager is amazing. When it c...
#
#                                             review_2  \
# 0  Update on September 7 2019 - Stay away from th...
# ...

# %%
df.isnull().sum()
# Out:
# price              242
# rating               0
# restaurant_id        0
# restaurant_name      0
# review_count         0
# review_1             0
# review_2            50
# review_3            83
# review_4           113
# review_5           135
# review_6           154
# review_7           169
# review_8           190
# review_9           209
# review_10          219
# review_11          234
# review_12          250
# review_13          260
# review_14          274
# review_15          289
# review_16          300
# review_17          313
# review_18          317
# review_19          332
# review_20          348
# review_21          358
# review_22          367
# review_23          379
# review_24          391
# review_25          402
# review_26          410
# review_27          420
# review_28          430
# review_29          434
# review_30          449
# review_31          461
# review_32          469
# review_33          474
# review_34          479
# review_35          481
# ...

# %%
df = df.dropna(thresh=df.shape[1]-120)

# %%
df.isnull().sum()
# Out:
# price               18
# rating               0
# restaurant_id        0
# restaurant_name      0
# review_count         0
# review_1             0
# review_2             0
# review_3             0
# review_4             0
# review_5             0
# review_6             0
# review_7             0
# review_8             0
# review_9             0
# review_10            0
# review_11            0
# review_12            0
# review_13            0
# review_14            0
# review_15            0
# review_16            0
# review_17            0
# review_18            0
# review_19            0
# review_20            0
# review_21            0
# review_22            0
# review_23            0
# review_24            0
# review_25            0
# review_26            0
# review_27            0
# review_28            0
# review_29            0
# review_30           11
# review_31           23
# review_32           31
# review_33           36
# review_34           41
# review_35           43
# ...

# %%
df.head(25)
# Out:
#    price  rating           restaurant_id  \
# 0    NaN     4.0  rcXD-hf7KTsY28ikeVJMuw
# 1     $$     4.0  qzxSdHp31nOFvrftOM3p2g
# 2     $$     4.0  CExfaNN6avB7U_JSRXK0Jw
# 4    NaN     4.5  YOOZjCcC4s1MOBtFsaMB8w
# 5    $$$     4.5  HK4mjpUdZ6xrw3OrsBV8zA
# 6     $$     4.0  s63N2t9IwXIABlVXR26CWg
# 7    $$$     4.0  AbkiG5m3JAkaPyapAeuZLw
# 8    NaN     4.5  ShQz0wFmdLkFcqI_sb6oBA
# 9     $$     3.5  gEmAC20Mifdsa_5IoXsyrA
# 10    $$     3.5  GvXRLqZKw6vC8zBCDXnyhQ
# 11    $$     4.5  hSfJ5n_jAduyLV2uxPcEaQ
# 12    $$     4.0  x_ojll0Ik-UPyXnSkgFBPQ
# 13    $$     4.5  UuiW2A-O11Q0baqSEUMvZA
# 14    $$     4.0  d_4dmneuGuJES1ikgQWJHA
# 15    $$     4.0  3jivt3RU-HlUZfk6I2kaqw
# 16    $$     4.0  oXkCGBRjP-qERDlEgPlwxQ
# 17   NaN     3.5  Nk2BdPhLB8WriGnFoaNG3Q
# 19    $$     4.5  hOuETUkoGbMDyA4w9fmdmg
# 21   NaN     4.5  MIHDANEJyqStu3CrbDHQcA
# 22    $$     3.5  Fyzulvq2QNhoaPnNfGvGGQ
# 23    $$     4.0  JTdkzPMNPVN4shyW7v768A
# 24    $$     4.0  4iKGVhy9NxbtNSfXNsT2Vg
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 562 entries, 0 to 998
# Columns: 154 entries, price to review_149
# dtypes: float64(1), int64(1), object(152)
# memory usage: 680.5+ KB

# %%
len(df)
# Out:
# 562

# %%
sns.distplot(df.rating)

# %%
sns.distplot(df.review_count)

# %%
df.review_count.value_counts()
# Out:
# 29      12
# 51      10
# 40      10
# 67      10
# 37       9
# 36       9
# 49       8
# 58       8
# 41       8
# 35       8
# 34       8
# 70       8
# 28       8
# 140      8
# 33       7
# 30       7
# 72       7
# 55       7
# 75       7
# 68       6
# 66       6
# 87       6
# 52       6
# 128      6
# 45       6
# 46       5
# 63       5
# 65       5
# 39       5
# 42       5
# 57       5
# 56       5
# 38       5
# 32       5
# 44       5
# 97       5
# 130      5
# 77       5
# 104      4
# 123      4
# 84       4
# 83       4
# 126      4
# 61       4
# 110      4
# 31       4
# 43       4
# 54       4
# 102      4
# 50       4
# 47       4
# 82       3
# 170      3
# 172      3
# 163      3
# 118      3
# 120      3
# 81       3
# 121      3
# 148      3
# 86       3
# 144      3
# 143      3
# 90       3
# 89       3
# 131      3
# 179      3
# 27       3
# 69       3
# 201      3
# 48       3
# 53       3
# 246      3
# 59       3
# 60       3
# 62       3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 563 entries, 0 to 997
# Columns: 154 entries, price to review_149
# dtypes: float64(1), int64(1), object(152)
# memory usage: 681.8+ KB

# %%
df = df.drop([180, 291, 318, 385, 441, 500, 504, 537, 550, 560, 642, 648, 660, 690, 755, 778, 988])

# %%
df.loc[df['review_count']>1000]
# Out:
#    price  rating           restaurant_id restaurant_name  review_count  \
# 62    $$     4.5  5boVu1QAQ-6VlnjfqeNdXg   Urban Griddle          1030
#
#                                              review_1  \
# 62  This place was soo good ! I came here because ...
#
#                                              review_2  \
# 62  First of all... PARKING SUCKS! You are going t...
#
#                                              review_3  \
# 62  The line for this place is LONG. The interior ...
#
#                                              review_4  \
# 62  Omg omg best stop in New Jersey!! I had the mo...
#
#                                              review_5  \
# 62  This place is memorable. The food is unique an...
#
#                                              review_6  \
# 62  AMAZING!!!!! Let me say that this place is a r...
#
#                                              review_7  \
# 62  I love breakfast. Favorite meal of the day and...
#
# ...

# %%
df = df.drop([62])

# %%
df.loc[df['review_count']>600]
# Out:
#    price  rating           restaurant_id           restaurant_name  \
# 15    $$     4.0  3jivt3RU-HlUZfk6I2kaqw        Valenca Restaurant
# 29    $$     4.0  GXq2Qsm--A7QQt9rTXldig  Denino's Pizzeria Tavern
#
#     review_count                                           review_1  \
# 15           871  Fantastic restaurant...Dined here with some co...
# 29           696  Old fashioned thin pizza pie, typical for Stat...
#
#                                              review_2  \
# 15  Came here to meet up with some friends. The re...
# 29  It is always great going out to dinner with gr...
#
#                                              review_3  \
# 15  how does this place get these reviews?  Oh, I ...
# 29  It's Deninos. It's world famous pizza. What el...
#
#                                              review_4  \
# 15  Phenomenal restaurant.  Our dishes were wonder...
# 29  Favorite pizza in SI! Actually in NYC period.E...
#
# ...

# %%
df = df.drop([15])

# %%
df.loc[df['review_count']>300]
# Out:
#     price  rating           restaurant_id  \
# 13     $$     4.5  UuiW2A-O11Q0baqSEUMvZA
# 19     $$     4.5  hOuETUkoGbMDyA4w9fmdmg
# 28     $$     4.0  76B7-T4f1EdsQsoI0NM9Wg
# 29     $$     4.0  GXq2Qsm--A7QQt9rTXldig
# 33    $$$     4.0  dmCqbWwTFHqri_6fr3KlNw
# 35    $$$     4.5  0O0DV4tKQkp2lS2wGcg_7A
# 36     $$     3.0  WgWRpL8dyTLA1fBaxzvZ6A
# 42     $$     4.5  U0HmnNv1wJL-dANj_Dq71A
# 46     $$     4.0  z-y9GDoRr1S9Ma6b2n0A4A
# 51     $$     3.5  pjTkv5MBIPnakUGuFddPvg
# 52     $$     4.0  hmndKMvCwTzXSAPp4KmGYg
# 104    $$     4.0  LlT5XLc88hFDcWiCKskasg
# 137    $$     3.5  J4QgBN-byWn3VpjOAY5XxQ
# 181    $$     4.0  na6Xd6dSmKNVC4lsPf1Y9w
# 259    $$     3.0  J6m_-e_CKheyeYUQ1Rh1Vg
# 276    $$     4.0  S9sc-6uSsplyU073_4waTQ
# 386    $$     4.0  qh3wMLiOuFGcZqvy2QRVJQ
# 576    $$     4.0  ENRFu6Py1D4yhZMbu-TN9A
# 722     $     4.5  UytOpeDV0-5wIHhi987WgA
# 775    $$     3.5  sWW6wCXcL0ATT8w6HhBpow
#
#                             restaurant_name  review_count  \
# ...

# %%
df = df.drop([181,259,386,576])

# %%
df.loc[df['review_count']>200]
# Out:
#     price  rating           restaurant_id  \
# 1      $$     4.0  qzxSdHp31nOFvrftOM3p2g
# 2      $$     4.0  CExfaNN6avB7U_JSRXK0Jw
# 6      $$     4.0  s63N2t9IwXIABlVXR26CWg
# 7     $$$     4.0  AbkiG5m3JAkaPyapAeuZLw
# 10     $$     3.5  GvXRLqZKw6vC8zBCDXnyhQ
# 12     $$     4.0  x_ojll0Ik-UPyXnSkgFBPQ
# 13     $$     4.5  UuiW2A-O11Q0baqSEUMvZA
# 14     $$     4.0  d_4dmneuGuJES1ikgQWJHA
# 19     $$     4.5  hOuETUkoGbMDyA4w9fmdmg
# 28     $$     4.0  76B7-T4f1EdsQsoI0NM9Wg
# 29     $$     4.0  GXq2Qsm--A7QQt9rTXldig
# 30     $$     4.0  Dci3yvrnPZ5kOF5t3xV8gg
# 32    $$$     4.0  _4ztTCCumLK79ZJkNqL3ZQ
# 33    $$$     4.0  dmCqbWwTFHqri_6fr3KlNw
# 34     $$     4.0  -BmS1FH3DSK6fSifIt8GgQ
# 35    $$$     4.5  0O0DV4tKQkp2lS2wGcg_7A
# 36     $$     3.0  WgWRpL8dyTLA1fBaxzvZ6A
# 42     $$     4.5  U0HmnNv1wJL-dANj_Dq71A
# 46     $$     4.0  z-y9GDoRr1S9Ma6b2n0A4A
# 49     $$     4.5  7YJxZAvMxB-oVZfHAuvBmw
# 51     $$     3.5  pjTkv5MBIPnakUGuFddPvg
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 556 entries, 0 to 998
# Columns: 154 entries, price to review_149
# dtypes: float64(1), int64(1), object(152)
# memory usage: 673.3+ KB

# %%
df = df.reset_index()

# %%
df.head()

# %%
df = df.drop(columns=['index'])

# %%
df.head()

# %%
sns.distplot(df.rating)

# %%
sns.distplot(df.review_count)

# %%
sns.scatterplot(x=df.review_count, y=df.rating)

# %%
df.to_csv('cleanedStatenIslandfull.csv')
