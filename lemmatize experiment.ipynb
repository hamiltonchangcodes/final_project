# %%
from nltk.stem import WordNetLemmatizer 
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk import punkt
tokenizer = word_tokenize
from nltk.corpus import stopwords
stop = set(stopwords.words('english'))

# %%
tokenizer = word_tokenize

# %%
lemmatizer = WordNetLemmatizer()

# %%
lemmatizer.lemmatize('service', pos='v')
# Out:
# 'service'

# %%
df = pd.read_csv('reviews_manhattan.csv')

# %%
df1 = df[df['Review'].str.contains('service')]

# %%
df1.drop(columns=['Unnamed: 0', 'Restaurant_Id'], axis=1, inplace=True)
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
df1['token_Review']= df1['Review'].apply(tokenizer)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df1.drop(columns=['Review'], axis=1, inplace=True)

# %%
tokenslist = df1.values.tolist()

# %%
temp = []
for row in tokenslist:
    if type(row) == list:
        temp.extend(row)

# %%
temp[0].count('service')
# Out:
# 1

# %%
for x in len(temp):
    x.count('service')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-82f27b09f5ff> in <module>
# ----> 1 for x in len(temp):
#       2     x.count('service')
#
# TypeError: 'int' object is not iterable

# %%
df = pd.read_csv('reviews_manhattan.csv')

# %%
import string 
def remove_punctuations(text):
    for punctuation in string.punctuation:
        text = text.replace(punctuation, '')
    return text

# %%
df1 = df[df['Review'].str.contains('service')]

# %%
df1 = df1.fillna(value=str('none'))

# %%
df1['Review'] = df1['Review'].apply(remove_punctuations)

# %%
df1['Review'] = df1['Review'].apply(lambda x: ' '.join([word.lower() for word in x.split() if word.lower() not in (stop)]))

# %%
df1['Review'] = df1['Review'].apply(lambda x: ' '.join([lemmatizer.lemmatize(word, pos = 'v') for word in x.split()]))

# %%
df1.drop(columns=['Unnamed: 0', 'Restaurant_Id'], axis=1, inplace=True)

# %%
df1['token_Review']= df1['Review'].apply(tokenizer)

# %%
df1.drop(columns=['Review'], axis=1, inplace=True)

# %%
tokenslist = df1.values.tolist()

# %%
temp = []
for row in tokenslist:
    if type(row) == list:
        temp.extend(row)

# %%
temp
# Out:
# [['mehhhhh',
#   'overrate',
#   'opinionwe',
#   'walk',
#   'reservation',
#   'prob',
#   'shouldnt',
#   'give',
#   'hype',
#   'surround',
#   'place',
#   'lucky',
#   'enough',
#   'get',
#   'table',
#   'give',
#   'time',
#   'limit',
#   'long',
#   'could',
#   'stay',
#   'big',
#   'deal',
#   'oyster',
#   'fresh',
#   'delicious',
#   'service',
#   'standard',
#   'waiter',
#   'knowledgeable',
#   'overall',
#   'unmemorable',
#   'mediocre',
#   'din',
#   'experiencemaybe',
#   'miss',
#   'something'],
#  ['hear',
#   'tons',
#   'people',
#   'rave',
#   'spot',
#   'ive',
#   'finally',
#   'decide',
#   'give',
#   'try',
#   'ive',
#   'actually',
#   'back',
#   'second',
#   'time',
#   'definitely',
#   'put',
#   'restaurant',
#   'bring',
#   'people',
#   'youd',
#   'like',
#   'impress',
#   'list',
#   'personally',
#   'dont',
#   'eat',
#   'oyster',
#   'know',
#   'please',
#   'dont',
#   'stone',
#   'nonetheless',
#   'great',
#   'freak',
#   'deal',
#   'happy',
#   'hours',
#   'additionally',
#   'someone',
#   'doesnt',
#   'actually',
#   'like',
#   'seafood',
#   'seafood',
#   'generally',
#   'get',
#   'thumb',
#   'octopus',
#   'great',
#   'flavorful',
#   'soft',
#   'id',
#   'pass',
#   'escargot',
#   'though',
#   'wasnt',
#   'special',
#   'risotto',
#   'fettuccine',
#   'amaze',
#   'scallop',
#   'dry',
#   'flavorful',
#   'clam',
#   'creamy',
#   'also',
#   'fresh',
#   'however',
#   'id',
#   'recommend',
#   'eat',
#   'dish',
#   'soon',
#   'possible',
#   'wouldnt',
#   'good',
#   'theyre',
#   'cold',
#   'reason',
#   'star',
#   'space',
#   'teeny',
#   'tiny',
#   'wait',
#   'tune',
#   'always',
#   'long',
#   'since',
#   'busy',
#   'spot',
#   'service',
#   'also',
#   'affect',
#   'term',
#   'efficiency',
#   'quality',
#   'dont',
#   'mind',
#   'much',
#   'please',
#   'make',
#   'reservation',
#   'enjoy'],
#  ['quick',
#   'recap',
#   'come',
#   'like',
#   'seafood',
#   'food',
#   'general',
#   'awesome',
#   'atmosphere',
#   'wonderful',
#   'service',
#   'delicious',
#   'food',
#   'biggest',
#   'restaurant',
#   'expect',
#   'wait',
#   'make',
#   'reservation',
#   'peak',
#   'hours',
#   'come',
#   'grab',
#   'quick',
#   'bite',
#   'healthier',
#   'food',
#   'come',
#   'pleasantly',
#   'surprise',
#   'get',
#   'sear',
#   'tuna',
#   'green',
#   'mash',
#   'potatoes',
#   'heaven',
#   'get',
#   'near',
#   'end',
#   'day',
#   'bartender',
#   'make',
#   'us',
#   'great',
#   'drink',
#   'let',
#   'us',
#   'sample',
#   'oyster',
#   'top',
#   'already',
#   'order',
#   'phenomenal',
#   'recommend',
#   'place',
#   'enough',
#   'great',
#   'ambiance',
#   'amaze',
#   'food',
#   'top',
#   'notch',
#   'service'],
#  ['great',
#   'spot',
#   'oyster',
#   'relax',
#   'vibe',
#   'good',
#   'drink',
#   'work',
#   'also',
#   'date',
#   'good',
#   'service',
#   'fresh',
#   'oyster'],
#  ['disappoint',
#   'upstate',
#   'list',
#   'awhile',
#   'finally',
#   'get',
#   'date',
#   'night',
#   'even',
#   'expectations',
#   'high',
#   'start',
#   'perfect',
#   'dinner',
#   'perfect',
#   'choice',
#   'restaurants',
#   'slowly',
#   'fizzle',
#   'major',
#   'disappointmentlets',
#   'get',
#   'thing',
#   'really',
#   'like',
#   'first',
#   'oyster',
#   'thats',
#   'put',
#   'upstate',
#   'must',
#   'try',
#   'date',
#   'night',
#   'radar',
#   'im',
#   'bite',
#   'obsess',
#   'oyster',
#   'order',
#   'dozen',
#   'six',
#   'happy',
#   'hour',
#   'options',
#   'six',
#   'waiters',
#   'recommendations',
#   'good',
#   'expect',
#   'something',
#   'bite',
#   'sensational',
#   'seem',
#   'better',
#   'something',
#   'id',
#   'race',
#   'back',
#   'didnt',
#   'even',
#   'keep',
#   'list',
#   'ones',
#   'less',
#   'enthuse',
#   'like',
#   'cull',
#   'pistol',
#   'crave',
#   'even',
#   'good',
#   'night',
#   'sonny',
#   'nearby',
#   'place',
#   'score',
#   'much',
#   'higher',
#   'even',
#   'happy',
#   'hourthe',
#   'ambience',
#   'pretty',
#   'cool',
#   'definitely',
#   'wasnt',
#   'expect',
#   'thats',
#   'good',
#   'thing',
#   'give',
#   'minimalist',
#   'site',
#   'design',
#   'upscale',
#   'look',
#   'menu',
#   'expect',
#   'something',
#   'fit',
#   'look',
#   'delightful',
#   'surprise',
#   'find',
#   'neighborhood',
#   'hole',
#   'wall',
#   'serve',
#   'extremely',
#   'fresh',
#   'dont',
#   'freezer',
#   'store',
#   'things',
#   'food',
#   'serve',
#   'fresh',
#   'day',
#   'extremely',
#   'upscale',
#   'offer',
#   'extremely',
#   'reasonable',
#   'price',
#   'starters',
#   'go',
#   'tuna',
#   'tartar',
#   'deliciousbut',
#   'thats',
#   'things',
#   'start',
#   'go',
#   'astray',
#   'start',
#   'great',
#   'service',
#   'quickly',
#   'become',
#   'blah',
#   'service',
#   'bad',
#   'good',
#   'blah',
#   'could',
#   'tell',
#   'hes',
#   'awhile',
#   'like',
#   'go',
#   'motionsi',
#   'order',
#   'octopus',
#   'hubby',
#   'order',
#   'bone',
#   'marrow',
#   'scallopsthe',
#   'octopus',
#   'cook',
#   'burn',
#   'theres',
#   'char',
#   'flavor',
#   'char',
#   'like',
#   'remnants',
#   'burn',
#   'build',
#   'inedible',
#   'jayson',
#   'want',
#   'send',
#   'back',
#   'didnt',
#   'want',
#   'go',
#   'longer',
#   'necessary',
#   'love',
#   'octopus',
#   'hat',
#   'couldnt',
#   'even',
#   'eat',
#   'itthe',
#   'bone',
#   'marrow',
#   'omg',
#   'delicious',
#   'im',
#   'pretty',
#   'sure',
#   'new',
#   'obsessionthe',
#   'scallop',
#   'though',
#   'eh',
#   'jayson',
#   'love',
#   'scallop',
#   'excite',
#   'go',
#   'somewhere',
#   'fresh',
#   'ones',
#   'lacklusterin',
#   'okay',
#   'meal',
#   'realize',
#   'spend',
#   '100',
#   'food',
#   'either',
#   'blah',
#   'edible',
#   'dont',
#   'see',
#   'race',
#   'back',
#   'anytime',
#   'soon'],
#  ['oh',
#   'goodness',
#   'even',
#   'start',
#   'boyfriend',
#   'eat',
#   'first',
#   'time',
#   'tonight',
#   'immensely',
#   'satisfy',
#   'everything',
#   'start',
#   'service',
#   'incredible',
#   'efficient',
#   'overall',
#   'atmosphere',
#   'warm',
#   'relax',
#   'start',
#   'crab',
#   'cake',
#   'fresh',
#   'flavorful',
#   'beautiful',
#   'bed',
#   'mix',
#   'green',
#   'carrots',
#   'corn',
#   'fresh',
#   'tomatoes',
#   'also',
#   'enjoy',
#   'bone',
#   'marrow',
#   'delicious',
#   'smear',
#   'toast',
#   'bread',
#   'point',
#   'sear',
#   'scallop',
#   'cauliflower',
#   'purée',
#   'overall',
#   'blend',
#   'flavor',
#   'compliment',
#   'every',
#   'bite',
#   'lastly',
#   'share',
#   'surf',
#   'turf',
#   'steak',
#   'perfect',
#   'medium',
#   'rare',
#   'melt',
#   'mouth',
#   'potatoes',
#   'crispy',
#   'yet',
#   'soft',
#   'shrimp',
#   'fresh',
#   'full',
#   'wonderful',
#   'flavor',
#   'server',
#   'even',
#   'bring',
#   'us',
#   'whiskey',
#   'cake',
#   'house',
#   'light',
#   'moist',
#   'sweet',
#   'definitely',
#   'back',
#   'recommend',
#   'spot',
#   'againthanks',
#   'phenomenal',
#   'food',
#   'experience'],
#  ['okay',
#   'upstate',
#   'need',
#   'review',
#   'know',
#   'everyone',
#   'know',
#   'get',
#   'rave',
#   'review',
#   'service',
#   'always',
#   'point',
#   'staff',
#   'give',
#   'great',
#   'advice',
#   'oyster',
#   'always',
#   'fresh',
#   'revolve',
#   'selection',
#   'beer',
#   'always',
#   'keep',
#   'things',
#   'interest',
#   'later',
#   'youre',
#   'still',
#   'hungry',
#   'gauntlet',
#   'oyster',
#   'order',
#   'regular',
#   'menu',
#   'make',
#   'sure',
#   'make',
#   'reservation',
#   'though',
#   'unless',
#   'youre',
#   'alone',
#   'place',
#   'always',
#   'crowd'],
#  ['maybe',
#   'friday',
#   '13th',
#   'maybe',
#   'full',
#   'moon',
#   'service',
#   'downright',
#   'rude',
#   'bark',
#   'order',
#   'fill',
#   'piece',
#   'paper',
#   'oyster',
#   'give',
#   'break',
#   'pencil',
#   'doesnt',
#   'even',
#   'write',
#   'try',
#   'get',
#   'waiters',
#   'attention',
#   'right',
#   'ignore',
#   'us',
#   'maybe',
#   'something',
#   'asians',
#   'sure',
#   'felt',
#   'pretty',
#   'discriminate',
#   'especially',
#   'since',
#   'hospitable',
#   'caucasian',
#   'guests',
#   'curtly',
#   'talk',
#   'us',
#   'would',
#   'give',
#   'place',
#   '5',
#   'star',
#   'rude',
#   'service',
#   'put',
#   'really',
#   'bad',
#   'taste',
#   'mouth',
#   'dont',
#   'need',
#   'spend',
#   'money',
#   'racist',
#   'unprofessional',
#   'establishments',
#   'oh',
#   'thank',
#   'sir',
#   'unpleasant',
#   'experience'],
#  ['date',
#   'nighttime',
#   'surprise',
#   'queen',
#   'new',
#   'spot',
#   'new',
#   'experience',
#   'keep',
#   'adventure',
#   'goingupstate',
#   'wasnt',
#   'first',
#   'choice',
#   'like',
#   '4th',
#   'something',
#   'tell',
#   'would',
#   'oneand',
#   'without',
#   'doubt',
#   'waswhile',
#   'head',
#   'manhattan',
#   'check',
#   'wait',
#   'time',
#   'via',
#   'yelp',
#   'didnt',
#   'seem',
#   'bad',
#   'get',
#   'got',
#   'ta',
#   'get',
#   'spot',
#   'well',
#   'probably',
#   'grab',
#   'drink',
#   'wait',
#   'table',
#   'logic',
#   'completely',
#   'forget',
#   'saturday',
#   'night',
#   'lolscooped',
#   'work',
#   'hop',
#   'cab',
#   'follow',
#   'checkin',
#   'confirmation',
#   'upstate',
#   'hmm',
#   'didnt',
#   'respond',
#   'think',
#   'get',
#   'closer',
#   'closer',
#   'closer',
#   'sht',
#   'go',
#   'get',
#   'turn',
#   'away',
#   'door',
#   'crap',
#   'fix',
#   'keep',
#   'things',
#   'calm',
#   'spoil',
#   'night',
#   'mom',
#   'teach',
#   'follow',
#   'already',
#   'enroute',
#   'turn',
#   'back',
#   'get',
#   'theres',
#   'crowd',
#   '7',
#   'people',
#   'wait',
#   'outside',
#   'cold',
#   'werent',
#   'see',
#   'walk',
#   'past',
#   'inform',
#   'maître',
#   'reservation',
#   'didnt',
#   'give',
#   'promise',
#   'response',
#   'back',
#   'stance',
#   'conviction',
#   'get',
#   'turn',
#   'away',
#   'say',
#   'check',
#   'back',
#   '30mins',
#   'return',
#   '27',
#   'guess',
#   'get',
#   'two',
#   'seat',
#   'bar',
#   'dfinally',
#   'seat',
#   'pack',
#   'warm',
#   'little',
#   'restaurant',
#   'begin',
#   'peruse',
#   'menuat',
#   'least',
#   'begin',
#   'already',
#   'know',
#   'want',
#   'swordfish',
#   'john',
#   'luke',
#   'gentlemans',
#   'name',
#   'service',
#   'forte',
#   'give',
#   'us',
#   'rundown',
#   'happy',
#   'hour',
#   'oyster',
#   'make',
#   'time',
#   'well',
#   'menu',
#   'suggestions',
#   'pair',
#   'beer',
#   'wine',
#   'serve',
#   'queen',
#   'begin',
#   'red',
#   'plan',
#   'finish',
#   'white',
#   'go',
#   'ipa',
#   'route',
#   'turn',
#   'wise',
#   'choices',
#   'appetizer',
#   'amazingly',
#   'delicioushouse',
#   'curse',
#   'salmon',
#   'lightly',
#   'cover',
#   'onions',
#   'caper',
#   'side',
#   'sweet',
#   'whole',
#   'grain',
#   'mustard',
#   'traditional',
#   'baguette',
#   'combination',
#   'genius',
#   'great',
#   'start',
#   'come',
#   'next',
#   'john',
#   'luke',
#   'keep',
#   'offer',
#   'oyster',
#   'keep',
#   'decline',
#   'think',
#   'try',
#   'upsell',
#   'case',
#   'keep',
#   'readingour',
#   'entrees',
#   'come',
#   'first',
#   'thing',
#   'hit',
#   'heavenly',
#   'smellmind',
#   'already',
#   'tell',
#   'john',
#   'dairy',
#   'opt',
#   'substitutions',
#   'meal',
#   'grill',
#   'swordfish',
#   'come',
#   'creamy',
#   'mash',
#   'potatoes',
#   'ask',
#   'grill',
#   'extra',
#   'taters',
#   'mix',
#   'veggies',
#   'work',
#   'look',
#   'beautiful',
#   'swordfish',
#   'well',
#   'season',
#   'cook',
#   'perfectly',
#   'go',
#   'exceptionally',
#   'well',
#   'grill',
#   'potatoes',
#   'touch',
#   'lemon',
#   'juice',
#   'queen',
#   'get',
#   'grill',
#   'tuna',
#   'immediately',
#   'jealous',
#   'look',
#   'delicious',
#   'cut',
#   'tender',
#   'fish',
#   'melt',
#   'knife',
#   'give',
#   'gleeful',
#   'smile',
#   'devour',
#   'lolthats',
#   'get',
#   'youre',
#   'foodiewithafro',
#   'dinner',
#   'yes',
#   'say',
#   'accept',
#   'johns',
#   'offer',
#   'try',
#   'oysterswe',
#   'go',
#   'suggestion',
#   'blue',
#   'island',
#   '9',
#   'gildden',
#   'point',
#   'blue',
#   'whale',
#   '2',
#   'eachthe',
#   'setup',
#   'impressive',
#   'blue',
#   'whale',
#   'meals',
#   'within',
#   'ideally',
#   'id',
#   'say',
#   '6',
#   'would',
#   'great',
#   'starter',
#   'one',
#   'person',
#   'plan',
#   'entree',
#   'afterwards',
#   'otherwise',
#   'get',
#   '12',
#   'dozen',
#   'baby',
#   'anything',
#   'except',
#   'whaleget',
#   'less',
#   'whale',
#   'lol',
#   'would',
#   'enough',
#   'get',
#   'someone',
#   'night',
#   'drink',
#   'two',
#   'foolishly',
#   'devour',
#   'share',
#   'carefully',
#   'decorate',
#   'ultimate',
#   'flavoragain',
#   'jealous',
#   'lol',
#   'cant',
#   'forget',
#   'add',
#   'complimentary',
#   'slice',
#   'whiskey',
#   'cake',
#   'receive',
#   'afterwards',
#   'delishafter',
#   'meals',
#   'go',
#   'tummies',
#   'happy',
#   'sit',
#   'order',
#   'drink',
#   'road',
#   'glance',
#   'around',
#   'notice',
#   'everyone',
#   'enjoy',
#   'experience',
#   'either',
#   'mean',
#   'conversation',
#   'drink',
#   'food',
#   'place',
#   'give',
#   'general',
#   'sense',
#   'calm',
#   'welcome',
#   'turn',
#   'another',
#   'amaze',
#   'date',
#   'night',
#   'course',
#   'add',
#   'list',
#   'release',
#   'yelp',
#   'public',
#   'soon',
#   'food',
#   '55service',
#   '55ambiance',
#   '55wait',
#   'time',
#   '455',
#   'utilize',
#   'online',
#   'book',
#   'plzstaff',
#   '55',
#   'helpfultalking',
#   'johnprice',
#   '55freshness',
#   'oyster',
#   '55cash',
#   'credit',
#   'happily',
#   'accept',
#   'herewait',
#   'wait',
#   'waitalmost',
#   'forget',
#   'tune',
#   'yo',
#   'john',
#   'music',
#   'choice',
#   'us',
#   'vibin',
#   'bar',
#   'thank'],
#  ['ohhh',
#   'update',
#   'minus',
#   '2',
#   'star',
#   'get',
#   'b',
#   'health',
#   'scorereally',
#   'nice',
#   'service',
#   'give',
#   'taste',
#   'beer',
#   'without',
#   'ask',
#   'really',
#   'nice',
#   'brew',
#   'good',
#   'quality',
#   'variety',
#   'decent',
#   'price',
#   'quality',
#   'portion',
#   'good',
#   'spot',
#   'seafood',
#   'andor',
#   'beers',
#   'good',
#   'man',
#   'john',
#   'bar'],
#  ['really',
#   'nice',
#   'service',
#   'give',
#   'taste',
#   'beer',
#   'without',
#   'ask',
#   'really',
#   'nice',
#   'brew',
#   'good',
#   'quality',
#   'variety',
#   'decent',
#   'price',
#   'quality',
#   'portion',
#   'good',
#   'spot',
#   'seafood',
#   'andor',
#   'beers',
#   'good',
#   'man',
#   'john',
#   'bar'],
#  ['place',
#   'spectacular',
#   'every',
#   'way',
#   'seafood',
#   'lovers',
#   'food',
#   'delicious',
#   'perfectly',
#   'portion',
#   'price',
#   'fair',
#   'environment',
#   'really',
#   'cool',
#   'well',
#   'nice',
#   'date',
#   'great',
#   'happy',
#   'hour',
#   'special',
#   'oyster',
#   'drink',
#   '12',
#   'probably',
#   'mention',
#   'near',
#   'every',
#   'reviewi',
#   'opportunity',
#   'try',
#   'dish',
#   'superb',
#   'first',
#   'naturally',
#   'start',
#   'happy',
#   'hour',
#   'special',
#   'order',
#   'dozen',
#   'oyster',
#   'get',
#   'kind',
#   'available',
#   'happy',
#   'hour',
#   'fresh',
#   'tasty',
#   'one',
#   'disappoint',
#   'get',
#   'marlin',
#   'crudo',
#   'appetizer',
#   'pack',
#   'flavor',
#   'creme',
#   'fraiche',
#   'perfect',
#   'tasty',
#   'counter',
#   'balance',
#   'seem',
#   'soy',
#   'base',
#   'marinade',
#   'good',
#   'another',
#   'fish',
#   'appetizer',
#   'well',
#   'also',
#   'really',
#   'good',
#   'main',
#   'dish',
#   'perfectly',
#   'cook',
#   'octopus',
#   'bed',
#   'risotto',
#   'truffle',
#   'oil',
#   'amaze',
#   'person',
#   'fish',
#   'special',
#   'day',
#   'really',
#   'enjoy',
#   'wellthe',
#   'service',
#   'staff',
#   'also',
#   'spectacular',
#   'particular',
#   'john',
#   'work',
#   'bar',
#   'seatedthis',
#   'easily',
#   'go',
#   'seafood',
#   'joint'],
#  ['want',
#   'love',
#   'everything',
#   'place',
#   'didntprosfriendly',
#   'servicecute',
#   'interior',
#   'atmosphere',
#   'although',
#   'darkgreat',
#   'drink',
#   'selection',
#   'vinho',
#   'verdo',
#   'portuguese',
#   'white',
#   'wine',
#   'easy',
#   'come',
#   'byconsfood',
#   'okay',
#   'mushroomrice',
#   'dish',
#   'really',
#   'didnt',
#   'much',
#   'flavoura',
#   'little',
#   'pricey',
#   'portion',
#   'size',
#   'qualityworth',
#   'try',
#   'youre',
#   'area',
#   'dont',
#   'go',
#   'way'],
#  ['even',
#   'remotely',
#   'like',
#   'seafood',
#   'manhattan',
#   'close',
#   'enough',
#   'get',
#   'place',
#   'favor',
#   'get',
#   'upstate',
#   'food',
#   'amaze',
#   'service',
#   'match',
#   'enough',
#   'price',
#   'reasonable',
#   'think',
#   'back',
#   'midwest',
#   'nyc',
#   'get',
#   'bill',
#   'honestly',
#   'cant',
#   'say',
#   'enough',
#   'good',
#   'things',
#   'upstate'],
#  ['omg',
#   'oyster',
#   'fresh',
#   'delicious',
#   'also',
#   'gnocchi',
#   'tuna',
#   'tartare',
#   'yum',
#   'tiny',
#   'place',
#   'get',
#   'early',
#   'make',
#   'reservation',
#   'hh',
#   'good',
#   'deal',
#   'service',
#   'excellent'],
#  ['even',
#   'though',
#   'everything',
#   'salt',
#   'im',
#   'still',
#   'give',
#   '5',
#   'star',
#   'seafood',
#   'amazingsmall',
#   'space',
#   'im',
#   'assume',
#   'usually',
#   'pack',
#   'dont',
#   'take',
#   'reservations',
#   'get',
#   'early',
#   'lucky',
#   'find',
#   'seat',
#   'bar',
#   'crab',
#   'cake',
#   'delicious',
#   'kind',
#   'crab',
#   'cake',
#   'nice',
#   'shred',
#   'crab',
#   'cake',
#   'meat',
#   'fillers',
#   'follow',
#   'scallop',
#   'mushroom',
#   'risotto',
#   'scallop',
#   'totally',
#   'salt',
#   'otherwise',
#   'well',
#   'cook',
#   'mushroom',
#   'risotto',
#   'one',
#   'best',
#   'ive',
#   'ever',
#   'pale',
#   'ale',
#   'light',
#   'refresh',
#   'order',
#   'monk',
#   'fish',
#   'go',
#   'enjoy',
#   'next',
#   'day',
#   'great',
#   'flaky',
#   'fish',
#   'well',
#   'cook',
#   'would',
#   'perfect',
#   'like',
#   'scallop',
#   'excessively',
#   'salt',
#   'friendly',
#   'service',
#   'bar',
#   'ill',
#   'back'],
#  ['food',
#   'oyster',
#   '55',
#   'shuck',
#   'perfectly',
#   'stray',
#   'shell',
#   'strange',
#   'fishy',
#   'taste',
#   'get',
#   'mix',
#   'west',
#   'east',
#   'coast',
#   'oyster',
#   'thoroughly',
#   'enjoy',
#   'quite',
#   'local',
#   'oyster',
#   'long',
#   'island',
#   'menu',
#   'unique',
#   'oyster',
#   'bar',
#   'small',
#   'plat',
#   'order',
#   'scallop',
#   'w',
#   'mushroom',
#   'risotto',
#   'shrimp',
#   'sea',
#   'urchin',
#   'butter',
#   'crab',
#   'cake',
#   'underwhelming',
#   '35the',
#   'drink',
#   '55',
#   'excellent',
#   'selection',
#   'wine',
#   'beer',
#   'bartender',
#   'introduce',
#   'us',
#   'grüner',
#   'veltliner',
#   'dry',
#   'white',
#   'wine',
#   'austria',
#   'delicious',
#   'alternative',
#   'sauvignon',
#   'blancthe',
#   'service',
#   '55',
#   'service',
#   'amaze',
#   'bartender',
#   'shane',
#   'attentive',
#   'knowledgeable',
#   'wine',
#   'oyster',
#   'staff',
#   'members',
#   'friendly',
#   'wellupstate',
#   'chill',
#   'intimate',
#   'place',
#   'great',
#   'casual',
#   'date',
#   'night',
#   'catch',
#   'friend',
#   'highly',
#   'recommend',
#   'come',
#   'fresh',
#   'oyster',
#   'excellent',
#   'service'],
#  ['place',
#   'legit',
#   'make',
#   'sure',
#   'add',
#   'name',
#   'wait',
#   'list',
#   'table',
#   '3',
#   '1hr',
#   'wait',
#   'time',
#   'able',
#   'sit',
#   'us',
#   'wait',
#   'drink',
#   'around',
#   'corner',
#   'finally',
#   'sit',
#   'way',
#   'toward',
#   'back',
#   'small',
#   'restaurant',
#   'bar',
#   'soo',
#   'hungry',
#   'ready',
#   'order',
#   'everything',
#   'delicious',
#   'menu',
#   'wait',
#   'knowledgeable',
#   'gentleman',
#   'recommend',
#   'dozen',
#   'oyster',
#   'selectioni',
#   'happy',
#   'let',
#   'decide',
#   'uber',
#   'fresh',
#   'yum',
#   'run',
#   'joke',
#   'easily',
#   'eat',
#   '12',
#   'dozen',
#   'oyster',
#   'without',
#   'problem',
#   'great',
#   'selection',
#   '3',
#   'east',
#   '2',
#   'west',
#   'coast',
#   'oyster',
#   'entree',
#   'select',
#   'tuna',
#   'steak',
#   'w',
#   'delicious',
#   'mash',
#   'potatoes',
#   'ehvaehva',
#   'last',
#   'least',
#   'sweet',
#   'whiskey',
#   'cake',
#   'seal',
#   'deal',
#   'please',
#   'make',
#   'point',
#   'visit',
#   'wait',
#   'time',
#   'worth',
#   'customer',
#   'service',
#   '5',
#   'star',
#   'food',
#   'worthy'],
#  ['really',
#   'excite',
#   'try',
#   'place',
#   'base',
#   'amaze',
#   'review',
#   'dont',
#   'come',
#   'city',
#   'often',
#   'pros',
#   'oyster',
#   'drink',
#   'beer',
#   'wine',
#   'selection',
#   'great',
#   'really',
#   'enjoy',
#   'oyster',
#   'fresh',
#   'service',
#   'good',
#   'waiter',
#   'help',
#   'us',
#   'decide',
#   'getcons',
#   'rest',
#   'food',
#   'order',
#   'ciopinno',
#   'fettuccine',
#   'clam',
#   'underwhelming',
#   'food',
#   'lack',
#   'flavor',
#   'clam',
#   'ciopinno',
#   'chewy',
#   'spit',
#   'get',
#   'piece',
#   'shell',
#   'first',
#   'bite',
#   'muscle',
#   'ciopinno',
#   'would',
#   'definitely',
#   'come',
#   'back',
#   'oyster',
#   'thats'],
#  ['tldr',
#   'upstate',
#   'goto',
#   'seafood',
#   'awesome',
#   'service',
#   'sometimes',
#   'complimentary',
#   'dessert',
#   'lovely',
#   'touchmy',
#   'friends',
#   'love',
#   'come',
#   'happy',
#   'hour',
#   'oyster',
#   'super',
#   'fresh',
#   'sizable',
#   '275',
#   'pop',
#   'nonhappy',
#   'hour',
#   'time',
#   'pricy',
#   'totally',
#   'worth',
#   'happy',
#   'hourin',
#   'term',
#   'entrees',
#   'always',
#   'get',
#   'fettuccine',
#   'clam',
#   'little',
#   'salty',
#   'give',
#   'huge',
#   'meaty',
#   'clam',
#   'creamy',
#   'one',
#   'portion',
#   'enough',
#   'hungry',
#   'person',
#   'share',
#   'two',
#   'less',
#   'hungry',
#   'people',
#   'sometimes',
#   'also',
#   'bring',
#   'complimentary',
#   'pound',
#   'cake',
#   'check',
#   'nice',
#   'touch'],
#  ['good',
#   'service',
#   'nice',
#   'environment',
#   'good',
#   'drink',
#   'dont',
#   'think',
#   'fry',
#   'chicken',
#   'dont',
#   'eat',
#   'collards',
#   'idk',
#   'friend',
#   'love',
#   'hummus',
#   'eat',
#   'large',
#   'plate'],
#  ['honestly',
#   'cant',
#   'say',
#   'enough',
#   'good',
#   'things',
#   'place',
#   'first',
#   'food',
#   'outstanding',
#   'surf',
#   'turf',
#   'fettuccine',
#   'clam',
#   'outstanding',
#   'service',
#   'fantastic',
#   'appreciate',
#   'large',
#   'beer',
#   'wine',
#   'selection',
#   'youre',
#   'east',
#   'village',
#   'musttry'],
#  ['one',
#   'best',
#   'din',
#   'experience',
#   'ive',
#   'nyc',
#   'absolute',
#   'must',
#   'seafood',
#   'loversi',
#   'bring',
#   'girlfriend',
#   'one',
#   'year',
#   'anniversary',
#   'since',
#   'huge',
#   'seafood',
#   'fan',
#   'upstate',
#   'deliver',
#   'every',
#   'course',
#   'mealtheir',
#   'half',
#   'dozen',
#   'oyster',
#   'plus',
#   'drink',
#   '12',
#   'beer',
#   '16',
#   'wine',
#   'great',
#   'happy',
#   'hour',
#   'deal',
#   'solid',
#   'appetizer',
#   'try',
#   'two',
#   'three',
#   'different',
#   'available',
#   'oyster',
#   'hh',
#   'menu',
#   'three',
#   'fantastic',
#   'prince',
#   'edward',
#   'island',
#   'oyster',
#   'particular',
#   'favorite',
#   'hear',
#   'black',
#   'trout',
#   'small',
#   'plate',
#   'best',
#   'item',
#   'menu',
#   'please',
#   'order',
#   'one',
#   'thing',
#   'get',
#   'trout',
#   'essentially',
#   'thin',
#   'crispier',
#   'version',
#   'salmon',
#   'serve',
#   'delicious',
#   'light',
#   'tomato',
#   'sauce',
#   'large',
#   'almostpuréed',
#   'gnocchi',
#   'also',
#   'order',
#   'crab',
#   'cake',
#   'small',
#   'plate',
#   'legitimately',
#   'best',
#   'ones',
#   'ive',
#   'ever',
#   'soggy',
#   'make',
#   'excess',
#   'sauce',
#   'crispy',
#   'outside',
#   'green',
#   'pure',
#   'crab',
#   'id',
#   'highly',
#   'recommend',
#   'well',
#   'entrees',
#   'order',
#   'seafood',
#   'bowl',
#   'mahi',
#   'steak',
#   'delicious',
#   'perfectly',
#   'simple',
#   'really',
#   'really',
#   'good',
#   'seafood',
#   'hit',
#   'spot',
#   'service',
#   'phenomenal',
#   'dimmer',
#   'quaint',
#   'ambiance',
#   'perfect',
#   'kind',
#   'datei',
#   'can',
#   'not',
#   'recommend',
#   'upstate',
#   'enough',
#   'definitely',
#   'back',
#   'love',
#   'seafood',
#   'restaurant',
#   'need',
#   'top',
#   'list',
#   'cheer'],
#  ['boyfriend',
#   'bring',
#   'anniversary',
#   'dinner',
#   'amaze',
#   'experience',
#   'food',
#   'service',
#   'ambiance',
#   'everything',
#   'perfectwe',
#   'huge',
#   'seafood',
#   'fan',
#   'place',
#   'make',
#   'us',
#   'come',
#   '5',
#   'sunday',
#   'night',
#   'right',
#   'open',
#   'able',
#   'grab',
#   'table',
#   'wait',
#   'restaurant',
#   'small',
#   'really',
#   'like',
#   'start',
#   'get',
#   'wine',
#   'dozen',
#   'happy',
#   'hour',
#   'oyster',
#   '4',
#   'upstates',
#   'little',
#   'shems',
#   'oyster',
#   'ponds',
#   'none',
#   'disappoint',
#   'wine',
#   'get',
#   'pinot',
#   'noir',
#   'sweet',
#   'white',
#   'fantastic',
#   'oyster',
#   'think',
#   'flavor',
#   'wise',
#   'little',
#   'shems',
#   'favorite',
#   'love',
#   'large',
#   'meaty',
#   'oyster',
#   'ponds',
#   'highly',
#   'recommend',
#   'three',
#   'appetizer',
#   'get',
#   'two',
#   'small',
#   'plat',
#   'crab',
#   'cake',
#   'trout',
#   'wow',
#   'dont',
#   'know',
#   'like',
#   'better',
#   'crab',
#   'cake',
#   'super',
#   'meaty',
#   'crispy',
#   'outside',
#   'serve',
#   'great',
#   'green',
#   'salad',
#   'carrots',
#   'corn',
#   'trout',
#   'cook',
#   'perfection',
#   'incredible',
#   'crispy',
#   'skin',
#   'serve',
#   'seem',
#   'like',
#   'little',
#   'mash',
#   'potato',
#   'log',
#   'swim',
#   'best',
#   'tomato',
#   'sauce',
#   'ever',
#   'entrees',
#   'get',
#   'two',
#   'large',
#   'plat',
#   'ciopinno',
#   'mahi',
#   'steak',
#   'ciopinno',
#   'delicious',
#   'seafood',
#   'stew',
#   'clam',
#   'mussels',
#   'fish',
#   'day',
#   'scallop',
#   'shrimp',
#   'also',
#   'come',
#   'side',
#   'bread',
#   'soak',
#   'stew',
#   'bet',
#   'wipe',
#   'bowl',
#   'clean',
#   'mahi',
#   'steak',
#   'sear',
#   'perfectly',
#   'serve',
#   'bed',
#   'mash',
#   'potatoes',
#   'broccoli',
#   'cover',
#   'great',
#   'red',
#   'sauce',
#   'almost',
#   'resemblance',
#   'cocktail',
#   'sauce',
#   'work',
#   'well',
#   'together',
#   'highly',
#   'recommend',
#   'dish',
#   'wellmy',
#   'mouth',
#   'water',
#   'remember',
#   'food',
#   'wait',
#   'back',
#   'menu',
#   'change',
#   'constantly',
#   'depend',
#   'seafood',
#   'available',
#   'love',
#   'regret',
#   'stomach',
#   'isnt',
#   'bigger',
#   'could',
#   'try',
#   'dish',
#   'menu',
#   'literally',
#   'make',
#   'want',
#   'order',
#   'everythingour',
#   'server',
#   'really',
#   'great',
#   'give',
#   'recommendations',
#   'throughout',
#   'meal',
#   'check',
#   'us',
#   'perfect',
#   'amount',
#   'get',
#   'slice',
#   'whiskey',
#   'cake',
#   'check',
#   'really',
#   'tasty',
#   'perfect',
#   'way',
#   'end',
#   'meal',
#   'absolutely',
#   'wait',
#   'back'],
#  ['great',
#   'experience',
#   'want',
#   'provide',
#   'realistic',
#   'account',
#   'wait',
#   'time',
#   '15',
#   'hour',
#   'wait',
#   'get',
#   'quite',
#   'dishearten',
#   'arrive',
#   'saw',
#   'size',
#   'restaurant',
#   'saw',
#   'space',
#   'avow',
#   'get',
#   'well',
#   'worth',
#   'music',
#   'nice',
#   'find',
#   'ambience',
#   'dark',
#   'intimate',
#   'great',
#   'conversations',
#   'great',
#   'date',
#   'small',
#   'group',
#   'quite',
#   'cozy',
#   'easy',
#   'balance',
#   'bookbags',
#   'coat',
#   'would',
#   'suggest',
#   'go',
#   'elsewhere',
#   'go',
#   'shop',
#   'spree',
#   'need',
#   'bag',
#   'placeent',
#   'must',
#   'say',
#   'waiters',
#   'amaze',
#   'downtoearth',
#   'definitely',
#   'friendly',
#   'would',
#   'revisit',
#   'due',
#   'high',
#   'level',
#   'service',
#   'kumamota',
#   'raw',
#   'oyster',
#   'west',
#   'coast',
#   'oyster',
#   'fantastic',
#   'would',
#   'highly',
#   'recommend',
#   'others',
#   'try',
#   'life',
#   'change',
#   'im',
#   'plan',
#   'next',
#   'visit',
#   'speak'],
#  ['place',
#   'awesome',
#   'perfect',
#   'date',
#   'night',
#   'oyster',
#   'seafood',
#   'super',
#   'fresh',
#   'delicious',
#   'service',
#   'great',
#   'price',
#   'arent',
#   'terrible',
#   'especially',
#   'city',
#   'steak',
#   'surf',
#   'turf',
#   'little',
#   'chewy',
#   'still',
#   'delicious',
#   'scallop',
#   'amaze',
#   'definitely',
#   'come',
#   'happy',
#   'hour',
#   'chance',
#   '6',
#   'oyster',
#   'beer',
#   '12'],
#  ['great',
#   'seafood',
#   'good',
#   'servicei',
#   'like',
#   'appetizers',
#   'entrees',
#   'happy',
#   'hour',
#   'every',
#   'day',
#   '57',
#   'give',
#   '6',
#   'oyster',
#   'beer',
#   '12',
#   'pretty',
#   'solid',
#   'deal',
#   'say',
#   'also',
#   'escargot',
#   'uni',
#   'toast',
#   'dieone',
#   'star',
#   'less',
#   'pretty',
#   'dark',
#   'night',
#   'totally',
#   'vibe',
#   'bring',
#   'mom',
#   'get',
#   'older',
#   'cant',
#   'really',
#   'see',
#   'well',
#   'dark',
#   'well',
#   'thats',
#   'problem'],
#  ['upstate',
#   'bookmarked',
#   'yelp',
#   'hot',
#   'minute',
#   'finally',
#   'chance',
#   'try',
#   'cousin',
#   'friend',
#   'somewhat',
#   'area',
#   'lowkey',
#   'speakeasy',
#   'tour',
#   'death',
#   'co',
#   'pdt',
#   'angels',
#   'share',
#   'etc',
#   'rare',
#   'im',
#   'disappoint',
#   'place',
#   'number',
#   'rave',
#   'review',
#   'know',
#   'didnt',
#   'order',
#   'incorrectly',
#   'either',
#   'pasta',
#   'clam',
#   'seem',
#   'goto',
#   'dish',
#   'cousins',
#   'friend',
#   'cousin',
#   'order',
#   'scallop',
#   'give',
#   'upstate',
#   'credit',
#   'credit',
#   'due',
#   'particularly',
#   'inexpensive',
#   'seafood',
#   'manhattan',
#   'acknowledge',
#   'feel',
#   'like',
#   'ive',
#   'say',
#   'everything',
#   'positive',
#   'need',
#   'say',
#   'find',
#   'pasta',
#   'bland',
#   'uninspired',
#   'clam',
#   'incredibly',
#   'chewy',
#   'somewhat',
#   'room',
#   'temperature',
#   'well',
#   'cousins',
#   'friend',
#   'felt',
#   'exactly',
#   'way',
#   'cousin',
#   'blow',
#   'away',
#   'scallop',
#   'food',
#   'easily',
#   '35',
#   'atrocious',
#   'wouldnt',
#   'even',
#   'go',
#   'far',
#   'call',
#   'good',
#   'im',
#   'take',
#   'away',
#   'extra',
#   'star',
#   'despite',
#   'restaurant',
#   'super',
#   'slow',
#   'think',
#   'sunday',
#   'something',
#   'werent',
#   'ton',
#   'people',
#   'service',
#   'even',
#   'slower',
#   'time',
#   'take',
#   'close',
#   'hour',
#   'time',
#   'order',
#   'pasta',
#   'come',
#   'almost',
#   'never',
#   'ask',
#   'server',
#   'food',
#   'use',
#   'work',
#   'restaurants',
#   'know',
#   'lot',
#   'time',
#   'nobodys',
#   'faultbut',
#   'come',
#   'hour',
#   'really',
#   'really',
#   'bad',
#   'able',
#   'order',
#   'pork',
#   'chop',
#   'well',
#   'do',
#   'take',
#   'long',
#   'restaurant',
#   'typical',
#   'bumfck',
#   'east',
#   'village',
#   'hole',
#   'wall',
#   'pretty',
#   'narrow',
#   'cramp',
#   'nothing',
#   'exceptional',
#   'beer',
#   'selection',
#   'isnt',
#   'anything',
#   'special',
#   'complimentary',
#   'pound',
#   'cake',
#   'end',
#   'meal',
#   'nice',
#   'touch',
#   'like',
#   'pasta',
#   'wasnt',
#   'good',
#   'taste',
#   'like',
#   'cheap',
#   'grocery',
#   'store',
#   'pound',
#   'cake',
#   'want',
#   'go',
#   'dinner',
#   'grandmas',
#   'nurse',
#   'home',
#   'potluck',
#   'tldr',
#   'try',
#   'eventually',
#   'disappoint',
#   'return'],
#  ['simply',
#   'love',
#   'become',
#   'new',
#   'favorite',
#   'go',
#   'french',
#   'place',
#   'cherry',
#   'top',
#   'use',
#   'creekstone',
#   'beef',
#   'halal',
#   'alert',
#   'disclaimer',
#   'got',
#   'ta',
#   'place',
#   'right',
#   'tapa',
#   'style',
#   'skip',
#   'entrees',
#   'load',
#   'appetizers',
#   'oyster',
#   'maine',
#   'fresh',
#   'perfect',
#   'vinegar',
#   'lemon',
#   'watermelon',
#   'gazpacho',
#   'little',
#   'bite',
#   'underwhelming',
#   'especially',
#   'two',
#   'nights',
#   'din',
#   'mercado',
#   'little',
#   'spain',
#   'jose',
#   'andres',
#   'hudson',
#   'yards',
#   'however',
#   'hold',
#   'worth',
#   'lot',
#   'warm',
#   'glob',
#   'pistachio',
#   'crust',
#   'goat',
#   'cheese',
#   'really',
#   'steal',
#   'show',
#   'honestly',
#   'felt',
#   'like',
#   'every',
#   'subsequent',
#   'dish',
#   'one',
#   'up',
#   'previous',
#   'one',
#   'ultimately',
#   'culminate',
#   'explosion',
#   'delicious',
#   'hot',
#   'cold',
#   'delight',
#   'melt',
#   'lava',
#   'cake',
#   'handsdown',
#   'best',
#   'dessert',
#   'country',
#   'add',
#   'fact',
#   'customize',
#   'whatever',
#   'gelato',
#   'flavor',
#   'come',
#   'swirl',
#   'strawberry',
#   'creme',
#   'anglais',
#   'would',
#   'give',
#   '65',
#   'texture',
#   'flavor',
#   'temperate',
#   'optimize',
#   'one',
#   'perfect',
#   'desert',
#   'cappuccino',
#   'pallet',
#   'cleanser',
#   'also',
#   'good',
#   'dessetthat',
#   'say',
#   'table',
#   'next',
#   'us',
#   'order',
#   'mediocre',
#   'creme',
#   'brûlée',
#   'chocolate',
#   'mousse',
#   'would',
#   'advise',
#   'beef',
#   'tartare',
#   'halal',
#   'perfectly',
#   'ratioed',
#   'another',
#   'winner',
#   'cheese',
#   'general',
#   'winners',
#   'burrata',
#   'solid',
#   'id',
#   'give',
#   '45',
#   'ive',
#   'better',
#   'travel',
#   'far',
#   'wide',
#   'look',
#   'burratadefinitely',
#   'go',
#   'back',
#   'perfect',
#   'ambience',
#   'girls',
#   'night',
#   'date',
#   'happy',
#   'hour',
#   'price',
#   'make',
#   'affordable',
#   'environment',
#   'service',
#   'amaze',
#   'worthy',
#   'three',
#   'star'],
#  ['second',
#   'time',
#   'visit',
#   'place',
#   'nice',
#   'let',
#   'us',
#   'sit',
#   'early',
#   'reservation',
#   'time',
#   'fail',
#   'time',
#   'service',
#   'guy',
#   'sit',
#   'initially',
#   'didnt',
#   'seem',
#   'happy',
#   'wait',
#   'bite',
#   'disappoint',
#   'since',
#   'early',
#   'birthday',
#   'dinner',
#   'one',
#   'less',
#   'star',
#   'however',
#   'food',
#   'still',
#   'good',
#   'best',
#   'chicken',
#   'liver',
#   'pate',
#   'beef',
#   'tartare',
#   'foie',
#   'gra',
#   'seem',
#   'better',
#   'first',
#   'time',
#   '2',
#   'years',
#   'ago',
#   'escargot',
#   'good',
#   'way',
#   'warn',
#   'cook',
#   'traditional',
#   'garlic',
#   'butter',
#   'parsley',
#   'sweet',
#   'end',
#   'party',
#   'mussels',
#   'like',
#   'hopefully',
#   'next',
#   'time',
#   'would',
#   '5',
#   'star',
#   'experience'],
#  ['place',
#   'bomb',
#   'eric',
#   'manager',
#   'awesome',
#   'glass',
#   'champagne',
#   'start',
#   'bottle',
#   'burgundy',
#   'dinner',
#   'another',
#   'glass',
#   'cheesehe',
#   'keep',
#   'glass',
#   'full',
#   'hourthe',
#   'food',
#   'amaze',
#   'escargot',
#   'one',
#   'best',
#   'ive',
#   'tuna',
#   'tartare',
#   'delicious',
#   'duck',
#   'confit',
#   'wow',
#   'snapper',
#   'amaze',
#   'foie',
#   'gras',
#   'um',
#   'ive',
#   'better',
#   'cheese',
#   'great',
#   'selectionthe',
#   'service',
#   'great',
#   'friendly',
#   'table',
#   'bite',
#   'small',
#   'hey',
#   'new',
#   'york'],
#  ['get',
#   'first',
#   'wine',
#   'flight',
#   'disappoint',
#   'menu',
#   'say',
#   'come',
#   '6',
#   'waiter',
#   'say',
#   'happy',
#   'hour',
#   'clearly',
#   'happy',
#   'hour',
#   'time',
#   'go',
#   'happy',
#   '3',
#   'selections',
#   'get',
#   'give',
#   'bread',
#   'get',
#   'mussels',
#   'really',
#   'good',
#   'usually',
#   'dont',
#   'get',
#   'seafood',
#   'restaurant',
#   'make',
#   'exception',
#   'let',
#   'best',
#   'part',
#   'dip',
#   'bread',
#   'soup',
#   'mussels',
#   'come',
#   'taste',
#   'great',
#   'love',
#   'good',
#   'life',
#   'hack',
#   'wine',
#   'taste',
#   'pretty',
#   'similar',
#   'friends',
#   'get',
#   'hint',
#   'smoke',
#   'cherry',
#   'get',
#   'waste',
#   'plan',
#   'also',
#   'come',
#   'french',
#   'fry',
#   'enough',
#   'dip',
#   'service',
#   'great',
#   'waiter',
#   'super',
#   'friendly',
#   'would',
#   'come'],
#  ['back',
#   'marvelous',
#   'meal',
#   'scrumptious',
#   'rise',
#   'bottle',
#   'boot',
#   'cheese',
#   'plate',
#   'divine',
#   'high',
#   'caliber',
#   'cheese',
#   'assortment',
#   'animal',
#   'milk',
#   'partner',
#   'love',
#   'croquettes',
#   'day',
#   'escargot',
#   'frisee',
#   'salad',
#   'poach',
#   'egg',
#   'asparagus',
#   'delicious',
#   'endeavor',
#   'aioli',
#   'look',
#   'homemade',
#   'rich',
#   'flavor',
#   'lastly',
#   'important',
#   'review',
#   'service',
#   'team',
#   'take',
#   'care',
#   'us',
#   'top',
#   'things',
#   'pleasant',
#   'friendly',
#   'knowledgeable',
#   'menu',
#   'take',
#   'marvelous',
#   'care',
#   'book',
#   'table',
#   'weeks',
#   'make',
#   'dinner',
#   'better',
#   'care',
#   'without',
#   'ever',
#   'interrupt',
#   'huge',
#   'advocate',
#   'regularly',
#   'return',
#   'absolutely',
#   'use',
#   'quality',
#   'restaurant',
#   'bring',
#   'parent',
#   'visit',
#   'absolutely',
#   'go',
#   'think',
#   'youll',
#   'hard',
#   'press',
#   'fall',
#   'head',
#   'heel'],
#  ['im',
#   'sucker',
#   'french',
#   'bistro',
#   'style',
#   'food',
#   'theres',
#   'lot',
#   'genre',
#   'choose',
#   'city',
#   'amelie',
#   'quite',
#   'leave',
#   'bank',
#   'parisian',
#   'bistro',
#   'west',
#   'village',
#   '8th',
#   'street',
#   'eatery',
#   'get',
#   'high',
#   'mark',
#   'yelp',
#   'take',
#   'leap',
#   'faith',
#   'choose',
#   'brunch',
#   'town',
#   'friends',
#   'overall',
#   'please',
#   'food',
#   'much',
#   'brusque',
#   'service',
#   'impossibly',
#   'loud',
#   'music',
#   'endless',
#   'chatter',
#   'pack',
#   'house',
#   'conversation',
#   'require',
#   'yell',
#   'one',
#   'another',
#   'like',
#   'carny',
#   'barkers',
#   'ideal',
#   'vibe',
#   'relax',
#   'saturday',
#   'brunch',
#   'friendsthe',
#   'best',
#   'bite',
#   'share',
#   'two',
#   'serve',
#   'escargots',
#   'serve',
#   'shell',
#   'classic',
#   'parsleygarlicbutter',
#   'gratinee',
#   'tender',
#   'globules',
#   'perfectly',
#   'season',
#   'melt',
#   'mouth',
#   'tender',
#   'mop',
#   'gratis',
#   'crusty',
#   'baguettes',
#   'sip',
#   'wine',
#   'think',
#   'burgundy',
#   'france',
#   'may',
#   'forget',
#   'deafen',
#   'joint',
#   'really',
#   'duck',
#   'leg',
#   'confit',
#   'classically',
#   'prepare',
#   'perfectly',
#   'tender',
#   'flavorful',
#   'soggy',
#   'flavorless',
#   'potato',
#   'slice',
#   'serve',
#   'duck',
#   'mar',
#   'dish',
#   'presentationmussels',
#   'wine',
#   'leek',
#   'pedestrian',
#   'several',
#   'unopened',
#   'old',
#   'dead',
#   'always',
#   'mildly',
#   'distress',
#   'lamb',
#   'burger',
#   'nicely',
#   'char',
#   'chef',
#   'recommend',
#   'medium',
#   'serve',
#   'toast',
#   'baguette',
#   'instead',
#   'brioche',
#   'bun',
#   'advertise',
#   'server',
#   'say',
#   'run',
#   'buns',
#   'suggest',
#   'baguette',
#   'would',
#   'work',
#   'even',
#   'better',
#   'didnt',
#   'make',
#   'gum',
#   'tear',
#   'teeth',
#   'rattle',
#   'chew',
#   'toast',
#   'baguettes',
#   'work',
#   'onion',
#   'soup',
#   'salad',
#   'croutons',
#   'vessels',
#   'tender',
#   'lamb',
#   'burgershanger',
#   'steak',
#   'frites',
#   'egg',
#   'honest',
#   'interpretation',
#   'shoestring',
#   'frites',
#   'perfectly',
#   'crispy',
#   'meal',
#   'serve',
#   'trio',
#   'flavorful',
#   'sauce',
#   'charcuterie',
#   'cheese',
#   'platter',
#   'choice',
#   '5',
#   '33',
#   'buck',
#   'satisfy',
#   'instance',
#   'crusty',
#   'baguette',
#   'perfect',
#   'match',
#   'especially',
#   'like',
#   'pheasant',
#   'pate',
#   'duck',
#   'rilette',
#   'alongside',
#   'stinky',
#   'french',
#   'cheese',
#   'great',
#   'contrast',
#   'flavor',
#   'wish',
#   'selectionsamelie',
#   'offer',
#   'plenty',
#   'choice',
#   'drink',
#   'though',
#   'include',
#   'nice',
#   'house',
#   'special',
#   'cocktails',
#   'two',
#   'absinthe',
#   'rye',
#   'whiskey',
#   'power',
#   'sazeracs',
#   'delicious',
#   'remind',
#   'much',
#   'miss',
#   'classic',
#   'south',
#   'france',
#   'combo',
#   'everyone',
#   'else',
#   'quaff',
#   'good',
#   'french',
#   'wine',
#   'glass',
#   'seem',
#   'happy',
#   'choicestop',
#   'tip',
#   'brunch',
#   'menu',
#   'limit',
#   'happy',
#   'hour',
#   '12',
#   'wine',
#   'flight',
#   'support',
#   'full',
#   'dinner',
#   'menu',
#   'run',
#   '4',
#   '7',
#   'miss',
#   'special',
#   'next',
#   'trip',
#   'look',
#   'forward',
#   'try',
#   'regular',
#   'dinner',
#   'menu',
#   'absinthe',
#   'inspire',
#   'cocktails',
#   'know',
#   'dont',
#   'lop',
#   'ear',
#   'might',
#   'inspire',
#   'enough',
#   'paint',
#   'like',
#   'vincent',
#   'wormwood',
#   'induce',
#   'green',
#   'fairylike',
#   'haze',
#   'lol'],
#  ['come',
#   'get',
#   'pistachio',
#   'crust',
#   'goat',
#   'cheese',
#   'ball',
#   'thank',
#   'later',
#   'absolutely',
#   'one',
#   'tastiest',
#   'items',
#   'menu',
#   'love',
#   'unlimited',
#   'bread',
#   'love',
#   'come',
#   'actual',
#   'sack',
#   'come',
#   'gf',
#   'steak',
#   'frites',
#   'lamb',
#   'burger',
#   'food',
#   'great',
#   'drink',
#   'delicious',
#   'service',
#   'good',
#   'im',
#   'write',
#   'review',
#   'next',
#   'day',
#   'im',
#   'still',
#   'think',
#   'good',
#   'cheese',
#   'definitely',
#   'come',
#   'back',
#   'lunch',
#   'try',
#   'happy',
#   'hour',
#   'menu'],
#  ['great',
#   'wine',
#   'flight',
#   'amaze',
#   'charcuterie',
#   'also',
#   'great',
#   'service',
#   'waiter',
#   'apologize',
#   'slow',
#   'really',
#   'wasnt',
#   'slow',
#   'give',
#   'us',
#   'complimentary',
#   'glass',
#   'wine',
#   'also',
#   'really',
#   'cool',
#   'bathrooms',
#   'strange',
#   'somehow',
#   'make',
#   'difference',
#   'back',
#   'get',
#   'chicken',
#   'also',
#   'crab',
#   'tartine'],
#  ['fiancé',
#   'come',
#   'brunch',
#   'past',
#   'sunday',
#   'noon',
#   'sure',
#   'still',
#   'early',
#   'rainy',
#   'weather',
#   'empty',
#   'walk',
#   'another',
#   'group',
#   'already',
#   'eat',
#   'thats',
#   'overall',
#   'service',
#   'good',
#   'food',
#   'find',
#   'anything',
#   'ordinary',
#   'regular',
#   'brunch',
#   'place',
#   'order',
#   'cheese',
#   'charcuterie',
#   'plate',
#   'two',
#   'cheese',
#   'one',
#   'meat',
#   'start',
#   'fiancé',
#   'order',
#   'french',
#   'onion',
#   'soup',
#   'judge',
#   'place',
#   'go',
#   'base',
#   'good',
#   'french',
#   'onion',
#   'soup',
#   'really',
#   'enjoy',
#   'one',
#   'entrees',
#   'order',
#   'lamb',
#   'burger',
#   'mimosa'],
#  ['make',
#   'reservation',
#   'two',
#   'people',
#   'friday',
#   'later',
#   'night',
#   'arrive',
#   'seat',
#   'without',
#   'problem',
#   'interior',
#   'much',
#   'modern',
#   'trendy',
#   'think',
#   'would',
#   'good',
#   'way',
#   'also',
#   'completely',
#   'full',
#   'friday',
#   'night',
#   'since',
#   'crowd',
#   'service',
#   'little',
#   'slow',
#   'werent',
#   'rushwe',
#   'decide',
#   'order',
#   'wine',
#   'flight',
#   '16',
#   'come',
#   'three',
#   'small',
#   'almost',
#   'full',
#   'glass',
#   'wine',
#   '8',
#   'different',
#   'wine',
#   'flight',
#   'choose',
#   'decide',
#   'try',
#   'eric',
#   'benjamin',
#   'like',
#   'type',
#   'wine',
#   'bring',
#   'us',
#   'dinner',
#   'order',
#   'steak',
#   'tartare',
#   '5',
#   'oz',
#   '8',
#   'oz',
#   'portion',
#   'also',
#   'order',
#   'fry',
#   'brussel',
#   'sprout',
#   'share',
#   'steak',
#   'tartare',
#   'delicious',
#   'prepare',
#   'perfectly',
#   'quail',
#   'egg',
#   'top',
#   'also',
#   'come',
#   'fresh',
#   'watercress',
#   'salad',
#   'side',
#   'fry',
#   'also',
#   'thin',
#   'delicious',
#   'side',
#   'mayo',
#   'well',
#   'spicy',
#   'mayo',
#   'brussel',
#   'sprout',
#   'good',
#   'favorite',
#   'mostly',
#   'prefer',
#   'crispy',
#   'rather',
#   'soft',
#   'ones',
#   'every',
#   'table',
#   'also',
#   'get',
#   'cute',
#   'sad',
#   'fresh',
#   'bread',
#   'baguette',
#   'end',
#   'meal',
#   'full',
#   'happy',
#   'really',
#   'enjoy',
#   'meal',
#   'less',
#   'pricey',
#   'lot',
#   'nyc',
#   'restaurants',
#   'lower',
#   'quality',
#   'come',
#   'back'],
#  ['come',
#   'busy',
#   'friday',
#   'night',
#   'thankfully',
#   'reservations',
#   'set',
#   'else',
#   'would',
#   '3',
#   'hour',
#   'wait',
#   'table',
#   '30',
#   'minute',
#   'wait',
#   'seat',
#   'bar',
#   'per',
#   'host',
#   'felt',
#   'cramp',
#   'super',
#   'cozy',
#   'thats',
#   'positive',
#   'sign',
#   'mean',
#   'place',
#   'legit',
#   'friend',
#   'happy',
#   'hour',
#   'wine',
#   'flight',
#   'solid',
#   'selection',
#   'many',
#   'varieties',
#   'different',
#   'regions',
#   'choose',
#   'one',
#   'theme',
#   'make',
#   'flight',
#   'happy',
#   'choices',
#   'price',
#   'solid',
#   'winewe',
#   'cheese',
#   'board',
#   'starters',
#   'would',
#   'definitely',
#   'recommend',
#   'delicious',
#   'come',
#   'dry',
#   'fruit',
#   'jam',
#   'honey',
#   'go',
#   'along',
#   'also',
#   'come',
#   'nice',
#   'warm',
#   'bread',
#   'werent',
#   'stingy',
#   'bread',
#   'nearly',
#   'full',
#   'bread',
#   'since',
#   'bread',
#   'basket',
#   'probably',
#   'contain',
#   'full',
#   'loafnext',
#   'fry',
#   'surprisingly',
#   'amaze',
#   'mean',
#   'french',
#   'fry',
#   'good',
#   'really',
#   'make',
#   'french',
#   'fry',
#   'truly',
#   'mind',
#   'blow',
#   'come',
#   'two',
#   'succulent',
#   'sauce',
#   'finish',
#   'salad',
#   'french',
#   'onion',
#   'soup',
#   'solid',
#   'good',
#   'flavor',
#   'nothing',
#   'really',
#   'write',
#   'home',
#   'aboutid',
#   'come',
#   'back',
#   'maybe',
#   'cheese',
#   'board',
#   'wine',
#   'flight',
#   'satisfy',
#   'fill',
#   'since',
#   'give',
#   'much',
#   'bread',
#   'would',
#   '5',
#   'star',
#   'experience',
#   'service',
#   'time',
#   'observe',
#   '1',
#   'waiter',
#   '1',
#   'busser',
#   'time',
#   'restaurant',
#   'stuff',
#   'like',
#   'sardines',
#   'wait',
#   'exceptionally',
#   'long',
#   'time',
#   'menus',
#   'water',
#   'wine',
#   'food',
#   'check',
#   'staff',
#   'try',
#   'best',
#   'work',
#   'hard',
#   'maybe',
#   'people',
#   'floor',
#   'would',
#   'provide',
#   'patrons',
#   'better',
#   'experiencez'],
#  ['wow',
#   'wow',
#   'superb',
#   'service',
#   'quality',
#   'food',
#   'ambience',
#   'crowd',
#   'love',
#   'everything',
#   'swank',
#   'french',
#   'restaurant',
#   'husband',
#   'come',
#   'date',
#   'night',
#   'lucked',
#   'instant',
#   'seat',
#   'bar',
#   'table',
#   'usually',
#   'theres',
#   'reservations',
#   'long',
#   'wait',
#   'time',
#   'tip',
#   'get',
#   'reservations',
#   'ahead',
#   'time',
#   'early',
#   'dinner',
#   'star',
#   'escargot',
#   'oh',
#   'god',
#   'die',
#   'duck',
#   'confit',
#   'wow',
#   'one',
#   'best',
#   'confit',
#   'super',
#   'moist',
#   'duck',
#   'light',
#   'crispy',
#   'skin',
#   'wow',
#   'wow',
#   'finish',
#   'meal',
#   'prosecco',
#   'husband',
#   'whiskey',
#   'whiskey',
#   'prosecco',
#   'kind',
#   'nightdef',
#   'recommend',
#   'place'],
#  ['absolute',
#   'favorite',
#   'restaurant',
#   'nyc',
#   'amaze',
#   'french',
#   'food',
#   'even',
#   'better',
#   'happy',
#   'hour',
#   'delicious',
#   'wine',
#   'flight',
#   '12',
#   'weve',
#   'amélie',
#   'quite',
#   'time',
#   'time',
#   'felt',
#   'welcome',
#   'help',
#   'quickly',
#   'even',
#   'extremely',
#   'busy',
#   'customer',
#   'service',
#   'top',
#   'notch',
#   'wish',
#   'could',
#   'give',
#   '5',
#   'star',
#   'seriously',
#   'complaints'],
#  ['first',
#   'time',
#   'visit',
#   'la',
#   'totally',
#   'worth',
#   'amelie',
#   'yelp',
#   'list',
#   'since',
#   'recommend',
#   'friend',
#   'impressive',
#   'review',
#   'yelp',
#   'make',
#   'reservations',
#   'month',
#   'ago',
#   '11',
#   'guests',
#   'include',
#   'saturday',
#   '8pm',
#   '10',
#   'people',
#   'party',
#   'prix',
#   'fixe',
#   'menu',
#   'include',
#   'appetizer',
#   'main',
#   'entrée',
#   'dessert',
#   'drink',
#   'house',
#   'wine',
#   'beer',
#   'soft',
#   'drinkall',
#   'great',
#   'price',
#   '60',
#   'pre',
#   'tax',
#   'gratuity',
#   'lot',
#   'place',
#   'even',
#   'include',
#   'drink',
#   'prix',
#   'fixe',
#   'menu',
#   'place',
#   'pack',
#   'bite',
#   'noisy',
#   'expect',
#   'ambiance',
#   'nice',
#   'cool',
#   'casual',
#   'vibe',
#   'red',
#   'backlight',
#   'seat',
#   'back',
#   'nice',
#   'bite',
#   'distance',
#   'front',
#   'crowd',
#   'prix',
#   'fixe',
#   'menu',
#   'get',
#   'follow',
#   'burgundy',
#   'escargots',
#   'gratines',
#   'vegetable',
#   'brunoise',
#   'sauce',
#   'give',
#   'yummy',
#   'umami',
#   'flavor',
#   'escargot',
#   'nice',
#   'moist',
#   'love',
#   'garlic',
#   'parsley',
#   'butter',
#   'one',
#   'best',
#   'escargots',
#   'ive',
#   'tastedcrab',
#   'tartine',
#   'friends',
#   'pick',
#   'good',
#   'great',
#   'escargot',
#   'pickle',
#   'jalapeno',
#   'give',
#   'nice',
#   'kick',
#   'citrus',
#   'aioli',
#   'nice',
#   'creamy',
#   'actually',
#   'try',
#   'pickle',
#   'jalapeno',
#   'escargot',
#   'deliciousseared',
#   'organic',
#   'salmon',
#   'cook',
#   'medium',
#   'delicious',
#   'salmon',
#   'nice',
#   'moist',
#   'inside',
#   'perfect',
#   'contrast',
#   'crispy',
#   'skin',
#   'outside',
#   'delicata',
#   'squash',
#   'underneath',
#   'give',
#   'dish',
#   'nice',
#   'texture',
#   'acidic',
#   'flavor',
#   'well',
#   'donevanilla',
#   'bean',
#   'crème',
#   'brulee',
#   'yummy',
#   'nothing',
#   'fancy',
#   'deconstruct',
#   'yummy',
#   'crème',
#   'brulee',
#   'nice',
#   'caramelizationsauvignon',
#   'blanc',
#   'light',
#   'refresh',
#   'smooth',
#   'way',
#   'like',
#   'itsuch',
#   'great',
#   'place',
#   'last',
#   'gno',
#   'new',
#   'york',
#   'would',
#   'say',
#   'food',
#   'way',
#   'better',
#   'beauty',
#   'essex',
#   'price',
#   'reasonable',
#   'food',
#   'delicious',
#   'service',
#   'great',
#   'benjamin',
#   'host',
#   'warm',
#   'welcome',
#   'eric',
#   'k',
#   'server',
#   'courteous',
#   'attentivei',
#   'totally',
#   'recommend',
#   'place',
#   'great',
#   'night',
#   'dinner',
#   'drink',
#   'whether',
#   'birthday',
#   'date',
#   'night',
#   'nyc',
#   '40',
#   'girls',
#   'trip',
#   'like',
#   'us'],
#  ['come',
#   'friday',
#   'night',
#   'romantic',
#   'anniversary',
#   'dinner',
#   'glad',
#   'make',
#   'reservations',
#   'via',
#   'yelp',
#   'restaurant',
#   'narrow',
#   'theres',
#   'line',
#   'end',
#   'wait',
#   'outside',
#   'cold',
#   'great',
#   'happy',
#   'hour',
#   'specials',
#   'wine',
#   '7pm',
#   '3',
#   'glass',
#   'win',
#   '13',
#   'give',
#   'theyre',
#   'full',
#   'size',
#   'wine',
#   'glass',
#   'still',
#   'great',
#   'deal',
#   'even',
#   'mix',
#   'match',
#   'get',
#   'different',
#   'kinds',
#   'wine',
#   'share',
#   'friends',
#   'cant',
#   'finish',
#   '3',
#   'im',
#   'judgingthe',
#   'service',
#   'bite',
#   'slow',
#   'fully',
#   'pack',
#   'great',
#   'place',
#   'girls',
#   'night',
#   'anniversary',
#   'dinner',
#   'dim',
#   'light',
#   'cool',
#   'look',
#   'décor',
#   'moderate',
#   'noise',
#   'level',
#   'end',
#   'pick',
#   'place',
#   'look',
#   'get',
#   'yummy',
#   'escargot',
#   'start',
#   'appetizers',
#   'escargot',
#   'smoke',
#   'salmon',
#   'crostini',
#   'octopus',
#   'crostini',
#   'crab',
#   'tartine',
#   'favorite',
#   'appetizers',
#   'octopus',
#   'crostini',
#   'know',
#   'like',
#   'octopus',
#   'beware',
#   'bread',
#   'crostini',
#   'super',
#   'hard',
#   'know',
#   'suppose',
#   'soft',
#   'like',
#   'white',
#   'bread',
#   'keep',
#   'hold',
#   'ingredients',
#   'top',
#   'another',
#   'level',
#   'hard',
#   'literally',
#   'use',
#   'fork',
#   'knife',
#   'try',
#   'cut',
#   'half',
#   'struggle',
#   'felt',
#   'like',
#   'chip',
#   'tooth',
#   'try',
#   'take',
#   'first',
#   'bite',
#   'escargot',
#   'bite',
#   'disappoint',
#   'taste',
#   'like',
#   'butter',
#   'much',
#   'else',
#   'ill',
#   'admit',
#   'love',
#   'dip',
#   'bread',
#   'escargot',
#   'butter',
#   'highlight',
#   'meal',
#   'entrée',
#   'duck',
#   'leg',
#   'tender',
#   'flavorful',
#   'okay',
#   'come',
#   'escargot',
#   'come',
#   'like',
#   'duck',
#   'leg',
#   'instead'],
#  ['definitely',
#   'say',
#   'everything',
#   'absolutely',
#   'amaze',
#   'wine',
#   'food',
#   'service',
#   'ny',
#   'birthday',
#   'weekend',
#   'want',
#   'come',
#   'make',
#   'reservation',
#   'promptly',
#   'seat',
#   'saturday',
#   'night',
#   'bustle',
#   'everything',
#   'come',
#   'without',
#   'hitch',
#   'order',
#   'bottle',
#   'wine',
#   'charcuterie',
#   'chicken',
#   'liver',
#   'go',
#   'chicken',
#   'liver',
#   'die',
#   'im',
#   'obsess',
#   'things',
#   'duck',
#   'get',
#   'duck',
#   'confit',
#   'perfectly',
#   'prepare',
#   'dry',
#   'absolutely',
#   'delicious',
#   'husband',
#   'get',
#   'steak',
#   'frites',
#   'perfectly',
#   'cook',
#   'medium',
#   'rare',
#   'yummy',
#   'frites',
#   'little',
#   'wine',
#   'leave',
#   'opt',
#   'chocolate',
#   'mousse',
#   'perfect',
#   'pair',
#   'everything',
#   'even',
#   'awesome',
#   'include',
#   'service',
#   'stay',
#   'short',
#   'list',
#   'next',
#   'ny',
#   'trip'],
#  ['review',
#   'year',
#   'late',
#   'need',
#   'mark',
#   'memorable',
#   'momentalthough',
#   'wine',
#   'bar',
#   'really',
#   'accommodate',
#   'family',
#   'child',
#   'even',
#   'without',
#   'reservation',
#   'weekendthe',
#   'wine',
#   'selection',
#   'great',
#   'list',
#   'servers',
# ...
#   'good',
#   'buttery',
#   'dough',
#   'amaze',
#   'bread',
#   'bowl',
#   'cheese',
#   'egg',
#   'definite',
#   'must',
#   'anything',
#   'order',
#   'delicious',
#   'taste',
#   'exactly',
#   'like',
#   'melt',
#   'buttery',
#   'popcornoverall',
#   'back',
#   'service',
#   'amaze',
#   'food',
#   'ambiance',
#   'clean',
#   'neat',
#   'bright',
#   'one',
#   'star',
#   'food',
#   'take',
#   'really',
#   'long',
#   'time',
#   'come',
#   'perhaps',
#   'thats',
#   'love',
#   'care',
#   'bestow',
#   'food'],
#  ['omg',
#   'love',
#   'parent',
#   'town',
#   'want',
#   'take',
#   'somewhere',
#   'unique',
#   'course',
#   'turn',
#   'yelp',
#   'discover',
#   'chama',
#   'mama',
#   'since',
#   'none',
#   'us',
#   'try',
#   'georgian',
#   'food',
#   'decide',
#   'give',
#   'go',
#   'make',
#   'reservation',
#   'day',
#   'trouble',
#   'place',
#   'super',
#   'trendy',
#   'yet',
#   'chillcasual',
#   'vibe',
#   'giant',
#   'glass',
#   'window',
#   'look',
#   'kitchen',
#   'cool',
#   'servers',
#   'extremely',
#   'attentive',
#   'helpful',
#   'term',
#   'food',
#   'start',
#   'taste',
#   'georgia',
#   'highly',
#   'recommend',
#   'soo',
#   'yummy',
#   'number',
#   'vegetarian',
#   'dish',
#   'cheese',
#   'spread',
#   'bread',
#   'next',
#   'beef',
#   'pork',
#   'khinkali',
#   'dumplings',
#   'pretty',
#   'good',
#   'wouldnt',
#   'get',
#   'also',
#   'adjaruli',
#   'seem',
#   'thing',
#   'get',
#   'yummy',
#   'cheesy',
#   'buttery',
#   'delicious',
#   'also',
#   'order',
#   'wine',
#   'sampler',
#   'recommend',
#   '3',
#   'win',
#   'great',
#   'number',
#   'desserts',
#   'menu',
#   'grape',
#   'jellytype',
#   'pie',
#   'unique',
#   'refresh',
#   'heavy',
#   'like',
#   'many',
#   'dessertsoverall',
#   'highly',
#   'recommend',
#   'check',
#   'chama',
#   'mama',
#   'look',
#   'unique',
#   'din',
#   'experience',
#   'food',
#   'service',
#   'ambiance',
#   'great',
#   'price',
#   'also',
#   'pretty',
#   'reasonable',
#   'definitely',
#   'back',
#   'try',
#   'menu',
#   'items'],
#  ['clean',
#   'spacious',
#   'special',
#   'place',
#   'attentive',
#   'service',
#   'cold',
#   'appetizers',
#   'would',
#   'recommend',
#   'taste',
#   'georgia',
#   'everything',
#   'like',
#   'stuff',
#   'eggplants',
#   'cheese',
#   'dumplings',
#   'recommend',
#   'kinda',
#   'pricey',
#   '3',
#   'piece',
#   'dumpling',
#   'wine',
#   'good',
#   'cheap',
#   'would',
#   'recommend',
#   'wine',
#   'flight',
#   '3',
#   'small',
#   'glass',
#   '10',
#   'boat',
#   'cheese',
#   'butter',
#   'another',
#   'must',
#   'georgian',
#   'bread',
#   'bake',
#   'differently',
#   'house',
#   'go',
#   'well',
#   'melt',
#   'cheese',
#   'best',
#   'thing',
#   'house',
#   'look',
#   'heavy',
#   'definitely',
#   'less',
#   'piece',
#   'cheesecake'],
#  ['come',
#   'dinner',
#   'thursday',
#   'night',
#   'pleasantly',
#   'surprise',
#   'spacious',
#   'inside',
#   'fact',
#   'take',
#   'reservations',
#   'convenientwe',
#   'order',
#   'share',
#   'try',
#   'variety',
#   'vegetarian',
#   'options',
#   'plenty',
#   'favorite',
#   'imeruli',
#   'cheese',
#   'bread',
#   'mushroom',
#   'chakapuli',
#   'good',
#   'particularly',
#   'special',
#   'would',
#   'probably',
#   'skip',
#   'favor',
#   'small',
#   'platesthe',
#   'main',
#   'downside',
#   'service',
#   'server',
#   'bring',
#   'us',
#   'incorrect',
#   'dish',
#   'problem',
#   'mistake',
#   'happen',
#   'take',
#   'almost',
#   '20min',
#   'us',
#   'wave',
#   'server',
#   'correct',
#   'issue',
#   'take',
#   'similarly',
#   'long',
#   'time',
#   'correct',
#   'bill',
#   'list',
#   'incorrect',
#   'dish',
#   'staff',
#   'friendly',
#   'give',
#   'good',
#   'recommendations',
#   'think',
#   'issue',
#   'didnt',
#   'enough',
#   'servers',
#   'number',
#   'table'],
#  ['come',
#   'last',
#   'weekend',
#   'friend',
#   'three',
#   'star',
#   'mostly',
#   'service',
#   'waiter',
#   'super',
#   'sweet',
#   'attentive',
#   'maybe',
#   'order',
#   'combination',
#   'overall',
#   'meal',
#   'little',
#   'disappoint',
#   'ordered1',
#   'soup',
#   'dumpling',
#   'pork',
#   'beef',
#   'okay',
#   'chinese',
#   'soup',
#   'dumpling',
#   'definitely',
#   'superior',
#   'fill',
#   'little',
#   'dry',
#   'dumpling',
#   'wrappers',
#   'way',
#   'thick',
#   'wrappers',
#   'also',
#   'bite',
#   'salty',
#   'kinda',
#   'taste',
#   'like',
#   'pasta',
#   'overall',
#   'huge',
#   'fan',
#   'dumplings',
#   '11',
#   '3',
#   'dumplings',
#   '2',
#   'shkmerulichicken',
#   'creamy',
#   'sauce',
#   'really',
#   'heavy',
#   'opinion',
#   'chicken',
#   'tasty',
#   '22',
#   '3',
#   'abjarulithe',
#   'famous',
#   'bread',
#   'boat',
#   'cheese',
#   'egg',
#   'butter',
#   'look',
#   'cute',
#   'like',
#   'food',
#   'little',
#   'salty',
#   'bland',
#   'also',
#   'pricey',
#   'bread',
#   'cheese',
#   '15overall',
#   'food',
#   'okay',
#   'think',
#   'food',
#   'expensive',
#   'get',
#   'also',
#   'recommend',
#   'get',
#   'creamy',
#   'chicken',
#   'get',
#   'cheese',
#   'bread',
#   'boat',
#   'way',
#   'heavy',
#   'im',
#   'glad',
#   'get',
#   'try',
#   'georgian',
#   'food',
#   'dont',
#   'think',
#   'ill',
#   'come',
#   'back'],
#  ['wait',
#   'time',
#   '25i',
#   'think',
#   'would',
#   'crowd',
#   'around',
#   'dinner',
#   'time',
#   '700',
#   'make',
#   'reservation',
#   'advance',
#   'im',
#   'use',
#   'seat',
#   'asap',
#   'make',
#   'reservations',
#   'chama',
#   'mama',
#   'seat',
#   'five',
#   'minutes',
#   'reservation',
#   'time',
#   'also',
#   'get',
#   'five',
#   'minutes',
#   'earlier',
#   'awkwardly',
#   'stand',
#   'whole',
#   'ten',
#   'minutes',
#   'even',
#   'though',
#   'make',
#   'reservation',
#   'service',
#   '255i',
#   'feel',
#   'like',
#   'chama',
#   'mama',
#   'either',
#   'extremely',
#   'understaffed',
#   'inexperienced',
#   'servers',
#   'get',
#   'table',
#   'one',
#   'friends',
#   'napkin',
#   'nothing',
#   'grab',
#   'nearby',
#   'set',
#   'cutlery',
#   'friends',
#   'lol',
#   'food',
#   '45',
#   'redeem',
#   'part',
#   'review',
#   'food',
#   'get',
#   'two',
#   'share',
#   'plat',
#   'megruli',
#   'kharsho',
#   'apkhazura',
#   'taste',
#   'georgia',
#   'cheese',
#   'lover',
#   'absolutely',
#   'enjoy',
#   'cheese',
#   'provide',
#   'taste',
#   'georgia',
#   'salty',
#   'cheese',
#   'go',
#   'well',
#   'jam',
#   'come',
#   'bread',
#   'megruli',
#   'kharsho',
#   'little',
#   'dry',
#   'apkhazura',
#   'good',
#   'highly',
#   'recommend',
#   'apkhazura',
#   'part',
#   'wish',
#   'meat',
#   'apkhazura',
#   'delicious',
#   'perfect',
#   'combo',
#   'sweet',
#   'smoky',
#   'salty',
#   'food',
#   'get',
#   '4',
#   'star',
#   'feel',
#   'like',
#   'still',
#   'bite',
#   'overprice',
#   'amount',
#   'serve',
#   'wish',
#   'could',
#   'give',
#   'place',
#   'least',
#   'four',
#   'star',
#   'service',
#   'price',
#   'really',
#   'turn',
#   'great',
#   'food',
#   'maybe',
#   'go',
#   'bad',
#   'day',
#   'ton',
#   'people',
#   'take',
#   'day'],
#  ['nice',
#   'ambiance',
#   'set',
#   'order',
#   'share',
#   'adjaruli',
#   'khatchapuri',
#   'lobio',
#   'cheese',
#   'khinkali',
#   'dumplings',
#   'cheese',
#   'boat',
#   'little',
#   'crispier',
#   'taste',
#   'like',
#   'doughey',
#   'lobio',
#   'good',
#   'khinkali',
#   'fill',
#   'runny',
#   'buttery',
#   'highlight',
#   'probably',
#   'medoki',
#   'honey',
#   'cake',
#   'dessert',
#   'good',
#   'take',
#   'another',
#   'star',
#   'service',
#   'kinda',
#   'slow',
#   'inattentive',
#   'even',
#   'though',
#   'barely',
#   'people',
#   'restaurant',
#   '5',
#   'pm',
#   'sure',
#   'id',
#   'come',
#   'back',
#   'since',
#   'georgian',
#   'place',
#   'area'],
#  ['ok',
#   'id',
#   'go',
#   'appetizers',
#   'main',
#   'disappointment',
#   'desserts',
#   'stale',
#   'taste',
#   'overly',
#   'process',
#   'service',
#   'great',
#   'though',
#   'everyone',
#   'nice',
#   'accommodate'],
#  ['far',
#   'one',
#   'best',
#   'restaurants',
#   'nyc',
#   'long',
#   'time',
#   'food',
#   'excellent',
#   'wine',
#   'well',
#   'authentic',
#   'georgian',
#   'restaurant',
#   'serve',
#   'georgian',
#   'cuisine',
#   'honestly',
#   'dont',
#   'remember',
#   'name',
#   'food',
#   'highly',
#   'recommend',
#   'sausage',
#   'khachapuri',
#   'piece',
#   'bread',
#   'cheese',
#   'whole',
#   'stick',
#   'butter',
#   'mix',
#   'inside',
#   'might',
#   'flagship',
#   'dish',
#   'far',
#   'one',
#   'popular',
#   'items',
#   'menu',
#   'lamb',
#   'also',
#   'great',
#   'well',
#   'wine',
#   'excellent',
#   'traditional',
#   'georgian',
#   'amber',
#   'red',
#   'wine',
#   'red',
#   'wine',
#   'call',
#   'pheasants',
#   'tear',
#   'great',
#   'ive',
#   'lot',
#   'different',
#   'foods',
#   'past',
#   'nothing',
#   'like',
#   'ive',
#   'recently',
#   'good',
#   'get',
#   'fresh',
#   'new',
#   'cuisine',
#   'sceneincredible',
#   'experience',
#   'overall',
#   'service',
#   'excellent',
#   'well',
#   'attentive',
#   'favor',
#   'check',
#   'place',
#   'guarantee',
#   'disappoint'],
#  ['love',
#   'nyc',
#   'place',
#   'like',
#   'chama',
#   'mama',
#   'seriously',
#   'else',
#   'us',
#   'probably',
#   'world',
#   'tbh',
#   'go',
#   'able',
#   'georgian',
#   'food',
#   'talk',
#   'atl',
#   'think',
#   'central',
#   'asian',
#   'random',
#   'weeknightin',
#   'case',
#   'race',
#   'palce',
#   'relatively',
#   'new',
#   'definitely',
#   'early',
#   'stage',
#   'jitters',
#   'term',
#   'service',
#   'also',
#   'restaurant',
#   'seattable',
#   'placement',
#   'feel',
#   'sorta',
#   'willynilly',
#   'theyd',
#   'well',
#   'invest',
#   'bite',
#   'restaurant',
#   'interior',
#   'design',
#   'consult',
#   'food',
#   'important',
#   'part',
#   'doesnt',
#   'need',
#   'consultingwhat',
#   'must',
#   'cheese',
#   'bread',
#   'know',
#   'youre',
#   'think',
#   'skip',
#   'calories',
#   'youre',
#   'stupid',
#   'stop',
#   'listen',
#   'get',
#   'one',
#   'breadsother',
#   'standouts',
#   'excellent',
#   'dumplings',
#   'lamb',
#   'grape',
#   'leaf',
#   'starters',
#   'must',
#   'try',
#   'hen',
#   'main',
#   'oh',
#   'goodthe',
#   'one',
#   'thing',
#   'miss',
#   'short',
#   'rib',
#   'reason',
#   'im',
#   'short',
#   'rib',
#   'fan',
#   'dish',
#   'like',
#   'one',
#   'great',
#   'weeknight',
#   'dinner',
#   'try',
#   'georgian',
#   'wine',
#   'youre',
#   'bad',
#   'got',
#   'ta',
#   'love',
#   'nyc'],
#  ['yum',
#   'vegetarian',
#   'problem',
#   'taste',
#   'georgia',
#   'wonderful',
#   'walnut',
#   'jam',
#   'homemade',
#   'feta',
#   'fire',
#   'bean',
#   'stew',
#   'hearty',
#   'pretty',
#   'yum',
#   'unique',
#   'item',
#   'menu',
#   'dumplings',
#   'pretty',
#   'good',
#   'cheese',
#   'heavy',
#   'honestly',
#   'wasnt',
#   'able',
#   'taste',
#   'hazelnut',
#   'might',
#   'bite',
#   'harder',
#   'vegan',
#   'almost',
#   'items',
#   'cheese',
#   'order',
#   'three',
#   'dish',
#   'plus',
#   '30',
#   'bottle',
#   'wine',
#   'come',
#   '90',
#   'tip',
#   'two',
#   'decor',
#   'nice',
#   'cool',
#   'watch',
#   'people',
#   'make',
#   'food',
#   'service',
#   'exceptional',
#   'food',
#   'yum',
#   'recommend',
#   'spot'],
#  ['great',
#   'place',
#   'never',
#   'try',
#   'georgian',
#   'food',
#   'really',
#   'enjoy',
#   'experience',
#   'unique',
#   'item',
#   'definitely',
#   'cheese',
#   'bread',
#   'bake',
#   'fresh',
#   'fill',
#   'brim',
#   'cheese',
#   'butter',
#   'exactly',
#   'healthiest',
#   'delicious',
#   'also',
#   'lambpork',
#   'medallions',
#   'lamb',
#   'stew',
#   'entrees',
#   'cook',
#   'well',
#   'unique',
#   'food',
#   'heavier',
#   'side',
#   'exactly',
#   'place',
#   'vegan',
#   'heart',
#   'healthy',
#   'food',
#   'otherwise',
#   'service',
#   'great',
#   'restaurant',
#   'beautifully',
#   'decorate',
#   'would',
#   'definitely',
#   'come',
#   'back'],
#  ['best',
#   'georgian',
#   'restaurant',
#   'nyc',
#   'far',
#   'great',
#   'customer',
#   'service',
#   'clean',
#   'delicious',
#   'nice',
#   'friendly',
#   'environment',
#   'georgian',
#   'person',
#   'huge',
#   'responsibility',
#   'introduce',
#   'culture',
#   'others',
#   'place',
#   'help',
#   'justify',
#   'expectations',
#   'great',
#   'place',
#   'vegetarians',
#   'georgian',
#   'appetizers',
#   'vegetarian',
#   'super',
#   'delicious',
#   'wine',
#   'fantastic',
#   'georgian',
#   'wine',
#   'recommend',
#   'vine',
#   'ponto',
#   'totally',
#   'recommend',
#   'place'],
#  ['delicious',
#   'salad',
#   'fry',
#   'cheese',
#   'love',
#   'go',
#   'back',
#   'wonderful',
#   'interior',
#   'perfect',
#   'romantic',
#   'date',
#   'meet',
#   'friends',
#   'incredibly',
#   'nice',
#   'friendly',
#   'service'],
#  ['let',
#   'first',
#   'say',
#   'georgian',
#   'food',
#   'come',
#   'possible',
#   'good',
#   'georgian',
#   'food',
#   'fan',
#   'cuisinethat',
#   'say',
#   'felt',
#   'whole',
#   'meal',
#   'lack',
#   'flavor',
#   'detectable',
#   'season',
#   'dish',
#   'order',
#   'get',
#   'taste',
#   'georgia',
#   'one',
#   'cheese',
#   'plate',
#   'extremely',
#   'salty',
#   'cornbread',
#   'dry',
#   'two',
#   'order',
#   'cheese',
#   'nut',
#   'dumplings',
#   'taste',
#   'cheese',
#   'cheese',
#   'boat',
#   'adjaruli',
#   'chvishtari',
#   'none',
#   'food',
#   'wow',
#   'us',
#   'group',
#   'five',
#   'leave',
#   'feel',
#   'barely',
#   'satiate',
#   'price',
#   'bite',
#   'high',
#   'consider',
#   'get',
#   'service',
#   'pretty',
#   'slow',
#   'agree',
#   'would',
#   'go',
#   'back'],
#  ['chama',
#   'mama',
#   'fairly',
#   'new',
#   'neighborhoodits',
#   'warm',
#   'addition',
#   'first',
#   'thing',
#   'catch',
#   'eye',
#   'layout',
#   'restaurant',
#   'give',
#   'tight',
#   'real',
#   'estate',
#   'space',
#   'nyc',
#   'owners',
#   'really',
#   'utilize',
#   'concept',
#   'open',
#   'space',
#   'well',
#   'love',
#   'open',
#   'kitchendespite',
#   'space',
#   'take',
#   'design',
#   'actually',
#   'make',
#   'restaurant',
#   'seem',
#   'spacious',
#   'bright',
#   'light',
#   'natural',
#   'color',
#   'nyc',
#   'restaurants',
#   'tend',
#   'dimmer',
#   'light',
#   'beautiful',
#   'cramp',
#   'bar',
#   'seat',
#   'front',
#   'portion',
#   'larger',
#   'expect',
#   'friend',
#   'could',
#   'eat',
#   'lunch',
#   'basket',
#   'homemade',
#   'bread',
#   'penovani',
#   'youre',
#   'carbs',
#   'cheese',
#   'type',
#   'person',
#   'chama',
#   'mama',
#   'probably',
#   'perfect',
#   'place',
#   'youmight',
#   'add',
#   'service',
#   'onpoint',
#   'managers',
#   'servers',
#   'kind',
#   'type',
#   'attention',
#   'sincerity',
#   'almost',
#   'make',
#   'doubletake',
#   'id',
#   'really',
#   'like',
#   'return',
#   'sit',
#   'bar',
#   'try',
#   'protein',
#   'dish',
#   'point',
#   'cheer'],
#  ['great',
#   'place',
#   'georgian',
#   'restaurant',
#   'someone',
#   'grow',
#   'region',
#   'azerbaijan',
#   'country',
#   'neighbor',
#   'georgia',
#   'familiar',
#   'georgian',
#   'cuisine',
#   'please',
#   'taste',
#   'quality',
#   'overall',
#   'experience',
#   'go',
#   'dinner',
#   '5',
#   'adults',
#   '2',
#   'kid',
#   'friday',
#   'night',
#   'busy',
#   'decor',
#   'modern',
#   'service',
#   'friendly',
#   'attentive',
#   'clay',
#   'oven',
#   'kitchen',
#   'bread',
#   'signature',
#   'khachapuri',
#   'adjaruli',
#   'cheese',
#   'stuff',
#   'dough',
#   'bake',
#   'see',
#   'oven',
#   'glass',
#   'wall',
#   'food',
#   'delicious',
#   'adjaruli',
#   'bake',
#   'dough',
#   'cheese',
#   'egg',
#   'middle',
#   'amaze',
#   'rest',
#   'meals',
#   'order',
#   'khachapuri',
#   'thin',
#   'dough',
#   'stuff',
#   'cheese',
#   'combination',
#   'appetizer',
#   'platter',
#   'megruli',
#   'kharsho',
#   'beef',
#   'short',
#   'rib',
#   'braise',
#   'walnut',
#   'sauce',
#   'shkmeruli',
#   'chicken',
#   'garlic',
#   'creme',
#   'sauce',
#   'chakapuli',
#   'lamb',
#   'tarragon',
#   'sauce',
#   'favorite',
#   'among',
#   'georgian',
#   'dish',
#   'khinkali',
#   'dumplings',
#   'grind',
#   'beef',
#   'pork',
#   'mix',
#   'soup',
#   'broth',
#   'run',
#   'mouth',
#   'bite',
#   'dumpling',
#   'personally',
#   'would',
#   'like',
#   'little',
#   'kick',
#   'traditionally',
#   'often',
#   'serve',
#   'red',
#   'pepper',
#   'flake',
#   'add',
#   'adjika',
#   'spicy',
#   'pepper',
#   'paste',
#   'cane',
#   'bread',
#   'basket',
#   'dumplings',
#   'take',
#   'bite',
#   'trick',
#   'otherwise',
#   'do',
#   'right',
#   'also',
#   'bottle',
#   'georgian',
#   'wine',
#   'great',
#   'character',
#   'due',
#   'traditional',
#   'claybarrel',
#   'age',
#   'kid',
#   'love',
#   'sparkle',
#   'tarragon',
#   'soda',
#   'overall',
#   'great',
#   'restaurant',
#   'different',
#   'cuisine',
#   'experience',
#   'heart',
#   'manhattan'],
#  ['fairly',
#   'new',
#   'edition',
#   'neighbor',
#   'experience',
#   'great',
#   'first',
#   'time',
#   'try',
#   'georgian',
#   'food',
#   'celebrate',
#   'cousins',
#   'birthday',
#   'start',
#   'try',
#   'wine',
#   'flight',
#   'see',
#   'best',
#   'waitress',
#   'recommend',
#   'amber',
#   'wine',
#   'since',
#   'unique',
#   'get',
#   'bottle',
#   'mosmierikakhuri',
#   'carb',
#   'lover',
#   'place',
#   'amaze',
#   'lot',
#   'cheese',
#   'bread',
#   'aka',
#   'khachapuri',
#   'go',
#   'imeruli',
#   'place',
#   'table',
#   'go',
#   'almost',
#   'didnt',
#   'get',
#   'take',
#   'picture',
#   'bread',
#   'make',
#   'fresh',
#   'kitchen',
#   'come',
#   'hot',
#   'cheesy',
#   'center',
#   'apps',
#   'get',
#   'taste',
#   'georgia',
#   'sample',
#   'cold',
#   'plat',
#   'bread',
#   'cheese',
#   'beets',
#   'eggplants',
#   'yogurt',
#   'pepper',
#   'etc',
#   'main',
#   'meal',
#   'decide',
#   'butcher',
#   'choice',
#   'meats',
#   'tender',
#   'pack',
#   'flavor',
#   'food',
#   'service',
#   'great'],
#  ...]
