# %%
import pandas as pd
import nltk
from nltk import punkt
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from math import log, sqrt
import pandas as pd
import numpy as np
import re
# %matplotlib inline
from nltk.tokenize import word_tokenize
from nltk import sent_tokenize
from nltk.corpus import stopwords
stop = set(stopwords.words('english'))
from nltk.stem import WordNetLemmatizer 
from tqdm import tqdm

# %%
lemmatizer = WordNetLemmatizer()

# %%
tokenizer = word_tokenize

# %%
df = pd.read_csv('cleanedManhattanfull.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 price  rating           restaurant_id  \
# 0           0    $$     4.5  ehUuSk5gPTCQmwS_ubgKRA
# 1           1    $$     4.5  ETgJqJHV7BW6pIr9Ox74sA
# 2           2    $$     4.0  nU4XBdvxDABXqZ6CnB8Dig
# 3           3    $$     4.5  jjJc_CrkB2HodEinB6cWww
# 4           4    $$     4.0  C2o3Iw-DXjoUJFgQIbiqkQ
#
#                  restaurant_name  review_count  \
# 0                        Upstate          1788
# 1                         Amélie          2570
# 2  Clinton Street Baking Company          4851
# 3                       LoveMama          4578
# 4                        BoCaphe          1291
#
#                                             review_1  \
# 0  Had a reservation on Saturday night for dinner...
# 1  The food and drinks here are both delicious. W...
# 2  I stopped by here to have brunch on my last da...
# 3  Was here with my boyfriend one Sunday evening ...
# 4  I came here with my friend last Saturday becau...
#
#                                             review_2  \
# 0  While it's not my new go-to place for seafood,...
# 1  My boyfriend took me here for my birthday earl...
# 2  This is probably my favorite brunch in NYC, fe...
# 3  My friend and I checked out LoveMama around 6p...
# 4  We found this restaurant from the review on ye...
#
#                                             review_3  \
# 0  Mehhhhh. Overrated in my opinion.We walked in ...
# 1  We came for our anniversary dinner. I got the ...
# 2  Came here many years ago & tried their famous ...
# 3  We were vacationing in New York and found this...
# 4  I'm surprised this place has such good reviews...
#
#                                             review_4  ... review_130  \
# 0  Unfortunately, dinner here was pretty disappoi...  ...        NaN
# 1  Came here for a light dinner with my friend an...  ...        NaN
# 2  I've heard so much about this place over the y...  ...        NaN
# 3  While this place may look a little dingy and d...  ...        NaN
# 4  When I think of having Vietnamese, I immediate...  ...        NaN
#
#   review_131 review_132 review_133 review_134 review_135 review_136  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   review_137 review_138 review_139
# 0        NaN        NaN        NaN
# 1        NaN        NaN        NaN
# 2        NaN        NaN        NaN
# 3        NaN        NaN        NaN
# 4        NaN        NaN        NaN
#
# [5 rows x 145 columns]

# %%
import string 
def remove_punctuations(text):
    for punctuation in string.punctuation:
        text = text.replace(punctuation, '')
    return text

# %%
rva = ['review_'+ str(x+1) for x in range(139)]

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df = df.fillna(value=str('none'))

# %%
for y in rva:
    df[y] = df[y].apply(remove_punctuations)

# %%
for y in rva:
    df[y] = df[y].apply(lambda x: ' '.join([word.lower() for word in x.split() if word not in (stop)]))

# %%
df.head()
# Out:
#   price  rating           restaurant_id                restaurant_name  \
# 0    $$     4.5  ehUuSk5gPTCQmwS_ubgKRA                        Upstate
# 1    $$     4.5  ETgJqJHV7BW6pIr9Ox74sA                         Amélie
# 2    $$     4.0  nU4XBdvxDABXqZ6CnB8Dig  Clinton Street Baking Company
# 3    $$     4.5  jjJc_CrkB2HodEinB6cWww                       LoveMama
# 4    $$     4.0  C2o3Iw-DXjoUJFgQIbiqkQ                        BoCaphe
#
#    review_count                                           review_1  \
# 0          1788  had reservation saturday night dinner everythi...
# 1          2570  the food drinks delicious we started cocktails...
# 2          4851  i stopped brunch last day nyc good thing i cas...
# 3          4578  was boyfriend one sunday evening i could happi...
# 4          1291  i came friend last saturday wanted go nearby s...
#
#                                             review_2  \
# 0  while new goto place seafood i still liked itc...
# 1  my boyfriend took birthday earlier month it so...
# 2  this probably favorite brunch nyc feel spoiled...
# 3  my friend i checked lovemama around 6pm friday...
# 4  we found restaurant review yelp friend wanted ...
#
#                                             review_3  \
# 0  mehhhhh overrated opinionwe walked reservation...
# 1  we came anniversary dinner i got first caberne...
# 2  came many years ago tried famous maine blueber...
# 3  we vacationing new york found restaurant many ...
# 4  im surprised place good reviews one times i fe...
#
#                                             review_4  \
# 0  unfortunately dinner pretty disappointing mayb...
# 1  came light dinner friend amazing cocktails the...
# 2  ive heard much place years knew notorious long...
# 3  while place may look little dingy dirty dont l...
# 4  when i think vietnamese i immediately refer ct...
#
#                                             review_5  ... review_130  \
# 0  this place overrated would give 2 stars we got...  ...       none
# 1  amelie lively wine bar cheese tapas menu a gre...  ...       none
# 2  met friends high expectations sadly i disappoi...  ...       none
# 3  this place packed friday night dont expect com...  ...       none
# 4  interesting fusion food worth price portions f...  ...       none
#
#   review_131 review_132 review_133 review_134 review_135 review_136  \
# 0       none       none       none       none       none       none
# 1       none       none       none       none       none       none
# 2       none       none       none       none       none       none
# 3       none       none       none       none       none       none
# 4       none       none       none       none       none       none
#
#   review_137 review_138 review_139
# 0       none       none       none
# 1       none       none       none
# 2       none       none       none
# 3       none       none       none
# 4       none       none       none
#
# [5 rows x 144 columns]

# %%
for y in rva:
    df[y] = df[y].apply(lambda x: ' '.join([lemmatizer.lemmatize(word, pos = 'r') for word in x.split()]))

# %%
df.head()
# Out:
#   price  rating           restaurant_id                restaurant_name  \
# 0    $$     4.5  ehUuSk5gPTCQmwS_ubgKRA                        Upstate
# 1    $$     4.5  ETgJqJHV7BW6pIr9Ox74sA                         Amélie
# 2    $$     4.0  nU4XBdvxDABXqZ6CnB8Dig  Clinton Street Baking Company
# 3    $$     4.5  jjJc_CrkB2HodEinB6cWww                       LoveMama
# 4    $$     4.0  C2o3Iw-DXjoUJFgQIbiqkQ                        BoCaphe
#
#    review_count                                           review_1  \
# 0          1788  had reservation saturday night dinner everythi...
# 1          2570  the food drinks delicious we started cocktails...
# 2          4851  i stopped brunch last day nyc good thing i cas...
# 3          4578  was boyfriend one sunday evening i could happi...
# 4          1291  i came friend last saturday wanted go nearby s...
#
#                                             review_2  \
# 0  while new goto place seafood i still liked itc...
# 1  my boyfriend took birthday earlier month it so...
# 2  this probably favorite brunch nyc feel spoiled...
# 3  my friend i checked lovemama around 6pm friday...
# 4  we found restaurant review yelp friend wanted ...
#
#                                             review_3  \
# 0  mehhhhh overrated opinionwe walked reservation...
# 1  we came anniversary dinner i got first caberne...
# 2  came many years ago tried famous maine blueber...
# 3  we vacationing new york found restaurant many ...
# 4  im surprised place good reviews one times i fe...
#
#                                             review_4  \
# 0  unfortunately dinner pretty disappointing mayb...
# 1  came light dinner friend amazing cocktails the...
# 2  ive heard much place years knew notorious long...
# 3  while place may look little dingy dirty dont l...
# 4  when i think vietnamese i immediately refer ct...
#
#                                             review_5  ... review_130  \
# 0  this place overrated would give 2 stars we got...  ...       none
# 1  amelie lively wine bar cheese tapas menu a gre...  ...       none
# 2  met friends high expectations sadly i disappoi...  ...       none
# 3  this place packed friday night dont expect com...  ...       none
# 4  interesting fusion food worth price portions f...  ...       none
#
#   review_131 review_132 review_133 review_134 review_135 review_136  \
# 0       none       none       none       none       none       none
# 1       none       none       none       none       none       none
# 2       none       none       none       none       none       none
# 3       none       none       none       none       none       none
# 4       none       none       none       none       none       none
#
#   review_137 review_138 review_139
# 0       none       none       none
# 1       none       none       none
# 2       none       none       none
# 3       none       none       none
# 4       none       none       none
#
# [5 rows x 144 columns]

# %%
for y in tqdm(rva):
    df['token'+y]= df[y].apply(tokenizer)
# Out:
#   0%|          | 0/139 [00:00<?, ?it/s]
#   1%|          | 1/139 [00:11<27:30, 11.96s/it]
#   1%|▏         | 2/139 [00:27<30:05, 13.18s/it]
#   2%|▏         | 3/139 [00:43<31:08, 13.74s/it]
#   3%|▎         | 4/139 [00:56<30:47, 13.68s/it]
#   4%|▎         | 5/139 [00:58<22:37, 10.13s/it]
#   4%|▍         | 6/139 [01:00<16:55,  7.63s/it]
#   5%|▌         | 7/139 [01:01<12:53,  5.86s/it]
#   6%|▌         | 8/139 [01:03<10:07,  4.64s/it]
#   6%|▋         | 9/139 [01:05<08:10,  3.77s/it]
#   7%|▋         | 10/139 [01:07<06:45,  3.14s/it]
#   8%|▊         | 11/139 [01:08<05:47,  2.71s/it]
#   9%|▊         | 12/139 [01:10<05:04,  2.40s/it]
#   9%|▉         | 13/139 [01:12<04:32,  2.16s/it]
#  10%|█         | 14/139 [01:13<04:13,  2.02s/it]
#  11%|█         | 15/139 [01:15<03:59,  1.93s/it]
#  12%|█▏        | 16/139 [01:17<03:48,  1.86s/it]
#  12%|█▏        | 17/139 [01:18<03:35,  1.76s/it]
#  13%|█▎        | 18/139 [01:20<03:29,  1.73s/it]
#  14%|█▎        | 19/139 [01:22<03:30,  1.75s/it]
#  14%|█▍        | 20/139 [01:23<03:24,  1.72s/it]
#  15%|█▌        | 21/139 [01:25<03:17,  1.68s/it]
#  16%|█▌        | 22/139 [01:27<03:18,  1.69s/it]
#  17%|█▋        | 23/139 [01:28<03:16,  1.69s/it]
#  17%|█▋        | 24/139 [01:30<03:09,  1.65s/it]
#  18%|█▊        | 25/139 [01:32<03:10,  1.67s/it]
#  19%|█▊        | 26/139 [01:33<03:11,  1.70s/it]
#  19%|█▉        | 27/139 [01:35<03:04,  1.65s/it]
#  20%|██        | 28/139 [01:37<03:00,  1.62s/it]
#  21%|██        | 29/139 [01:38<02:57,  1.61s/it]
#  22%|██▏       | 30/139 [01:40<02:56,  1.62s/it]
#  22%|██▏       | 31/139 [01:40<02:15,  1.25s/it]
#  23%|██▎       | 32/139 [01:41<01:46,  1.01it/s]
#  24%|██▎       | 33/139 [01:41<01:25,  1.23it/s]
#  24%|██▍       | 34/139 [01:41<01:13,  1.44it/s]
#  91%|█████████ | 126/139 [02:16<00:03,  3.87it/s]
#  91%|█████████▏| 127/139 [02:17<00:04,  2.49it/s]
#  92%|█████████▏| 128/139 [02:17<00:03,  3.15it/s]
#  93%|█████████▎| 129/139 [02:17<00:02,  3.88it/s]
#  94%|█████████▎| 130/139 [02:17<00:01,  4.65it/s]
#  94%|█████████▍| 131/139 [02:17<00:01,  5.49it/s]
#  95%|█████████▍| 132/139 [02:18<00:01,  6.23it/s]
#  96%|█████████▌| 133/139 [02:18<00:00,  6.57it/s]
#  96%|█████████▋| 134/139 [02:18<00:00,  6.75it/s]
#  97%|█████████▋| 135/139 [02:18<00:00,  7.33it/s]
#  98%|█████████▊| 136/139 [02:18<00:00,  7.52it/s]
#  99%|█████████▊| 137/139 [02:18<00:00,  7.91it/s]
#  99%|█████████▉| 138/139 [02:18<00:00,  8.10it/s]
# 100%|██████████| 139/139 [02:18<00:00,  8.10it/s]

# %%
df.head()
# Out:
#   price  rating           restaurant_id                restaurant_name  \
# 0    $$     4.5  ehUuSk5gPTCQmwS_ubgKRA                        Upstate
# 1    $$     4.5  ETgJqJHV7BW6pIr9Ox74sA                         Amélie
# 2    $$     4.0  nU4XBdvxDABXqZ6CnB8Dig  Clinton Street Baking Company
# 3    $$     4.5  jjJc_CrkB2HodEinB6cWww                       LoveMama
# 4    $$     4.0  C2o3Iw-DXjoUJFgQIbiqkQ                        BoCaphe
#
#    review_count                                           review_1  \
# 0          1788  [ [ ' [ ' ] ,   [ ' [ ' ] ,   [ " ' " ] ,   [ ...
# 1          2570  [ [ ' [ ' ] ,   [ ' [ ' ] ,   [ " ' " ] ,   [ ...
# 2          4851  [ [ ' [ ' ] ,   [ ' [ ' ] ,   [ " ' " ] ,   [ ...
# 3          4578  [ [ ' [ ' ] ,   [ ' [ ' ] ,   [ " ' " ] ,   [ ...
# 4          1291  [ [ ' [ ' ] ,   [ ' [ ' ] ,   [ " ' " ] ,   [ ...
#
#                                             review_2  \
# 0  [ [ ' [ ' ] ,   [ ' [ ' ] ,   [ " ' " ] ,   [ ...
# 1  [ [ ' [ ' ] ,   [ ' [ ' ] ,   [ " ' " ] ,   [ ...
# 2  [ [ ' [ ' ] ,   [ ' [ ' ] ,   [ " ' " ] ,   [ ...
# 3  [ [ ' [ ' ] ,   [ ' [ ' ] ,   [ " ' " ] ,   [ ...
# 4  [ [ ' [ ' ] ,   [ ' [ ' ] ,   [ " ' " ] ,   [ ...
#
#                                             review_3  \
# 0  [ [ ' [ ' ] ,   [ ' [ ' ] ,   [ " ' " ] ,   [ ...
# 1  [ [ ' [ ' ] ,   [ ' [ ' ] ,   [ " ' " ] ,   [ ...
# 2  [ [ ' [ ' ] ,   [ ' [ ' ] ,   [ " ' " ] ,   [ ...
# 3  [ [ ' [ ' ] ,   [ ' [ ' ] ,   [ " ' " ] ,   [ ...
# 4  [ [ ' [ ' ] ,   [ ' [ ' ] ,   [ " ' " ] ,   [ ...
#
#                                             review_4  \
# 0  [ [ ' [ ' ] ,   [ ' [ ' ] ,   [ " ' " ] ,   [ ...
# 1  [ [ ' [ ' ] ,   [ ' [ ' ] ,   [ " ' " ] ,   [ ...
# 2  [ [ ' [ ' ] ,   [ ' [ ' ] ,   [ " ' " ] ,   [ ...
# 3  [ [ ' [ ' ] ,   [ ' [ ' ] ,   [ " ' " ] ,   [ ...
# 4  [ [ ' [ ' ] ,   [ ' [ ' ] ,   [ " ' " ] ,   [ ...
#
#                                             review_5  ... tokenreview_130  \
# 0  [ [ ' t h i s ' ] ,   [ ' p l a c e ' ] ,   [ ...  ...          [none]
# 1  [ [ ' a m e l i e ' ] ,   [ ' l i v e l y ' ] ...  ...          [none]
# 2  [ [ ' m e t ' ] ,   [ ' f r i e n d s ' ] ,   ...  ...          [none]
# 3  [ [ ' t h i s ' ] ,   [ ' p l a c e ' ] ,   [ ...  ...          [none]
# 4  [ [ ' i n t e r e s t i n g ' ] ,   [ ' f u s ...  ...          [none]
#
#   tokenreview_131 tokenreview_132 tokenreview_133 tokenreview_134  \
# 0          [none]          [none]          [none]          [none]
# 1          [none]          [none]          [none]          [none]
# 2          [none]          [none]          [none]          [none]
# 3          [none]          [none]          [none]          [none]
# 4          [none]          [none]          [none]          [none]
#
#   tokenreview_135 tokenreview_136 tokenreview_137 tokenreview_138  \
# 0          [none]          [none]          [none]          [none]
# 1          [none]          [none]          [none]          [none]
# 2          [none]          [none]          [none]          [none]
# 3          [none]          [none]          [none]          [none]
# 4          [none]          [none]          [none]          [none]
#
#   tokenreview_139
# 0          [none]
# 1          [none]
# 2          [none]
# 3          [none]
# 4          [none]
#
# [5 rows x 283 columns]
