# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import nltk
from nltk import punkt
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from math import log, sqrt
import pandas as pd
import numpy as np
import re
# %matplotlib inline
from nltk.tokenize import word_tokenize
from nltk import sent_tokenize
from nltk.corpus import stopwords
stop = set(stopwords.words('english'))
from nltk.stem import WordNetLemmatizer 
from tqdm import tqdm
pd.options.display.max_columns = 999

# %%
lemmatizer = WordNetLemmatizer()

# %%
tokenizer = word_tokenize

# %%
df = pd.read_csv('cleanedManhattanfull.csv')

# %%
import string 
def remove_punctuations(text):
    for punctuation in string.punctuation:
        text = text.replace(punctuation, '')
    return text

# %%
df.head()
# Out:
#    Unnamed: 0 price  rating           restaurant_id  \
# 0           0    $$     4.5  ehUuSk5gPTCQmwS_ubgKRA
# 1           1    $$     4.5  ETgJqJHV7BW6pIr9Ox74sA
# 2           2    $$     4.0  nU4XBdvxDABXqZ6CnB8Dig
# 3           3    $$     4.5  jjJc_CrkB2HodEinB6cWww
# 4           4    $$     4.0  C2o3Iw-DXjoUJFgQIbiqkQ
#
#                  restaurant_name  review_count  \
# 0                        Upstate          1788
# 1                         Amélie          2570
# 2  Clinton Street Baking Company          4851
# 3                       LoveMama          4578
# 4                        BoCaphe          1291
#
#                                             review_1  \
# 0  Had a reservation on Saturday night for dinner...
# 1  The food and drinks here are both delicious. W...
# 2  I stopped by here to have brunch on my last da...
# 3  Was here with my boyfriend one Sunday evening ...
# 4  I came here with my friend last Saturday becau...
#
# ...

# %% [markdown]
# ## Sample Run

# %%
sample = df.iloc[0:1]

# %%
sample

# %%
sampledrop = ['review_'+str(x) for x in range(125,140)]

# %%
sampledrop

# %%
sample.drop(columns=sampledrop, axis=1, inplace=True)

# %%
sample

# %%
sample.drop(columns=['Unnamed: 0', 'price', 'rating', 'restaurant_id', 'review_count'], axis=1, inplace=True)

# %%
sample

# %%
rva = ['review_'+ str(x+1) for x in range(124)]

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df = df.fillna(value=str('none'))

# %%
df.drop(columns=rva, inplace=True)

# %%
sample.drop(columns=rva, inplace=True)

# %%
sample.head()

# %%
sample.drop(columns=['restaurant_name'], inplace=True)

# %%
sample.head()

# %%
for y in rva:
    sample[y] = sample[y].apply(remove_punctuations)

# %%
for y in rva:
    sample[y] = sample[y].apply(lambda x: ' '.join([word.lower() for word in x.split() if word not in (stop)]))

# %%
sample.head()

# %%
for y in rva:
    sample[y] = sample[y].apply(lambda x: ' '.join([lemmatizer.lemmatize(word, pos = 'r') for word in x.split()]))

# %%
df.head()

# %%
for y in tqdm(rva):
    sample['token_'+y]= sample[y].apply(tokenizer)

# %%
sample.head()

# %%
sample.values

# %%
import numpy as np
tokenslist = sample.values.tolist()

# %%
print(len(tokenslist[0][10]))

# %%
tokenslist

# %%
#FUNCTION TO FLATTEN TOKEN LIST

def flatten( alist ):
     newlist = []
     for item in alist:
         if isinstance(item, list):
             newlist = newlist + flatten(item)
         else:
             newlist.append(item)
     return newlist

# %%
flattoken = flatten(tokenslist)

# %%
print(len(flattoken))

# %%
flattoken

# %%
import gensim
from gensim import corpora
dictionary = corpora.Dictionary(sample.values[0])

doc_term_matrix = [dictionary.doc2bow(doc) for doc in sample.values[0]]

# %%
# Creating the object for LDA model using gensim library
Lda = gensim.models.ldamodel.LdaModel

# Running and Trainign LDA model on the document term matrix.
ldamodel = Lda(doc_term_matrix, num_topics=10, id2word = dictionary, passes=100)

# %%
print(ldamodel.print_topics(num_topics=10, num_words=10))

# %% [markdown]
# ## Full Run

# %%
rva

# %%
rva = ['review_'+ str(x+1) for x in range(139)]

# %%
rem = ['review_'+ str(x+1) for x in range(124, 139)]

# %%
df = df.fillna(value=str('none'))

# %%
df.drop(columns=['Unnamed: 0', 'price', 'rating', 'restaurant_id', 'review_count'], axis=1, inplace=True)

# %%
for y in rva:
    df[y] = df[y].apply(remove_punctuations)

# %%
for y in rva:
    df[y] = df[y].apply(lambda x: ' '.join([word.lower() for word in x.split() if word.lower() not in (stop)]))

# %%
for y in tqdm(rva):
    df[y] = df[y].apply(lambda x: ' '.join([lemmatizer.lemmatize(word, pos = 'r') for word in x.split()]))

# %%
for y in tqdm(rva):
    df['token_'+y]= df[y].apply(tokenizer)

# %%
df.head()

# %%
df.drop(columns=rva, inplace=True)

# %%
df.drop(columns=['restaurant_name'], axis=1, inplace=True)

# %%
df.head()

# %%
tokenslist = df.values.tolist()

# %%
len(tokenslist)

# %%
type(tokenslist)

# %%
df.head()

# %%
df['token_review_129'][0]

# %%
temp = []
for row in tokenslist:
    if len(row) > 1:
        temp.extend(row)
#remove below line for full run        
# temp = temp[0:50] + temp[1000:1100]

# %%
def deleting(list_1,del_name):
    for sub_list in tqdm(list_1):
        if del_name in sub_list:
            list_1.remove(sub_list)
    return list_1

deleting(temp, 'none')

# %%
temp

# %% [markdown]
# ### Full Run Corpus

# %%
import gensim
from gensim import corpora
dictionary = corpora.Dictionary(temp)
dictionary.filter_extremes(no_below=10, no_above=0.5, keep_n=8000)
doc_term_matrix = [dictionary.doc2bow(doc) for doc in temp]

# %% [markdown]
# ### Full Run LDA

# %%
# Creating the object for LDA model using gensim library
Lda = gensim.models.ldamodel.LdaModel

# Running and Trainign LDA model on the document term matrix.
ldamodel = Lda(doc_term_matrix, num_topics=10, per_word_topics=True, id2word = dictionary, passes=100, random_state=12)

# %%
ldamodel.print_topics(num_topics=10, num_words=10)

# %%
# Creating the object for LDA model using gensim library
Lda = gensim.models.ldamodel.LdaModel

# Running and Trainign LDA model on the document term matrix.
ldamodel2 = Lda(doc_term_matrix, num_topics=10, per_word_topics=True, id2word = dictionary, passes=100, random_state=15)

# %%
ldamodel2.print_topics(num_topics=10, num_words=20)

# %%
# Creating the object for LDA model using gensim library
Lda = gensim.models.ldamodel.LdaModel

# Running and Trainign LDA model on the document term matrix.
ldamodel3 = Lda(doc_term_matrix, num_topics=10, per_word_topics=True, id2word = dictionary, passes=100, random_state=15)

# %%
ldamodel3.print_topics(num_topics=10, num_words=20)

# %% [markdown]
# ### Full Run Multi-Core LDA

# %%
lda_modelmulti = gensim.models.LdaMulticore(doc_term_matrix, num_topics=10, id2word=dictionary, passes=2, workers=2)

# %%
lda_modelmulti.print_topics(num_topics=10, num_words=20)

# %%
lda_modelmulti2 = gensim.models.LdaMulticore(doc_term_matrix, num_topics=10, id2word=dictionary, passes=2, workers=2)

# %%
lda_modelmulti2.print_topics(num_topics=10, num_words=20)

# %%
words_to_ignore = ['lamb', 'pork', 'beef', 'chicken', 'duck', 'oyster', 'clam', 'clams', 'oysters', 'cheese', 'eggs', 'bacon', 'pizza']

# %%
lda_modelmulti3 = gensim.models.LdaMulticore(doc_term_matrix, num_topics=10, alpha='asymmetric', id2word=dictionary, passes=30, workers=2)

# %%
lda_modelmulti3.print_topics(num_topics=10, num_words=20)

# %% [markdown]
# ## Service Only Run

# %%
df = pd.read_csv('reviews_manhattan.csv')

# %%
df.head()
# Out:
#    Unnamed: 0           Restaurant_Id  \
# 0           0  ehUuSk5gPTCQmwS_ubgKRA
# 1           1  ehUuSk5gPTCQmwS_ubgKRA
# 2           2  ehUuSk5gPTCQmwS_ubgKRA
# 3           3  ehUuSk5gPTCQmwS_ubgKRA
# 4           4  ehUuSk5gPTCQmwS_ubgKRA
#
#                                               Review
# 0  Had a reservation on Saturday night for dinner...
# 1  While it's not my new go-to place for seafood,...
# 2  Mehhhhh. Overrated in my opinion.We walked in ...
# 3  Unfortunately, dinner here was pretty disappoi...
# 4  This place is overrated, i would give only 2 s...

# %%
df = df.fillna(value=str('none'))

# %%
df.drop(columns=['Unnamed: 0', 'Restaurant_Id'], axis=1, inplace=True)

# %%
df['Review'] = df['Review'].apply(remove_punctuations)

# %%
df['Review'] = df['Review'].apply(lambda x: ' '.join([word.lower() for word in x.split() if word.lower() not in (stop)]))

# %%
df1 = df[df['Review'].str.contains('service')]

# %%
df['Review'] = df['Review'].apply(lambda x: ' '.join([lemmatizer.lemmatize(word, pos = 'v') for word in x.split()]))

# %%
df1.head()
# Out:
#                                                Review
# 2   mehhhhh overrated opinionwe walked reservation...
# 9   hearing tons rave spot finally decided give tr...
# 10  quick recap seafood food general awesome atmos...
# 12  unheard trifecta cheap tasting seafoodthe seaf...
# 17  spot oysters relaxed vibe drink work date serv...

# %%
df1['token_Review']= df1['Review'].apply(tokenizer)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df1.drop(columns=['Review'], axis=1, inplace=True)
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
tokenslist = df1.values.tolist()

# %%
temp = []
for row in tokenslist:
    if type(row) == list:
        temp.extend(row)

# %%
temp
# Out:
# [['mehhhhh',
#   'overrated',
#   'opinionwe',
#   'walked',
#   'reservation',
#   'prob',
#   'shouldnt',
#   'given',
#   'hype',
#   'surrounding',
#   'place',
#   'lucky',
#   'enough',
#   'get',
#   'table',
#   'given',
#   'time',
#   'limit',
#   'long',
#   'could',
#   'stay',
#   'big',
#   'deal',
#   'oysters',
#   'fresh',
#   'delicious',
#   'service',
#   'standard',
#   'waiter',
#   'knowledgeable',
#   'overall',
#   'unmemorable',
#   'mediocre',
#   'dining',
#   'experiencemaybe',
#   'missed',
#   'something'],
#  ['hearing',
#   'tons',
#   'people',
#   'rave',
#   'spot',
#   'ive',
#   'finally',
#   'decided',
#   'give',
#   'try',
#   'ive',
#   'actually',
#   'back',
#   'second',
#   'time',
#   'definitely',
#   'puts',
#   'restaurant',
#   'bring',
#   'people',
#   'youd',
#   'like',
#   'impress',
#   'list',
#   'personally',
#   'dont',
#   'eat',
#   'oysters',
#   'know',
#   'please',
#   'dont',
#   'stone',
#   'nonetheless',
# ...

# %%
def deleting(list_1,del_name):
    for sub_list in tqdm(list_1):
        if del_name in sub_list:
            list_1.remove(sub_list)
    return list_1

deleting(temp, 'none')
# Out:
#  99%|█████████▉| 37415/37799 [00:00<00:00, 55667.39it/s]
# [['mehhhhh',
#   'overrated',
#   'opinionwe',
#   'walked',
#   'prob',
#   'shouldnt',
#   'given',
#   'hype',
#   'surrounding',
#   'lucky',
#   'enough',
#   'given',
#   'limit',
#   'long',
#   'stay',
#   'big',
#   'deal',
#   'oysters',
#   'fresh',
#   'service',
#   'standard',
#   'waiter',
#   'knowledgeable',
#   'overall',
#   'unmemorable',
#   'mediocre',
#   'dining',
#   'experiencemaybe',
#   'missed',
#   'something'],
#  ['hearing',
#   'tons',
#   'rave',
#   'finally',
#   'decided',
#   'give',
#   'try',
#   'actually',
#   'second',
#   'puts',
#   'bring',
#   'youd',
#   'impress',
#   'list',
#   'personally',
#   'eat',
#   'oysters',
#   'please',
#   'stone',
#   'nonetheless',
#   'freaking',
#   'deal',
#   'hours',
#   'additionally',
#   'someone',
#   'doesnt',
#   'actually',
#   'seafood',
#   'seafood',
#   'generally',
#   'gets',
#   'thumbs',
#   'octopus',
#   'flavorful',
# ...

# %%
temp

# %%
import gensim
from gensim import corpora
dictionary = corpora.Dictionary(temp)
dictionary.filter_extremes(no_below=10, no_above=0.5, keep_n=8000)
doc_term_matrix = [dictionary.doc2bow(doc) for doc in temp]

# %%
# Creating the object for LDA model using gensim library
Lda = gensim.models.ldamodel.LdaModel

# Running and Trainign LDA model on the document term matrix.
ldamodel = Lda(doc_term_matrix, num_topics=10, per_word_topics=True, id2word = dictionary, passes=100, random_state=42)

# %%
ldamodel.print_topics(num_topics=10, num_words=10)

# %%
stops = ['sauce', 'sweet', 'seating', 'lunch', 'menu', 'stars', 'quality', 'nothing', 'worth', 'reservation', 'recommend', 'spot', 'happy', 'everything', 'cooked', 'bread', 'outside', 'tables', 'location', 'mac', 'course', 'made', 'never', 'another', 'know', 'take', 'korean', 'french', 'italian', 'sauce', 'area', ]

# %%
morestopwords = ['even', 'said', 'took', 'people', 'could', 'wait', 'first', 'always', 'go', 'love', 'new', 'im', 'come', 'favorite', 'times', 'excellent', 'night','hour', 'pretty', 'bit', 'small', 'little', 'though', 'much', 'think', 'better', 'quite', 'spicy','side']

# %%
# Creating the object for LDA model using gensim library
Lda = gensim.models.ldamodel.LdaModel

# Running and Trainign LDA model on the document term matrix.
ldamodel2 = Lda(doc_term_matrix, num_topics=10, per_word_topics=True, id2word = dictionary, passes=100, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-68fea668265e> in <module>
#       3
#       4 # Running and Trainign LDA model on the document term matrix.
# ----> 5 ldamodel2 = Lda(doc_term_matrix, num_topics=10, per_word_topics=True, id2word = dictionary, passes=100, random_state=42)
#
# /anaconda3/lib/python3.7/site-packages/gensim/models/ldamodel.py in __init__(self, corpus, num_topics, id2word, distributed, chunksize, passes, update_every, alpha, eta, decay, offset, eval_every, iterations, gamma_threshold, minimum_probability, random_state, ns_conf, minimum_phi_value, per_word_topics, callbacks, dtype)
#     517         if corpus is not None:
#     518             use_numpy = self.dispatcher is not None
# --> 519             self.update(corpus, chunks_as_numpy=use_numpy)
#     520
#     521     def init_dir_prior(self, prior, name):
#
# ...

# %%
ldamodel2.print_topics(num_topics=10, num_words=10)

# %%
morestop = ['time', 'definitely', 'would', 'delicious', 'dont', 'dish', 'ordered', 'table', 'place', 'nice', 'bar', 'also', 'came', 'great', 'good', 'amazing', 'restaurant', 'really', 'well', 'bad', 'minutes', 'nice', 'back', 'best', 'ive', 'like','dont','get', 'us', 'came', 'order','minutes','one', 'asked', 'got', 'didnt']

# %%
stop.update(morestop)

# %%
stop.update(morestopwords)

# %%
stop.update(stops)
