# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import nltk
from nltk import punkt
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from math import log, sqrt
import pandas as pd
import numpy as np
import re
# %matplotlib inline
from nltk.tokenize import word_tokenize
from nltk import sent_tokenize
from nltk.corpus import stopwords
stop = set(stopwords.words('english'))
from nltk.stem import WordNetLemmatizer 
from tqdm import tqdm
pd.options.display.max_columns = 999

# %%
lemmatizer = WordNetLemmatizer()

# %%
stops = ['sauce', 'sweet', 'seating', 'lunch', 'menu', 'stars', 'quality', 'nothing', 'worth', 'reservation',
         'recommend', 'spot', 'happy', 'everything', 'cooked', 'bread', 'outside', 'tables', 'location', 'mac', 
         'course', 'made', 'never', 'another', 'know', 'take', 'korean', 'french', 'italian', 'sauce', 'area', ]

# %%
morestopwords = ['even', 'said', 'took', 'people', 'could', 'wait', 'first', 'always', 'go', 'love', 'new', 'im', 
                 'come', 'favorite', 'times', 'excellent', 'night','hour', 'pretty', 'bit', 'small', 'little', 
                 'though', 'much', 'think', 'better', 'quite', 'spicy','side']

# %%
morestop = ['time', 'definitely', 'would', 'delicious', 'dont', 'dish', 'ordered', 'table', 'place', 'nice', 
            'bar', 'also', 'came', 'great', 'good', 'amazing', 'restaurant', 'really', 'well', 'bad', 'minutes', 
            'nice', 'back', 'best', 'ive', 'like','dont','get', 'us', 'came', 'order','minutes','one', 'asked', 
            'got', 'didnt']

# %%
stop.update(stops)

# %%
stop.update(morestop)

# %%
stop.update(morestopwords)

# %%
stop.update(newstop)

# %%
stop.update(newnewstop)

# %%
stop.update(anotherstop)

# %%
stop.update(morestops)

# %%
tokenizer = word_tokenize

# %%
df = pd.read_csv('cleanedManhattanfull.csv')

# %%
import string 
def remove_punctuations(text):
    for punctuation in string.punctuation:
        text = text.replace(punctuation, '')
    return text

# %%
df.head()

# %% [markdown]
# ## Sample Run

# %%
sample = df.iloc[0:1]

# %%
sample

# %%
sampledrop = ['review_'+str(x) for x in range(125,140)]

# %%
sampledrop

# %%
sample.drop(columns=sampledrop, axis=1, inplace=True)

# %%
sample

# %%
sample.drop(columns=['Unnamed: 0', 'price', 'rating', 'restaurant_id', 'review_count'], axis=1, inplace=True)

# %%
sample

# %%
rva = ['review_'+ str(x+1) for x in range(124)]

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df = df.fillna(value=str('none'))

# %%
df.drop(columns=rva, inplace=True)

# %%
sample.drop(columns=rva, inplace=True)

# %%
sample.head()

# %%
sample.drop(columns=['restaurant_name'], inplace=True)

# %%
sample.head()

# %%
for y in rva:
    sample[y] = sample[y].apply(remove_punctuations)

# %%
for y in rva:
    sample[y] = sample[y].apply(lambda x: ' '.join([word.lower() for word in x.split() if word not in (stop)]))

# %%
sample.head()

# %%
for y in rva:
    sample[y] = sample[y].apply(lambda x: ' '.join([lemmatizer.lemmatize(word, pos = 'r') for word in x.split()]))

# %%
df.head()

# %%
for y in tqdm(rva):
    sample['token_'+y]= sample[y].apply(tokenizer)

# %%
sample.head()

# %%
sample.values

# %%
import numpy as np
tokenslist = sample.values.tolist()

# %%
print(len(tokenslist[0][10]))

# %%
tokenslist

# %%
#FUNCTION TO FLATTEN TOKEN LIST

def flatten( alist ):
     newlist = []
     for item in alist:
         if isinstance(item, list):
             newlist = newlist + flatten(item)
         else:
             newlist.append(item)
     return newlist

# %%
flattoken = flatten(tokenslist)

# %%
print(len(flattoken))

# %%
flattoken

# %%
import gensim
from gensim import corpora
dictionary = corpora.Dictionary(sample.values[0])

doc_term_matrix = [dictionary.doc2bow(doc) for doc in sample.values[0]]

# %%
# Creating the object for LDA model using gensim library
Lda = gensim.models.ldamodel.LdaModel

# Running and Trainign LDA model on the document term matrix.
ldamodel = Lda(doc_term_matrix, num_topics=10, id2word = dictionary, passes=100)

# %%
print(ldamodel.print_topics(num_topics=10, num_words=10))

# %% [markdown]
# ## Full Run

# %%
rva

# %%
rva = ['review_'+ str(x+1) for x in range(139)]

# %%
rem = ['review_'+ str(x+1) for x in range(124, 139)]

# %%
df = df.fillna(value=str('none'))

# %%
df.drop(columns=['Unnamed: 0', 'price', 'rating', 'restaurant_id', 'review_count'], axis=1, inplace=True)

# %%
for y in rva:
    df[y] = df[y].apply(remove_punctuations)

# %%
for y in rva:
    df[y] = df[y].apply(lambda x: ' '.join([word.lower() for word in x.split() if word.lower() not in (stop)]))

# %%
for y in tqdm(rva):
    df[y] = df[y].apply(lambda x: ' '.join([lemmatizer.lemmatize(word, pos = 'r') for word in x.split()]))

# %%
for y in tqdm(rva):
    df['token_'+y]= df[y].apply(tokenizer)

# %%
df.head()

# %%
df.drop(columns=rva, inplace=True)

# %%
df.drop(columns=['restaurant_name'], axis=1, inplace=True)

# %%
df.head()

# %%
tokenslist = df.values.tolist()

# %%
len(tokenslist)

# %%
type(tokenslist)

# %%
df.head()

# %%
df['token_review_129'][0]

# %%
temp = []
for row in tokenslist:
    if len(row) > 1:
        temp.extend(row)
#remove below line for full run        
# temp = temp[0:50] + temp[1000:1100]

# %%
def deleting(list_1,del_name):
    for sub_list in tqdm(list_1):
        if del_name in sub_list:
            list_1.remove(sub_list)
    return list_1

deleting(temp, 'none')

# %%
temp

# %% [markdown]
# ### Full Run Corpus

# %%
import gensim
from gensim import corpora
dictionary = corpora.Dictionary(temp)
dictionary.filter_extremes(no_below=10, no_above=0.5, keep_n=8000)
doc_term_matrix = [dictionary.doc2bow(doc) for doc in temp]

# %% [markdown]
# ### Full Run LDA

# %%
# Creating the object for LDA model using gensim library
Lda = gensim.models.ldamodel.LdaModel

# Running and Trainign LDA model on the document term matrix.
ldamodel = Lda(doc_term_matrix, num_topics=10, per_word_topics=True, id2word = dictionary, passes=100, random_state=12)

# %%
ldamodel.print_topics(num_topics=10, num_words=10)

# %%
# Creating the object for LDA model using gensim library
Lda = gensim.models.ldamodel.LdaModel

# Running and Trainign LDA model on the document term matrix.
ldamodel2 = Lda(doc_term_matrix, num_topics=10, per_word_topics=True, id2word = dictionary, passes=100, random_state=15)

# %%
ldamodel2.print_topics(num_topics=10, num_words=20)

# %%
# Creating the object for LDA model using gensim library
Lda = gensim.models.ldamodel.LdaModel

# Running and Trainign LDA model on the document term matrix.
ldamodel3 = Lda(doc_term_matrix, num_topics=10, per_word_topics=True, id2word = dictionary, passes=100, random_state=15)

# %%
ldamodel3.print_topics(num_topics=10, num_words=20)

# %% [markdown]
# ### Full Run Multi-Core LDA

# %%
lda_modelmulti = gensim.models.LdaMulticore(doc_term_matrix, num_topics=10, id2word=dictionary, passes=2, workers=2)

# %%
lda_modelmulti.print_topics(num_topics=10, num_words=20)

# %%
lda_modelmulti2 = gensim.models.LdaMulticore(doc_term_matrix, num_topics=10, id2word=dictionary, passes=2, workers=2)

# %%
lda_modelmulti2.print_topics(num_topics=10, num_words=20)

# %%
words_to_ignore = ['lamb', 'pork', 'beef', 'chicken', 'duck', 'oyster', 'clam', 'clams', 'oysters', 'cheese', 'eggs', 'bacon', 'pizza']

# %%
lda_modelmulti3 = gensim.models.LdaMulticore(doc_term_matrix, num_topics=10, alpha='asymmetric', id2word=dictionary, passes=30, workers=2)

# %%
lda_modelmulti3.print_topics(num_topics=10, num_words=20)

# %% [markdown]
# ## Service Only Run

# %%
df = pd.read_csv('reviews_manhattan.csv')

# %%
df.head()
# Out:
#    Unnamed: 0           Restaurant_Id  \
# 0           0  ehUuSk5gPTCQmwS_ubgKRA
# 1           1  ehUuSk5gPTCQmwS_ubgKRA
# 2           2  ehUuSk5gPTCQmwS_ubgKRA
# 3           3  ehUuSk5gPTCQmwS_ubgKRA
# 4           4  ehUuSk5gPTCQmwS_ubgKRA
#
#                                               Review
# 0  Had a reservation on Saturday night for dinner...
# 1  While it's not my new go-to place for seafood,...
# 2  Mehhhhh. Overrated in my opinion.We walked in ...
# 3  Unfortunately, dinner here was pretty disappoi...
# 4  This place is overrated, i would give only 2 s...

# %%
df = df.fillna(value=str('none'))

# %%
df.drop(columns=['Unnamed: 0', 'Restaurant_Id'], axis=1, inplace=True)

# %%
df['Review'] = df['Review'].apply(remove_punctuations)

# %%
df['Review'] = df['Review'].apply(lambda x: ' '.join([word.lower() for word in x.split() if word.lower() not in (stop)]))

# %%
df1 = df[df['Review'].str.contains('service')]

# %%
df['Review'] = df['Review'].apply(lambda x: ' '.join([lemmatizer.lemmatize(word, pos = 'v') for word in x.split()]))

# %%
df1['token_Review']= df1['Review'].apply(tokenizer)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df1.drop(columns=['Review'], axis=1, inplace=True)
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
tokenslist = df1.values.tolist()

# %%
temp = []
for row in tokenslist:
    if type(row) == list:
        temp.extend(row)

# %%
def deleting(list_1,del_name):
    for sub_list in tqdm(list_1):
        if del_name in sub_list:
            list_1.remove(sub_list)
    return list_1

deleting(temp, 'none')
# Out:
#  99%|█████████▉| 37415/37799 [00:00<00:00, 83610.01it/s]
# [['mehhhhh',
#   'overrated',
#   'opinionwe',
#   'prob',
#   'shouldnt',
#   'given',
#   'hype',
#   'surrounding',
#   'lucky',
#   'given',
#   'limit',
#   'stay',
#   'deal',
#   'oysters',
#   'service',
#   'standard',
#   'waiter',
#   'knowledgeable',
#   'unmemorable',
#   'mediocre',
#   'experiencemaybe',
#   'missed'],
#  ['oysters',
#   'please',
#   'stone',
#   'nonetheless',
#   'freaking',
#   'deal',
#   'hours',
#   'additionally',
#   'someone',
#   'doesnt',
#   'generally',
#   'gets',
#   'thumbs',
#   'octopus',
#   'soft',
#   'pass',
#   'escargot',
#   'risotto',
#   'fettuccine',
#   'scallops',
#   'dry',
#   'clams',
#   'creamy',
#   'eating',
#   'soon',
#   'possible',
#   'wouldnt',
#   'cold',
#   'reason',
#   'teeny',
#   'tiny',
#   'tune',
#   'service',
#   'affected',
#   'terms',
#   'efficiency',
#   'mind',
#   'please'],
#  ['quick',
#   'recap',
#   'food',
#   'general',
#   'atmosphere',
#   'service',
#   'food',
#   'biggest',
#   'peak',
#   'hours',
#   'grab',
#   'quick',
#   'healthier',
#   'food',
#   'pleasantly',
#   'surprised',
#   'seared',
#   'tuna',
#   'greens',
#   'mashed',
#   'potatoes',
#   'heaven',
#   'near',
#   'bartender',
#   'let',
#   'sample',
#   'oysters',
#   'already',
#   'phenomenal',
#   'ambiance',
#   'food',
#   'notch',
#   'service'],
#  ['unheard',
#   'trifecta',
#   'cheap',
#   'seafoodthe',
#   'prepared',
#   'excellently',
#   'thoughtfully',
#   'put',
#   'together',
#   'rich',
#   'plates',
#   'heavy',
#   'handed',
#   'value',
#   'itoverall',
#   '44',
#   'food',
#   '44',
#   'service',
#   '48',
#   '30',
#   'value',
#   '45fettuccine',
#   'clams',
#   'entree',
#   'pasta',
#   'al',
#   'dente',
#   'heartily',
#   'coated',
#   'garlic',
#   'oil',
#   'clams',
#   'similarly',
#   'dressed',
#   'happen',
#   'garlic',
#   'butter',
#   'found',
#   'seafoodey',
#   'flavored',
#   'pasta',
#   'dishfish',
#   'atlantic',
#   'swordfish',
#   'fingerling',
#   'potatoes',
#   'broccoli',
#   'brussels',
#   'sprouts',
#   'swordfish',
#   'mild',
#   'seasoned',
#   'finished',
#   'lemon',
#   'sriracha',
#   'butter',
#   'fish',
#   'soft',
#   'packing',
#   'bright',
#   'rich',
#   'complementary',
#   'potatoes',
#   'broccoli',
#   'brussels',
#   'sprouts',
#   'getting',
#   'picked',
#   'lemon',
#   'sriracha',
#   'butter',
#   'sides',
#   'todiefor',
#   'broccoli',
#   'bites',
#   'decently',
#   'heavy',
#   'butter',
#   'hence',
#   'deliciousness',
#   'sideshonorable',
#   'mention',
#   'sampled',
#   'girlfriends',
#   'tuna',
#   'wasabi',
#   'mashed',
#   'potatoes',
#   'bok',
#   'choy',
#   'coriander',
#   'reduction',
#   'tuna',
#   'exquisitely',
#   'highlight',
#   'fat',
#   'slabs',
#   'tuna',
#   'nicely',
#   'seared',
#   'coriander',
#   'reduction',
#   'slightly',
#   'tropical',
#   'bright',
#   'butter',
#   'wasabi',
#   'potatoes',
#   'earthy',
#   'wasabi',
#   'flavorthe',
#   'waitstaff',
#   'exceptional',
#   'helping',
#   'decisions',
#   'explanations',
#   'thoughts',
#   'cramped',
#   'easy',
#   'vil',
#   'holesinthewall',
#   'uncomfortable',
#   'value',
#   'spent',
#   '60',
#   'entrees',
#   'alllllll',
#   'catch',
#   'biases',
#   'mid20s',
#   'male',
#   'mean',
#   'tooth',
#   'desire',
#   'amounts',
#   'food',
#   'appreciation',
#   'highquality',
#   'food',
#   'experiences',
#   'value',
#   'food',
#   'priority'],
#  ['oysters', 'relaxed', 'work', 'service', 'oysters'],
#  ['disappointed',
#   'upstate',
#   'awhile',
#   'expectations',
#   'choice',
#   'slowly',
#   'fizzled',
#   'major',
#   'disappointmentlets',
#   'thing',
#   'liked',
#   'oysters',
#   'put',
#   'upstate',
#   'radar',
#   'obsessed',
#   'oysters',
#   'dozen',
#   'six',
#   'six',
#   'waiters',
#   'recommendations',
#   'expected',
#   'sensational',
#   'seemed',
#   'race',
#   'keep',
#   'ones',
#   'less',
#   'enthused',
#   'likes',
#   'cull',
#   'pistol',
#   'crave',
#   'sonny',
#   'nearby',
#   'score',
#   'higher',
#   'hourthe',
#   'ambience',
#   'expected',
#   'thing',
#   'given',
#   'minimalist',
#   'site',
#   'design',
#   'upscale',
#   'expected',
#   'fit',
#   'look',
#   'delightful',
#   'surprise',
#   'hole',
#   'extremely',
#   'freezer',
#   'store',
#   'food',
#   'serve',
#   'extremely',
#   'upscale',
#   'offerings',
#   'extremely',
#   'reasonable',
#   'prices',
#   'starters',
#   'tuna',
#   'tartar',
#   'deliciousbut',
#   'astray',
#   'service',
#   'quickly',
#   'became',
#   'blah',
#   'service',
#   'blah',
#   'hes',
#   'awhile',
#   'motionsi',
#   'octopus',
#   'hubby',
#   'marrow',
#   'scallopsthe',
#   'octopus',
#   'burnt',
#   'charred',
#   'charred',
#   'remnants',
#   'burned',
#   'building',
#   'inedible',
#   'jayson',
#   'send',
#   'longer',
#   'necessary',
#   'octopus',
#   'hated',
#   'couldnt',
#   'itthe',
#   'marrow',
#   'omg',
#   'obsessionthe',
#   'scallops',
#   'eh',
#   'jayson',
#   'loves',
#   'scallops',
#   'excited',
#   'somewhere',
#   'ones',
#   'lacklusterin',
#   'realize',
#   'spent',
#   '100',
#   'food',
#   'either',
#   'blah',
#   'edible',
#   'racing',
#   'anytime',
#   'soon'],
#  ['early',
#   'beat',
#   'crowd',
#   'dozen',
#   'oysters',
#   'tuna',
#   'tartare',
#   'fetticini',
#   'clams',
#   'softshell',
#   'crabseverything',
#   'fetticini',
#   'clams',
#   'stood',
#   'rich',
#   'buttery',
#   'clams',
#   'might',
#   'slightly',
#   'salty',
#   'nitpick',
#   'softshell',
#   'crab',
#   'couscous',
#   'care',
#   'couscous',
#   'softshell',
#   'crab',
#   'beer',
#   'selections',
#   'funktown',
#   'white',
#   'ale',
#   'beer',
#   'strong',
#   'cucumber',
#   'service',
#   'waiter',
#   'quick',
#   'polite',
#   'food',
#   'fast',
#   'ordering',
#   'fetticini',
#   'clams'],
#  ['goodness',
#   'start',
#   'boyfriend',
#   'ate',
#   'tonight',
#   'immensely',
#   'satisfied',
#   'start',
#   'service',
#   'efficient',
#   'atmosphere',
#   'relaxing',
#   'crab',
#   'cakes',
#   'bed',
#   'mixed',
#   'greens',
#   'carrots',
#   'corn',
#   'tomatoes',
#   'marrow',
#   'smeared',
#   'toasted',
#   'points',
#   'seared',
#   'scallops',
#   'cauliflower',
#   'purée',
#   'blend',
#   'complimented',
#   'lastly',
#   'shared',
#   'surf',
#   'turf',
#   'steak',
#   'melted',
#   'mouth',
#   'potatoes',
#   'yet',
#   'soft',
#   'shrimp',
#   'server',
#   'whiskey',
#   'house',
#   'moist',
#   'againthanks',
#   'phenomenal',
#   'food',
#   'experience'],
#  ['upstate',
#   'knows',
#   'gets',
#   'service',
#   'staff',
#   'advice',
#   'oysters',
#   'revolving',
#   'beer',
#   'keeps',
#   'later',
#   'hungry',
#   'gauntlet',
#   'oysters',
#   'regular',
#   'unless',
#   'alone'],
#  ['13th',
#   'moon',
#   'service',
#   'downright',
#   'rude',
#   'barked',
#   'orders',
#   'fill',
#   'piece',
#   'paper',
#   'oysters',
#   'broken',
#   'pencil',
#   'doesnt',
#   'write',
#   'tried',
#   'waiters',
#   'attention',
#   'ignored',
#   'asians',
#   'discriminated',
#   'especially',
#   'hospitable',
#   'caucasian',
#   'guests',
#   'curtly',
#   'talking',
#   'rude',
#   'service',
#   'put',
#   'mouth',
#   'spending',
#   'money',
#   'racist',
#   'unprofessional',
#   'establishments',
#   'sir',
#   'unpleasant',
#   'experience'],
#  ['description',
#   'focused',
#   'lots',
#   'beer',
#   '6',
#   'oysters',
#   'beer',
#   '12',
#   'service',
#   'quickly',
#   'job',
#   'considering',
#   'manage',
#   'fit',
#   'atmosphere',
#   'dimply',
#   'lit',
#   'friendsdate',
#   'families',
#   'items',
#   'fettuccine',
#   'clams',
#   'tried',
#   'salty',
#   'pasta',
#   'clams',
#   'todays',
#   'scallop',
#   'scallops',
#   'mushroom',
#   'risotto',
#   'yummy',
#   'flavoring',
#   'octopus',
#   'risotto',
#   'charred',
#   'mean',
#   'char',
#   'housecured',
#   'sockeye',
#   'salmon',
#   'salmon',
#   'salty',
#   'type',
#   'food',
#   'oysters',
#   'subtle',
#   'difference'],
#  ['cohort',
#   'picked',
#   'oblige',
#   'cater',
#   'toward',
#   'shellfish',
#   'case',
#   'havent',
#   'figured',
#   'devour',
#   'anything',
#   'seafoodmoving',
#   'cali',
#   'sauv',
#   'blanc',
#   'compliment',
#   'variety',
#   'partake',
#   'coast',
#   'oysters',
#   'regular',
#   'price',
#   'impeccably',
#   'surprising',
#   'ceviche',
#   'looked',
#   'anything',
#   'simple',
#   'marvelousthe',
#   'tuna',
#   'tartar',
#   'subtle',
#   'yet',
#   'oysters',
#   'chucked',
#   'perfection',
#   'indulged',
#   'cowboy',
#   'komosomething',
#   'huge',
#   'creamy',
#   'least',
#   'faveservice',
#   'attentive',
#   'intrusive',
#   'rushed',
#   'thursday',
#   '730pm',
#   'wete',
#   'cheerio'],
#  ['nighttime',
#   'surprise',
#   'queen',
#   'experience',
#   'keep',
#   'adventure',
#   'goingupstate',
#   'choice',
#   '4th',
#   'oneand',
#   'without',
#   'doubt',
#   'waswhile',
#   'heading',
#   'checked',
#   'via',
#   'seem',
#   'got',
#   'ta',
#   'grab',
#   'logic',
#   'completely',
#   'forgot',
#   'lolscooped',
#   'work',
#   'hopped',
#   'cab',
#   'followed',
#   'checkin',
#   'confirmation',
#   'upstate',
#   'hmm',
#   'respond',
#   'thought',
#   'closer',
#   'closer',
#   'closer',
#   'sht',
#   'turned',
#   'crap',
#   'fix',
#   'keeping',
#   'calm',
#   'spoiling',
#   'mom',
#   'taught',
#   'follow',
#   'already',
#   'enroute',
#   'turning',
#   'crowd',
#   '7',
#   'cold',
#   'werent',
#   'past',
#   'informed',
#   'maître',
#   'promising',
#   'response',
#   'backed',
#   'stance',
#   'conviction',
#   'getting',
#   'turned',
#   'check',
#   '30mins',
#   'returned',
#   '27',
#   'guess',
#   'dfinally',
#   'began',
#   'peruse',
#   'menuat',
#   'least',
#   'began',
#   'already',
#   'knew',
#   'swordfish',
#   'john',
#   'luke',
#   'gentlemans',
#   'service',
#   'forte',
#   'rundown',
#   'oysters',
#   'suggestions',
#   'pair',
#   'beer',
#   'queen',
#   'began',
#   'red',
#   'planned',
#   'finish',
#   'white',
#   'ipa',
#   'route',
#   'turned',
#   'wise',
#   'choices',
#   'amazingly',
#   'delicioushouse',
#   'curse',
#   'salmon',
#   'lightly',
#   'covered',
#   'onions',
#   'capers',
#   'sided',
#   'whole',
#   'grain',
#   'mustard',
#   'traditional',
#   'baguette',
#   'combination',
#   'genius',
#   'start',
#   'john',
#   'luke',
#   'kept',
#   'offering',
#   'oysters',
#   'kept',
#   'declining',
#   'thinking',
#   'trying',
#   'upsell',
#   'case',
#   'keep',
#   'readingour',
#   'entrees',
#   'thing',
#   'hit',
#   'heavenly',
#   'smellmind',
#   'already',
#   'john',
#   'dairy',
#   'opted',
#   'substitutions',
#   'swordfish',
#   'comes',
#   'creamy',
#   'mashed',
#   'potatoes',
#   'extra',
#   'taters',
#   'mix',
#   'veggies',
#   'worked',
#   'looked',
#   'swordfish',
#   'seasoned',
#   'exceptionally',
#   'potatoes',
#   'touch',
#   'lemon',
#   'juice',
#   'queen',
#   'tuna',
#   'immediately',
#   'jealous',
#   'looked',
#   'fish',
#   'melted',
#   'knife',
#   'gleeful',
#   'smile',
#   'devouring',
#   'lolthats',
#   'foodiewithafro',
#   'accepted',
#   'johns',
#   'offer',
#   'oysterswe',
#   'suggestion',
#   'blue',
#   'island',
#   '9',
#   'gildden',
#   'blue',
#   'whale',
#   'eachthe',
#   'setup',
#   'impressive',
#   'blue',
#   'whales',
#   'meals',
#   'within',
#   'ideally',
#   '6',
#   'starter',
#   'plan',
#   'entree',
#   'afterwards',
#   'otherwise',
#   '12',
#   'dozen',
#   'babies',
#   'anything',
#   'except',
#   'whaleget',
#   'less',
#   'whales',
#   'someone',
#   'foolishly',
#   'devoured',
#   'share',
#   'carefully',
#   'decorated',
#   'ultimate',
#   'flavoragain',
#   'jealous',
#   'forget',
#   'add',
#   'complimentary',
#   'slices',
#   'whiskey',
#   'received',
#   'afterwards',
#   'delishafter',
#   'meals',
#   'gone',
#   'tummies',
#   'road',
#   'glanced',
#   'noticed',
#   'enjoying',
#   'experience',
#   'either',
#   'means',
#   'conversation',
#   'food',
#   'gives',
#   'general',
#   'sense',
#   'calm',
#   'welcoming',
#   'turned',
#   'added',
#   'released',
#   'public',
#   'soon',
#   'food',
#   '55service',
#   '55ambiance',
#   '55wait',
#   '455',
#   'utilize',
#   'online',
#   'booking',
#   'plzstaff',
#   '55',
#   'helpfultalking',
#   'johnprice',
#   '55freshness',
#   'oysters',
#   '55cash',
#   'credit',
#   'happily',
#   'accepted',
#   'herewait',
#   'waitalmost',
#   'forgot',
#   'tunes',
#   'yo',
#   'john',
#   'choice',
#   'vibin'],
#  ['ohhh',
#   'update',
#   'minus',
#   'b',
#   'health',
#   'scorereally',
#   'service',
#   'tastes',
#   'beer',
#   'without',
#   'asking',
#   'brews',
#   'variety',
#   'prices',
#   'andor',
#   'man',
#   'john'],
#  ['service',
#   'tastes',
#   'beer',
#   'without',
#   'asking',
#   'brews',
#   'variety',
#   'prices',
#   'andor',
#   'man',
#   'john'],
#  ['spectacular',
#   'lovers',
#   'food',
#   'portioned',
#   'prices',
#   'fair',
#   'environment',
#   'oysters',
#   '12',
#   'mentioned',
#   'near',
#   'reviewi',
#   'opportunity',
#   'superb',
#   'naturally',
#   'dozen',
#   'oysters',
#   'kind',
#   'available',
#   'disappointed',
#   'marlin',
#   'crudo',
#   'creme',
#   'fraiche',
#   'counter',
#   'balance',
#   'seemed',
#   'soy',
#   'based',
#   'marinade',
#   'fish',
#   'octopus',
#   'bed',
#   'risotto',
#   'truffle',
#   'oil',
#   'fish',
#   'wellthe',
#   'service',
#   'staff',
#   'spectacular',
#   'particular',
#   'john',
#   'working',
#   'seatedthis',
#   'easily',
#   'joint'],
#  ['didntprosfriendly',
#   'servicecute',
#   'interior',
#   'atmosphere',
#   'darkgreat',
#   'vinho',
#   'verdo',
#   'portuguese',
#   'white',
#   'easy',
#   'byconsfood',
#   'mushroomrice',
#   'flavoura',
#   'pricey',
#   'qualityworth'],
#  ['remotely',
#   'close',
#   'favor',
#   'upstate',
#   'food',
#   'service',
#   'match',
#   'prices',
#   'reasonable',
#   'thought',
#   'midwest',
#   'honestly',
#   'upstate'],
#  ['omg',
#   'oysters',
#   'gnocchi',
#   'tuna',
#   'tartare',
#   'yum',
#   'tiny',
#   'early',
#   'hh',
#   'deal',
#   'service'],
#  ['salted',
#   'giving',
#   'amazingsmall',
#   'assuming',
#   'early',
#   'lucky',
#   'seat',
#   'crab',
#   'cakes',
#   'kind',
#   'crab',
#   'cakes',
#   'shredded',
#   'crab',
#   'fillers',
#   'followed',
#   'scallops',
#   'mushroom',
#   'risotto',
#   'scallops',
#   'totally',
#   'salted',
#   'otherwise',
#   'mushroom',
#   'risotto',
#   'pale',
#   'ale',
#   'refreshing',
#   'monk',
#   'fish',
#   'flaky',
#   'fish',
#   'scallops',
#   'excessively',
#   'salted',
#   'service',
#   'ill'],
#  ['food',
#   'oysters',
#   '55',
#   'shucked',
#   'stray',
#   'shells',
#   'strange',
#   'fishy',
#   'mix',
#   'coast',
#   'oysters',
#   'thoroughly',
#   'local',
#   'oysters',
#   'island',
#   'oyster',
#   'bars',
#   'plates',
#   'scallops',
#   'w',
#   'mushroom',
#   'risotto',
#   'shrimp',
#   'sea',
#   'urchin',
#   'butter',
#   'crab',
#   'cakes',
#   'underwhelming',
#   '35the',
#   '55',
#   'beer',
#   'bartender',
#   'introduced',
#   'grüner',
#   'veltliner',
#   'dry',
#   'white',
#   'austria',
#   'alternative',
#   'sauvignon',
#   'blancthe',
#   'service',
#   '55',
#   'service',
#   'bartender',
#   'shane',
#   'attentive',
#   'knowledgeable',
#   'oysters',
#   'staff',
#   'members',
#   'wellupstate',
#   'chill',
#   'intimate',
#   'casual',
#   'catch',
#   'oysters',
#   'service'],
#  ['legit',
#   'add',
#   '1hr',
#   'corner',
#   'toward',
#   'soo',
#   'hungry',
#   'ready',
#   'knowledgeable',
#   'gentleman',
#   'recommended',
#   'dozen',
#   'oysters',
#   'selectioni',
#   'let',
#   'decide',
#   'uber',
#   'yum',
#   'running',
#   'joke',
#   'easily',
#   '12',
#   'dozen',
#   'oysters',
#   'without',
#   'problem',
#   'coast',
#   'oysters',
#   'entree',
#   'selected',
#   'tuna',
#   'steak',
#   'w',
#   'mashed',
#   'potatoes',
#   'ehvaehva',
#   'least',
#   'whiskey',
#   'seals',
#   'deal',
#   'please',
#   'customer',
#   'service',
#   'food',
#   'worthy'],
#  ['especially',
#   'oysters',
#   'selections',
#   'scallops',
#   'huge',
#   'scallop',
#   'meatynote',
#   'goooodenivornment',
#   'dim',
#   'tiny',
#   'elbow',
#   'elbow',
#   'cozyprice',
#   'service'],
#  ['upstate',
#   'upscale',
#   'serve',
#   'eclectic',
#   'oysters',
#   'rotating',
#   'beerswines',
#   'array',
#   'appetizers',
#   'entrees',
#   'service',
#   'consistently',
#   'refilling',
#   'fast',
#   'ordering',
#   'quick',
#   'serving',
#   'etc',
#   'feels',
#   'fashioned',
#   'sea',
#   'food',
#   'limited',
#   '20m',
#   'queue',
#   'seatsoverall',
#   'impressed',
#   'foodorderedshigoku',
#   'wa',
#   'briney',
#   'oysters',
#   'ocean',
#   'consistent',
#   'tier',
#   'oyster',
#   'barsbarnstable',
#   'cape',
#   'cod',
#   'fattier',
#   'meatier',
#   'crunchymontauke',
#   'pearl',
#   'montauke',
#   'lake',
#   'cleancrisp',
#   'roundeddarbee',
#   'irresistible',
#   'pale',
#   'ale',
#   'unfiltered',
#   'pa',
#   'aromatic',
#   'bitter',
#   'palette',
#   'cleansersoft',
#   'shell',
#   'crab',
#   'comes',
#   'cous',
#   'cous',
#   'nicely',
#   'saltedseasoned',
#   'crunch',
#   'entreescallops',
#   'seared',
#   'seasoned',
#   'mushroom',
#   'risotto',
#   'solid',
#   'dishuni',
#   'comes',
#   'puree',
#   'plated',
#   'raw',
#   'egg',
#   'onions',
#   'roe',
#   'eaten',
#   'weakest'],
#  ['honestly',
#   'beat',
#   '12',
#   'half',
#   'dozen',
#   'oyster',
#   'beer',
#   'husband',
#   'checked',
#   'bookmarks',
#   'longest',
#   'monday',
#   'luckily',
#   'hostess',
#   'waiter',
#   'hand',
#   'menus',
#   'already',
#   'knew',
#   'oysters',
#   'part',
#   'additional',
#   '12',
#   'hh',
#   'deal',
#   'forgot',
#   'paired',
#   'tuna',
#   'tartar',
#   'share',
#   '12',
#   'oysters',
#   'tuna',
#   'tartar',
#   'service',
#   'guys',
#   'shucking',
#   'oysters',
#   'ambiance',
#   'itll',
#   'hard',
#   'saw',
#   '6',
#   'sitting',
#   'four',
#   'seater',
#   'look',
#   'comfy',
#   'hh',
#   'heard',
#   'pasta',
#   'based',
#   'return',
#   'tr'],
#  ['excited',
#   'based',
#   'pros',
#   'oysters',
#   'beer',
#   'oysters',
#   'service',
#   'waiter',
#   'helped',
#   'decide',
#   'getcons',
#   'rest',
#   'food',
#   'ciopinno',
#   'fettuccine',
#   'clams',
#   'underwhelming',
#   'food',
#   'lacked',
#   'clams',
#   'ciopinno',
#   'chewy',
#   'spit',
#   'piece',
#   'shell',
#   'muscles',
#   'ciopinno',
#   'oysters'],
#  ['tldr',
#   'upstate',
#   'goto',
#   'service',
#   'complimentary',
#   'touchmy',
#   'oysters',
#   'sizable',
#   '275',
#   'pop',
#   'nonhappy',
#   'pricy',
#   'totally',
#   'hourin',
#   'terms',
#   'entrees',
#   'fettuccine',
#   'clams',
#   'salty',
#   'huge',
#   'meaty',
#   'clams',
#   'creamy',
#   'hungry',
#   'shared',
#   'less',
#   'hungry',
#   'complimentary',
#   'pound',
#   'check',
#   'touch'],
#  ['service', 'environment', 'chicken', 'collards', 'idk', 'hummus', 'ate'],
#  ['honestly',
#   'food',
#   'outstanding',
#   'surf',
#   'turf',
#   'fettuccine',
#   'clams',
#   'outstanding',
#   'service',
#   'appreciated',
#   'beer',
#   'musttry'],
#  ['experiences',
#   'absolute',
#   'loversi',
#   'girlfriend',
#   'year',
#   'anniversary',
#   'huge',
#   'fans',
#   'upstate',
#   'delivered',
#   'mealtheir',
#   'half',
#   'dozen',
#   'oysters',
#   'plus',
#   '12',
#   'beer',
#   '16',
#   'deal',
#   'solid',
#   'tried',
#   'three',
#   'available',
#   'oysters',
#   'hh',
#   'three',
#   'prince',
#   'edward',
#   'island',
#   'oysters',
#   'particular',
#   'heard',
#   'black',
#   'trout',
#   'item',
#   'please',
#   'thing',
#   'trout',
#   'essentially',
#   'thin',
#   'crispier',
#   'version',
#   'salmon',
#   'tomato',
#   'almostpuréed',
#   'gnocchi',
#   'crab',
#   'cakes',
#   'legitimately',
#   'ones',
#   'soggy',
#   'excess',
#   'greens',
#   'pure',
#   'crab',
#   'entrees',
#   'mahi',
#   'steak',
#   'simple',
#   'hit',
#   'service',
#   'phenomenal',
#   'dimmer',
#   'quaint',
#   'ambiance',
#   'kind',
#   'datei',
#   'can',
#   'not',
#   'upstate',
#   'needs',
#   'cheers'],
#  ['daytime',
#   '630pmwait',
#   '1',
#   'hourseating',
#   'plenty',
#   'availableservice',
#   'prompt',
#   'friendlydrinks',
#   'beer',
#   'food',
#   'halfdozen',
#   'oysters',
#   'crab',
#   'cakes',
#   'tuna',
#   'tartare',
#   'charred',
#   'octopus',
#   'scallop',
#   'mushroom',
#   'risotto',
#   'complimentary',
#   'pound',
#   'touch',
#   'smaller',
#   'venue',
#   'expected',
#   'intimate',
#   'someone',
#   'bellies',
#   'brim',
#   'crab',
#   'cakes',
#   'tuna',
#   'tartare',
#   'octopus',
#   'chewy',
#   'scallop',
#   'mushroom',
#   'risotto'],
#  ['experience',
#   'provide',
#   'realistic',
#   'account',
#   '15',
#   'disheartening',
#   'saw',
#   'saw',
#   'avow',
#   'found',
#   'ambience',
#   'dark',
#   'intimate',
#   'conversations',
#   'dates',
#   'groups',
#   'easy',
#   'balance',
#   'bookbags',
#   'coat',
#   'suggest',
#   'elsewhere',
#   'shopping',
#   'spree',
#   'bag',
#   'placeent',
#   'waiters',
#   'downtoearth',
#   'revisit',
#   'due',
#   'level',
#   'service',
#   'kumamota',
#   'raw',
#   'oysters',
#   'coast',
#   'oysters',
#   'others',
#   'life',
#   'changed',
#   'planning',
#   'speak'],
#  ['showcases',
#   'highlights',
#   'seasonality',
#   'look',
#   'girlfriends',
#   'sundays',
#   'opens',
#   '5pm',
#   'opens',
#   'limited',
#   'sitting',
#   'atmosphere',
#   'rustic',
#   'air',
#   'literally',
#   'food',
#   'deal',
#   '6',
#   'oysters',
#   'craft',
#   'beer',
#   '12',
#   'pay',
#   'extra',
#   'instead',
#   'oysters',
#   'fettuccine',
#   'clams',
#   'divine',
#   'pasta',
#   'blend',
#   'garlic',
#   'olive',
#   'oil',
#   'parmesan',
#   'coating',
#   'honorable',
#   'mentions',
#   'crab',
#   'cakes',
#   'soft',
#   'crab',
#   'charred',
#   'squid',
#   'salad',
#   'mmm',
#   'squid',
#   'service',
#   'attentive',
#   'knowledgeable'],
#  ['oysters',
#   'service',
#   'prices',
#   'arent',
#   'terrible',
#   'especially',
#   'steak',
#   'surf',
#   'turf',
#   'chewy',
#   'scallops',
#   'chance',
#   '6',
#   'oysters',
#   'beer',
#   '12'],
#  ['servicei',
#   'liked',
#   'appetizers',
#   'entrees',
#   '57',
#   '6',
#   'oysters',
#   'beer',
#   '12',
#   'solid',
#   'deal',
#   'escargot',
#   'uni',
#   'dieone',
#   'less',
#   'dark',
#   'totally',
#   'mom',
#   'getting',
#   'older',
#   'dark',
#   'problem'],
#  ['upstate',
#   'bookmarked',
#   'minute',
#   'chance',
#   'cousin',
#   'somewhat',
#   'lowkey',
#   'speakeasy',
#   'tour',
#   'death',
#   'co',
#   'pdt',
#   'angels',
#   'share',
#   'etc',
#   'disappointed',
#   'number',
#   'incorrectly',
#   'either',
#   'pasta',
#   'clams',
#   'seems',
#   'goto',
#   'cousins',
#   'cousin',
#   'scallops',
#   'upstate',
#   'credit',
#   'credit',
#   'due',
#   'particularly',
#   'inexpensive',
#   'acknowledged',
#   'positive',
#   'needed',
#   'found',
#   'pasta',
#   'uninspired',
#   'clams',
#   'incredibly',
#   'chewy',
#   'somewhat',
#   'temperature',
#   'cousins',
#   'exactly',
#   'cousin',
#   'blown',
#   'scallops',
#   'food',
#   'easily',
#   '35',
#   'atrocious',
#   'wouldnt',
#   'far',
#   'call',
#   'taking',
#   'extra',
#   'despite',
#   'werent',
#   'ton',
#   'service',
#   'slower',
#   'timed',
#   'close',
#   'pasta',
#   'almost',
#   'server',
#   'food',
#   'used',
#   'work',
#   'nobodys',
#   'faultbut',
#   'pork',
#   'chop',
#   'done',
#   'typical',
#   'bumfck',
#   'hole',
#   'narrow',
#   'cramped',
#   'exceptional',
#   'beer',
#   'anything',
#   'complimentary',
#   'pound',
#   'touch',
#   'pasta',
#   'cheap',
#   'grocery',
#   'store',
#   'pound',
#   'grandmas',
#   'nursing',
#   'potluck',
#   'tldr',
#   'eventually',
#   'disappointed',
#   'return'],
#  ['forward',
#   'meet',
#   'deal',
#   'oysters',
#   'beer',
#   'price',
#   'oysters',
#   'oysters',
#   'regards',
#   '45',
#   'discuss',
#   'food',
#   'impressed',
#   'anything',
#   'memorable',
#   'seasonal',
#   'fettuccine',
#   'clams',
#   'cioppino',
#   'fact',
#   'opinion',
#   'fettuccine',
#   'slightly',
#   'al',
#   'dente',
#   'topped',
#   'clams',
#   'buttery',
#   'garlic',
#   'type',
#   'cheese',
#   'lover',
#   'clams',
#   'butter',
#   'garlic',
#   'pair',
#   'claims',
#   'pasta',
#   'cioppino',
#   'huge',
#   'miss',
#   'missing',
#   'present',
#   'cioppino',
#   'lots',
#   'clams',
#   'mussels',
#   'shrimp',
#   'fish',
#   'tomato',
#   'based',
#   'broth',
#   'lacking',
#   'dip',
#   'disappointed',
#   'food',
#   'hungry',
#   'finished',
#   'food',
#   'save',
#   'service',
#   'waiters',
#   'asap',
#   'wave'],
#  ['simply',
#   'become',
#   'cherry',
#   'use',
#   'creekstone',
#   'beef',
#   'halal',
#   'alert',
#   'disclaimer',
#   'got',
#   'ta',
#   'tapa',
#   'style',
#   'skip',
#   'entrees',
#   'load',
#   'appetizers',
#   'oysters',
#   'maine',
#   'vinegar',
#   'lemon',
#   'watermelon',
#   'gazpacho',
#   'underwhelming',
#   'especially',
#   'nights',
#   'mercado',
#   'spain',
#   'jose',
#   'andres',
#   'hudson',
#   'yards',
#   'held',
#   'glob',
#   'pistachio',
#   'crusted',
#   'goat',
#   'cheese',
#   'stole',
#   'show',
#   'honestly',
#   'subsequent',
#   'upped',
#   'previous',
#   'ultimately',
#   'culminating',
#   'explosion',
#   'cold',
#   'delight',
#   'molten',
#   'lava',
#   'handsdown',
#   'country',
#   'add',
#   'fact',
#   'customize',
#   'whatever',
#   'gelato',
#   'comes',
#   'swirl',
#   'strawberry',
#   'creme',
#   'anglais',
#   '65',
#   'temperate',
#   'optimized',
#   'desert',
#   'cappuccino',
#   'pallet',
#   'cleanser',
#   'dessetthat',
#   'mediocre',
#   'creme',
#   'brûlée',
#   'chocolate',
#   'mousse',
#   'advise',
#   'beef',
#   'tartare',
#   'halal',
#   'ratioed',
#   'winner',
#   'cheeses',
#   'general',
#   'winners',
#   'burrata',
#   'solid',
#   '45',
#   'traveled',
#   'far',
#   'wide',
#   'burratadefinitely',
#   'ambience',
#   'girls',
#   'prices',
#   'affordable',
#   'environment',
#   'service',
#   'worthy',
#   'three'],
#  ['visited',
#   'letting',
#   'early',
#   'failed',
#   'service',
#   'guy',
#   'initially',
#   'seem',
#   'disappointed',
#   'early',
#   'less',
#   'food',
#   'chicken',
#   'liver',
#   'pate',
#   'beef',
#   'tartare',
#   'foie',
#   'gra',
#   'seems',
#   'ago',
#   'escargot',
#   'warning',
#   'traditional',
#   'garlic',
#   'butter',
#   'parsley',
#   'mussels',
#   'liked',
#   'hopefully',
#   'experience'],
#  ['truly',
#   'experience',
#   'amelie',
#   'greeted',
#   'maître',
#   'knew',
#   'vis',
#   'convenient',
#   'option',
#   'chose',
#   'window',
#   'extensive',
#   'diverse',
#   'couldnt',
#   'decide',
#   'funky',
#   'red',
#   'flight',
#   'settled',
#   'mostly',
#   'apps',
#   'cauliflower',
#   'fig',
#   'jam',
#   'ravioli',
#   'share',
#   'app',
#   'delightful',
#   'surprise',
#   'raviolis',
#   'foie',
#   'gras',
#   'octopus',
#   'half',
#   'chicken',
#   'sharing',
#   'ordering',
#   'appetizers',
#   'sample',
#   'service',
#   'timely',
#   'close',
#   'together',
#   'problem',
#   'allonly',
#   'negative',
#   'volume',
#   'hear',
#   'talk',
#   'without',
#   'leaning',
#   'halfway',
#   'someone',
#   'chose',
#   'turn',
#   'louder',
#   'completely',
#   'needed',
#   'conversation'],
#  ['bomb',
#   'eric',
#   'manager',
#   'champagne',
#   'start',
#   'burgundy',
#   'cheesehe',
#   'kept',
#   'glasses',
#   'hourthe',
#   'food',
#   'escargot',
#   'tuna',
#   'tartare',
#   'duck',
#   'confit',
#   'wow',
#   'snapper',
#   'foie',
#   'gras',
#   'um',
#   'cheese',
#   'selectionthe',
#   'service',
#   'hey'],
#  ['flight',
#   'disappointed',
#   'comes',
#   '6',
#   'waiter',
#   'clearly',
#   'selections',
#   'mussels',
#   'exception',
#   'let',
#   'part',
#   'dip',
#   'soup',
#   'mussels',
#   'tastes',
#   'life',
#   'hack',
#   'similar',
#   'getting',
#   'hints',
#   'smoke',
#   'cherry',
#   'getting',
#   'wasted',
#   'planned',
#   'comes',
#   'fries',
#   'dip',
#   'service',
#   'waiter'],
#  ['marvelous',
#   'scrumptious',
#   'rose',
#   'boot',
#   'cheese',
#   'divine',
#   'caliber',
#   'cheese',
#   'assortment',
#   'animal',
#   'milks',
#   'partner',
#   'croquettes',
#   'escargot',
#   'frisee',
#   'salad',
#   'poached',
#   'eggs',
#   'asparagus',
#   'endeavor',
#   'aioli',
#   'looked',
#   'homemade',
#   'rich',
#   'lastly',
#   'important',
#   'service',
#   'team',
#   'taking',
#   'care',
#   'pleasant',
#   'knowledgeable',
#   'marvelous',
#   'care',
#   'booked',
#   'weeks',
#   'care',
#   'without',
#   'interrupting',
#   'huge',
#   'advocate',
#   'regularly',
#   'return',
#   'use',
#   'parents',
#   'hard',
#   'pressed',
#   'fall',
#   'head',
#   'heels'],
#  ['sucker',
#   'bistro',
#   'style',
#   'food',
#   'lots',
#   'genre',
#   'choose',
#   'amelie',
#   'bank',
#   'parisian',
#   'bistro',
#   '8th',
#   'eatery',
#   'gets',
#   'marks',
#   'leap',
#   'faith',
#   'chose',
#   'town',
#   'pleased',
#   'food',
#   'brusque',
#   'service',
#   'impossibly',
#   'endless',
#   'chatter',
#   'house',
#   'conversation',
#   'required',
#   'yelling',
#   'carny',
#   'barkers',
#   'ideal',
#   'relaxing',
#   'friendsthe',
#   'shared',
#   'servings',
#   'escargots',
#   'shelled',
#   'classic',
#   'parsleygarlicbutter',
#   'gratinee',
#   'globules',
#   'seasoned',
#   'melt',
#   'mouth',
#   'mop',
#   'gratis',
#   'crusty',
#   'baguettes',
#   'sip',
#   'burgundy',
#   'france',
#   'forget',
#   'deafening',
#   'joint',
#   'duck',
#   'leg',
#   'confit',
#   'classically',
#   'prepared',
#   'soggy',
#   'flavorless',
#   'potato',
#   'slices',
#   'duck',
#   'marred',
#   'presentationmussels',
#   'leek',
#   'pedestrian',
#   'several',
#   'unopened',
#   'dead',
#   'mildly',
#   'distressing',
#   'lamb',
#   'burger',
#   'nicely',
#   'charred',
#   'chef',
#   'recommended',
#   'toasted',
#   'baguette',
#   'instead',
#   'brioche',
#   'bun',
#   'advertised',
#   'server',
#   'ran',
#   'buns',
#   'suggested',
#   'baguette',
#   'work',
#   'gum',
#   'tearing',
#   'teeth',
#   'rattling',
#   'chewing',
#   'toasted',
#   'baguettes',
#   'work',
#   'onion',
#   'soup',
#   'salad',
#   'croutons',
#   'vessels',
#   'lamb',
#   'burgershanger',
#   'steak',
#   'frites',
#   'eggs',
#   'honest',
#   'interpretation',
#   'shoestring',
#   'frites',
#   'trio',
#   'sauces',
#   'charcuterie',
#   'cheese',
#   'platter',
#   'choice',
#   '33',
#   'bucks',
#   'satisfying',
#   'instance',
#   'crusty',
#   'baguette',
#   'match',
#   'especially',
#   'liked',
#   'pheasant',
#   'pate',
#   'duck',
#   'rilette',
#   'alongside',
#   'stinky',
#   'cheeses',
#   'contrasts',
#   'wish',
#   'selectionsamelie',
#   'offers',
#   'plenty',
#   'choice',
#   'including',
#   'house',
#   'absinthe',
#   'rye',
#   'whiskey',
#   'powered',
#   'sazeracs',
#   'reminded',
#   'missed',
#   'classic',
#   'south',
#   'france',
#   'combo',
#   'else',
#   'quaffed',
#   'seemed',
#   'choicestop',
#   'limited',
#   '12',
#   'flights',
#   'supported',
#   'runs',
#   '7',
#   'missed',
#   'trip',
#   'look',
#   'forward',
#   'trying',
#   'regular',
#   'absinthe',
#   'inspired',
#   'knows',
#   'lop',
#   'ear',
#   'might',
#   'inspired',
#   'paint',
#   'vincent',
#   'wormwood',
#   'induced',
#   'fairylike',
#   'haze'],
#  ['pistachio',
#   'crusted',
#   'goat',
#   'cheese',
#   'ball',
#   'later',
#   'tastiest',
#   'items',
#   'unlimited',
#   'comes',
#   'actual',
#   'sack',
#   'gf',
#   'steak',
#   'frites',
#   'lamb',
#   'burger',
#   'food',
#   'service',
#   'writing',
#   'thinking',
#   'cheese'],
#  ['flights',
#   'charcuterie',
#   'service',
#   'waiter',
#   'apologized',
#   'complimentary',
#   'bathrooms',
#   'strange',
#   'somehow',
#   'difference',
#   'chicken',
#   'crab',
#   'tartine'],
#  ['amélie',
#   'tight',
#   'intimate',
#   'close',
#   'lamb',
#   'burger',
#   'solid',
#   'mind',
#   'blowing',
#   'properly',
#   'fries',
#   'salad',
#   'accompanied',
#   'mixed',
#   'fruit',
#   'whipped',
#   'rate',
#   'decor',
#   'quirky',
#   'fixture',
#   'money',
#   'handwritten',
#   'notes',
#   'hanging',
#   'somehow',
#   'works',
#   'given',
#   'quirky',
#   'design',
#   'elements',
#   'porthole',
#   'windows',
#   'leads',
#   'bathroom',
#   'hallway',
#   'service',
#   'fairly'],
#  ['escargot',
#   'delivered',
#   'sizzling',
#   'yet',
#   'overcooked',
#   'cheese',
#   'charcuterie',
#   'meats',
#   'cheeses',
#   'choose',
#   'comes',
#   'additional',
#   'condiments',
#   'mustard',
#   'honey',
#   'figs',
#   'pickled',
#   'onions',
#   'peppercorn',
#   'kind',
#   'jam',
#   'gratin',
#   'creamy',
#   'service',
#   'staff',
#   'checks',
#   'doesnt',
#   'intrusive',
#   'reccomend',
#   'enjoyable',
#   'chill',
#   'atmosphere'],
#  ['fiancé',
#   'past',
#   'noon',
#   'early',
#   'rainy',
#   'weather',
#   'empty',
#   'already',
#   'eating',
#   'service',
#   'food',
#   'anything',
#   'ordinary',
#   'regular',
#   'cheese',
#   'charcuterie',
#   'cheeses',
#   'start',
#   'fiancé',
#   'onion',
#   'soup',
#   'judges',
#   'based',
#   'onion',
#   'soup',
#   'entrees',
#   'lamb',
#   'burger',
#   'mimosa'],
#  ['later',
#   'without',
#   'problem',
#   'interior',
#   'modern',
#   'trendy',
#   'thought',
#   'completely',
#   'service',
#   'werent',
#   'rushwe',
#   'flights',
#   '16',
#   'three',
#   'almost',
#   'glasses',
#   '8',
#   'flights',
#   'choose',
#   'eric',
#   'benjamin',
#   'liked',
#   'types',
#   'steak',
#   'tartare',
#   'oz',
#   '8',
#   'oz',
#   'fries',
#   'brussel',
#   'sprouts',
#   'share',
#   'steak',
#   'tartare',
#   'prepared',
#   'quail',
#   'egg',
#   'watercress',
#   'salad',
#   'fries',
#   'thin',
#   'mayo',
#   'mayo',
#   'brussel',
#   'sprouts',
#   'mostly',
#   'prefer',
#   'rather',
#   'soft',
#   'ones',
#   'gets',
#   'sad',
#   'baguette',
#   'less',
#   'pricey',
#   'lower'],
#  ['alone',
#   'deserves',
#   'food',
#   'disappoints',
#   'amelie',
#   'service',
#   'hit',
#   'miss',
#   'food',
#   'makes'],
#  ['thankfully',
#   'set',
#   'else',
#   '30',
#   'minute',
#   'seat',
#   'host',
#   'cramped',
#   'positive',
#   'sign',
#   'means',
#   'legit',
#   'flights',
#   'solid',
#   'varieties',
#   'regions',
#   'choose',
#   'themes',
#   'flight',
#   'choices',
#   'pricing',
#   'solid',
#   'winewe',
#   'cheese',
#   'board',
#   'starters',
#   'dried',
#   'fruits',
#   'jams',
#   'honey',
#   'along',
#   'werent',
#   'stingy',
#   'nearly',
#   'basket',
#   'contained',
#   'loafnext',
#   'fries',
#   'surprisingly',
#   'mean',
#   'fries',
#   'fries',
#   'truly',
#   'mind',
#   'blowing',
#   'succulent',
#   'sauces',
#   'finished',
#   'salad',
#   'onion',
#   'soup',
#   'solid',
#   'write',
#   'aboutid',
#   'cheese',
#   'board',
#   'flights',
#   'satisfying',
#   'filling',
#   'experience',
#   'service',
#   'observed',
#   '1',
#   'waiter',
#   '1',
#   'busser',
#   'stuffed',
#   'sardines',
#   'exceptionally',
#   'menus',
#   'food',
#   'check',
#   'staff',
#   'trying',
#   'work',
#   'hard',
#   'floor',
#   'provide',
#   'patrons',
#   'experiencez'],
#  ['1130',
#   'malbec',
#   'tablewe',
#   'placed',
#   'included',
#   'omelettes',
#   'amélie',
#   'lamb',
#   'burger',
#   '16',
#   'lettuce',
#   'wrap',
#   'service',
#   'quick',
#   'food',
#   'within',
#   'minsservice',
#   'speaking',
#   'staff',
#   'especially',
#   'needs',
#   'lessons',
#   'hospitality',
#   'checked',
#   'liking',
#   'paying',
#   'attention',
#   'bother',
#   'spite',
#   'signaling',
#   'serversalso',
#   'called',
#   'check',
#   'charged',
#   'fries',
#   'clearly',
#   'included',
#   'omelettes',
#   'flagged',
#   'error',
#   'speaking',
#   'staff',
#   'included',
#   'gentleman',
#   'corrected',
#   'error',
#   'apologized',
#   'error',
#   'kind',
#   'manfood',
#   'lamb',
#   'burger',
#   'salt',
#   'guess',
#   'salt',
#   'either',
#   'yeah',
#   'looked',
#   'authentic'],
#  ['wow',
#   'wow',
#   'superb',
#   'service',
#   'food',
#   'ambience',
#   'crowd',
#   'swank',
#   'husband',
#   'lucked',
#   'instant',
#   'ahead',
#   'early',
#   'stared',
#   'escargot',
#   'god',
#   'die',
#   'duck',
#   'confit',
#   'wow',
#   'confit',
#   'moist',
#   'duck',
#   'skin',
#   'wow',
#   'wow',
#   'finished',
#   'prosecco',
#   'husband',
#   'whiskey',
#   'whiskey',
#   'prosecco',
#   'kind',
#   'nightdef'],
#  ['absolute',
#   'food',
#   'flight',
#   '12',
#   'weve',
#   'amélie',
#   'welcomed',
#   'helped',
#   'quickly',
#   'extremely',
#   'customer',
#   'service',
#   'notch',
#   'wish',
#   'seriously',
#   'complaints'],
#  ['visiting',
#   'totally',
#   'amelie',
#   'recommended',
#   'impressive',
#   'month',
#   'ago',
#   '11',
#   'guests',
#   'including',
#   '8pm',
#   '10',
#   'prix',
#   'fixe',
#   'includes',
#   'entrée',
#   'house',
#   'beer',
#   'soft',
#   'drinkall',
#   'price',
#   '60',
#   'pre',
#   'tax',
#   'gratuity',
#   'include',
#   'prix',
#   'fixe',
#   'noisy',
#   'expected',
#   'ambiance',
#   'casual',
#   'red',
#   'backlight',
#   'distance',
#   'crowd',
#   'prix',
#   'fixe',
#   'following',
#   'burgundy',
#   'escargots',
#   'gratines',
#   'vegetable',
#   'brunoise',
#   'yummy',
#   'umami',
#   'escargot',
#   'moist',
#   'garlic',
#   'parsley',
#   'butter',
#   'escargots',
#   'tastedcrab',
#   'tartine',
#   'pick',
#   'escargot',
#   'pickled',
#   'jalapeno',
#   'kick',
#   'citrus',
#   'aioli',
#   'creamy',
#   'tried',
#   'pickled',
#   'jalapeno',
#   'escargot',
#   'deliciousseared',
#   'organic',
#   'salmon',
#   'salmon',
#   'moist',
#   'contrast',
#   'skin',
#   'delicata',
#   'squash',
#   'underneath',
#   'acidic',
#   'donevanilla',
#   'bean',
#   'crème',
#   'brulee',
#   'yummy',
#   'fancy',
#   'deconstructed',
#   'yummy',
#   'crème',
#   'brulee',
#   'caramelizationsauvignon',
#   'blanc',
#   'refreshing',
#   'smooth',
#   'itsuch',
#   'gno',
#   'food',
#   'beauty',
#   'essex',
#   'price',
#   'reasonable',
#   'food',
#   'service',
#   'benjamin',
#   'host',
#   'welcoming',
#   'eric',
#   'k',
#   'server',
#   'courteous',
#   'attentivei',
#   'totally',
#   'whether',
#   '40',
#   'girls',
#   'trip'],
#  ['romantic',
#   'anniversary',
#   'glad',
#   'via',
#   'narrow',
#   'cold',
#   'specials',
#   '7pm',
#   'glasses',
#   'wines',
#   '13',
#   'given',
#   'sized',
#   'glasses',
#   'deal',
#   'mix',
#   'match',
#   'kinds',
#   'share',
#   'finish',
#   'judgingthe',
#   'service',
#   'fully',
#   'girls',
#   'anniversary',
#   'dim',
#   'décor',
#   'moderate',
#   'noise',
#   'level',
#   'ended',
#   'picking',
#   'yummy',
#   'escargot',
#   'appetizers',
#   'escargot',
#   'smoke',
#   'salmon',
#   'crostini',
#   'octopus',
#   'crostini',
#   'crab',
#   'tartine',
#   'appetizers',
#   'octopus',
#   'crostini',
#   'knew',
#   'liked',
#   'octopus',
#   'beware',
#   'crostini',
#   'hard',
#   'supposed',
#   'soft',
#   'white',
#   'keep',
#   'hold',
#   'level',
#   'hard',
#   'literally',
#   'used',
#   'fork',
#   'knife',
#   'half',
#   'struggling',
#   'chip',
#   'tooth',
#   'trying',
#   'escargot',
#   'disappointing',
#   'butter',
#   'else',
#   'ill',
#   'admit',
#   'dip',
#   'escargot',
#   'butter',
#   'highlight',
#   'entrée',
#   'duck',
#   'leg',
#   'escargot',
#   'liking',
#   'duck',
#   'leg',
#   'instead'],
#  ['food',
#   'service',
#   'ny',
#   'weekend',
#   'promptly',
#   'bustling',
#   'without',
#   'hitch',
#   'charcuterie',
#   'chicken',
#   'liver',
#   'chicken',
#   'liver',
#   'die',
#   'obsessed',
#   'duck',
#   'duck',
#   'confit',
#   'prepared',
#   'dry',
#   'husband',
#   'steak',
#   'frites',
#   'yummy',
#   'frites',
#   'opted',
#   'chocolate',
#   'mousse',
#   'pairing',
#   'including',
#   'service',
#   'staying',
#   'ny',
#   'trip'],
#  ['immediately',
#   'generous',
#   'pours',
#   'mussels',
#   'steamed',
#   'chardonnay',
#   'kindly',
#   'provide',
#   'dip',
#   'toofor',
#   'smoked',
#   'salmon',
#   'salad',
#   'husband',
#   'duck',
#   'confit',
#   'latter',
#   'insanely',
#   'richdessert',
#   'chocolate',
#   'mousse',
#   'goodservice',
#   'attentivereally',
#   '12',
#   'alas',
#   'plates'],
#  ['play',
#   'classic',
#   'modern',
#   'bathrooms',
#   'service',
#   'rate',
#   'food',
#   'foie',
#   'gras',
#   'hook',
#   'escargot',
#   'duck',
#   'confit',
#   'salty',
#   'brussels',
#   'sprouts',
#   'issue',
#   'level',
#   'noise',
#   'wow'],
#  ['year',
#   'late',
#   'mark',
#   'memorable',
#   'momentalthough',
#   'accommodating',
#   'child',
#   'without',
#   'weekendthe',
#   'listed',
#   'servers',
#   'recommended',
#   'flight',
#   'opted',
#   'white',
#   'option',
#   'recall',
#   'pair',
#   'dishesthe',
#   'service',
#   'refill',
#   'food',
#   'mussels',
#   'dip',
#   'entrees',
#   'duck',
#   'confit',
#   'gratin',
#   'truffle',
#   'oil',
#   'gratini',
#   'forward',
#   'perhaps'],
#  ['serviceable',
#   'bartender',
#   'attentive',
#   'kept',
#   'aperol',
#   'spritzes',
#   'flowing',
#   'tried',
#   'surprisingly',
#   'food',
#   'underwhelming',
#   'generously',
#   'timed'],
#  ['bookthe',
#   'food',
#   'consistently',
#   'outstanding',
#   'disappointsthe',
#   'price',
#   'true',
#   'food',
#   'honestservice',
#   'abovepar',
#   'lacks',
#   'sexy',
#   'ambience',
#   'makes',
#   'everywhere',
#   'elsei',
#   'entirely',
#   'inspiration',
#   'product',
#   'red',
#   'overhead',
#   'tenting',
#   'surpasses',
#   'assumption',
#   'standard',
#   '8th',
#   'streetnyu',
#   'staplesin',
#   'seat',
#   'booth',
#   'whole',
#   'fish',
#   'sancerre100',
#   'ices'],
#  ['lady',
#   'mothers',
#   'including',
#   'clams',
#   'service',
#   'welcoming',
#   'homey',
#   'flights',
#   'delicacy',
#   'remember',
#   'exactly',
#   'write',
#   'remember',
#   'ill'],
#  ['running',
#   'late',
#   'summer',
#   'traffic',
#   'insane',
#   'called',
#   'worries',
#   'understand',
#   'instantly',
#   'food',
#   'service',
#   'flights',
#   'inexpensive',
#   'soooo',
#   'reisling',
#   'remember',
#   'husband',
#   'salvatore',
#   'wines',
#   'thumbs'],
#  ['weekend',
#   'thought',
#   'burgundy',
#   'escargots',
#   'gratines',
#   'tried',
#   'escargot',
#   'red',
#   'reduction',
#   'escargot',
#   'tried',
#   'woman',
#   'paris',
#   'several',
#   'pure',
#   'indulgent',
#   'perfection',
#   'especially',
#   'soak',
#   'upfor',
#   'duck',
#   'leg',
#   'confit',
#   'duck',
#   'completely',
#   'paired',
#   'côtes',
#   'du',
#   'jura',
#   'domaine',
#   'lornet',
#   '46',
#   'bargain',
#   'splurge',
#   'fondant',
#   'du',
#   'chocolat',
#   'simple',
#   'goodthe',
#   'service',
#   'attentive',
#   'anything',
#   'start',
#   'finish',
#   'celebrate',
#   'consistent',
#   'ambience',
#   'authentic',
#   'tightly',
#   'spaced',
#   'expected',
#   'advantage'],
#  ['indifferent',
#   'service',
#   'incredibly',
#   'couldnt',
#   'carry',
#   'conversation',
#   'terrible',
#   'ambiance'],
#  ['lil',
#   'turns',
#   'used',
#   'live',
#   'close',
#   'sf',
#   'polk',
#   'version',
#   'aesthetically',
#   'similar',
#   'remembernot',
#   'huge',
#   'otherwise',
#   'getting',
#   'early',
#   'recommended',
#   'esp',
#   'wo',
#   'reservationsthey',
#   '8',
#   'flights',
#   'flights',
#   'service',
#   'accommodating',
#   'despite',
#   'fact',
#   'lots',
#   'folks',
#   'buzzing',
#   'rush',
#   'particularly'],
#  ['week', 'food', 'service'],
#  ['amelie',
#   'package',
#   'deal',
#   'food',
#   'ambiance',
#   'service',
#   'wouldnt',
#   'mind',
#   'revisiting',
#   'amelie',
#   'summer',
#   'summer',
#   'experiences',
#   'delightful',
#   'pink',
#   'aura',
#   'either',
#   'inviting',
#   'distracting',
#   'depending',
#   'embraced',
#   'welcoming',
#   'visits',
#   'ravioli',
#   'gratin',
#   'mini',
#   'raviola',
#   'pasta',
#   'stuffed',
#   'comte',
#   'cottage',
#   'cheese',
#   'rich',
#   'overwhelming',
#   'sense',
#   'pasta',
#   'balance',
#   'cheese',
#   'warmth',
#   '16',
#   'relatively',
#   'inexpensive',
#   'compared',
#   'pasta',
#   'menus',
#   'serve',
#   'ill',
#   'complain',
#   'appetizers',
#   'making',
#   '630',
#   'safe',
#   'starts',
#   'filling',
#   'quickly',
#   '630',
#   'especially',
#   'weekends',
#   'elements',
#   'enhance',
#   'amelies',
#   'vibrancy',
#   'provide',
#   'checks',
#   'novels',
#   'decorate',
#   'walls',
#   'neon',
#   'pink',
#   'bottles',
#   'girls',
#   'discovered',
#   'planning',
#   'checking',
#   'amelie',
#   'third',
#   'finding',
#   'pay',
#   'eggs',
#   'pancakes',
#   'seems',
#   'near',
#   'impossible',
#   'amelie',
#   'seems',
#   'offer',
#   'variety',
#   'offerings',
#   'lower',
#   'prices'],
#  ['disappointed',
#   'mention',
#   'breakfaststyle',
#   'offering',
#   'imagine',
#   'anything',
#   'solid',
#   'mention',
#   'basket',
#   'essentially',
#   'baguette',
#   'helps',
#   'set',
#   'service',
#   'laid',
#   'yet',
#   'attentive',
#   'ambience'],
#  ['visiting',
#   'son',
#   'recently',
#   'moved',
#   'work',
#   'near',
#   'apartment',
#   'saw',
#   'glad',
#   'didfirst',
#   'service',
#   'spectacular',
#   'eric',
#   'server',
#   'care',
#   'food',
#   'prepared',
#   'breadwe',
#   'escargot',
#   'duck',
#   'snapper',
#   'tempwrapped',
#   'chocolate',
#   'mousse',
#   'excellentfor',
#   'exactly',
#   'experience'],
#  ['serve',
#   'appetizers',
#   'opted',
#   'pistachio',
#   'crusted',
#   'goat',
#   'cheese',
#   'ball',
#   'honey',
#   'caramelized',
#   'onions',
#   'toasts',
#   '700',
#   'goat',
#   'cheese',
#   'spread',
#   'onions',
#   'red',
#   'onions',
#   'contrasted',
#   'tartness',
#   'goat',
#   'cheese',
#   'wellwe',
#   'opted',
#   'split',
#   'mains',
#   'smoked',
#   'salmon',
#   'arugula',
#   'salad',
#   'cherry',
#   'tomatoes',
#   'cucumber',
#   'avocado',
#   'leeks',
#   'tossed',
#   'mustard',
#   'vinaigrette',
#   '1200',
#   'smoked',
#   'salmon',
#   'salad',
#   'veggies',
#   'liked',
#   'mustard',
#   'vinaigrette',
#   'flavorthe',
#   'boyfriend',
#   'amelie',
#   'burger',
#   'brioche',
#   'bun',
#   'tomato',
#   'onion',
#   'lettuce',
#   'fries',
#   'opted',
#   'add',
#   'gruyere',
#   'cheese',
#   'extra',
#   '1',
#   'liked',
#   'burger',
#   'filling',
#   'desired',
#   'veggies',
#   'cheese',
#   'fries',
#   'liked',
#   'thin',
#   'crunchywe',
#   'stay',
#   'stuffed',
#   'burger',
#   'salad',
#   'specials',
#   'food',
#   'service',
#   'iced',
#   'lattes',
#   'stumptown',
#   'block',
#   'waiter',
#   'require',
#   'throw',
#   'finish',
#   'offered',
#   'move',
#   'maison',
#   'jars',
#   'keep',
#   'call',
#   'service'],
#  ['heard',
#   'knew',
#   'notorious',
#   'regardless',
#   'recommended',
#   'catch',
#   'heck',
#   'ill',
#   'waitour',
#   'four',
#   '230',
#   'afternoon',
#   'informed',
#   'hostess',
#   '45',
#   'minute',
#   'understandable',
#   'given',
#   'fact',
#   'completely',
#   'filled',
#   'hella',
#   'early',
#   'trying',
#   'turned',
#   '30',
#   'mind',
#   'option',
#   'wellthe',
#   'layout',
#   'windows',
#   'allow',
#   'natural',
#   'flow',
#   'bright',
#   'entire',
#   'server',
#   'menus',
#   'ample',
#   'look',
#   'themwhen',
#   'apparently',
#   'popular',
#   'chicken',
#   'waffles',
#   '17',
#   'hefty',
#   'pieces',
#   'boneless',
#   'chicken',
#   'breast',
#   'thick',
#   'belgian',
#   'waffle',
#   'honeytabasco',
#   'legit',
#   'icing',
#   'filling',
#   'savory',
#   'sweetthe',
#   'service',
#   'placed',
#   'orders',
#   'server',
#   'prepared',
#   'waiter',
#   'informed',
#   'fact',
#   'wouldve',
#   'done',
#   'beginning',
#   'wouldve',
#   'convenient',
#   'les',
#   'early',
#   'experience'],
#  ['believe',
#   '2019',
#   'businesses',
#   'established',
#   'business',
#   'afford',
#   'cc',
#   'fees',
#   'least',
#   'square',
#   'reader',
#   'ipad',
#   'shame',
#   'shame',
#   'shamei',
#   'dined',
#   'prime',
#   'put',
#   'noon',
#   'text',
#   'ready',
#   '10',
#   'live',
#   'corner',
#   'doors',
#   'counterchicken',
#   'waffles',
#   'ish',
#   'prefer',
#   'chicken',
#   'serve',
#   'boneless',
#   'chicken',
#   'chicken',
#   'honey',
#   'tobasco',
#   'bomb',
#   'signature',
#   'maple',
#   'syrup',
#   'chicken',
#   'waffles',
#   'waffle',
#   'moist',
#   'eggs',
#   'benedict',
#   'tooif',
#   'patience',
#   'clinton',
#   'job',
#   'service',
#   'remember',
#   'bank'],
#  ['45',
#   'fine',
#   'wandered',
#   'called',
#   'inonce',
#   'chicken',
#   'waffles',
#   'brioche',
#   'food',
#   'filling',
#   'service',
#   'attentive',
#   'thing',
#   'heads'],
#  ['bakery',
#   'food',
#   'minus',
#   'service',
#   'refilla',
#   '30',
#   'food',
#   'food',
#   'comes',
#   'style',
#   'five',
#   'service'],
#  ['traditional',
#   'foods',
#   'food',
#   'chicken',
#   'waffles',
#   'chicken',
#   'dry',
#   'waffle',
#   'maple',
#   'butter',
#   'maple',
#   'butter',
#   'bathe',
#   'docked',
#   'juicy',
#   'piece',
#   'chicken',
#   'pancakes',
#   'known',
#   'potato',
#   'pancakes',
#   'beside',
#   'looked',
#   'yummy',
#   'service',
#   'service',
#   'typical',
#   'noon',
#   'seat',
#   'alone',
#   'likely',
#   '3045',
#   'mins',
#   'food',
#   'decently',
#   'quick',
#   '10',
#   'ordering',
#   'atmosphere',
#   'decor',
#   'typical',
#   'diner',
#   'decor',
#   'atmosphere',
#   'loudprice',
#   'price',
#   'quantity',
#   'food',
#   'getting',
#   'complaints',
#   'safe',
#   'choice',
#   'pancakes',
#   'goto'],
#  ['hands',
#   'possibly',
#   'everwhile',
#   '2ish',
#   'hours',
#   'willing',
#   'provides',
#   'vibes',
#   'maintains',
#   'charming',
#   'elements',
#   'updated',
#   'modern',
#   'clean',
#   'except',
#   'please',
#   'please',
#   'update',
#   'accept',
#   'cards',
#   'single',
#   'item',
#   'tried',
#   'comes',
#   'lovesome',
#   'sizes',
#   'huge',
#   'prices',
#   'fair',
#   'aregritsfrench',
#   'toasteggs',
#   'benedict',
#   'salmon',
#   'favoritebuttermilk',
#   'biscuit',
#   'sandwich',
#   'service',
#   'host',
#   'soon',
#   'thougha',
#   'nyc495'],
#  ['service',
#   'pancakes',
#   'downfall',
#   'butter',
#   'connoisseur',
#   'regular',
#   'butter',
#   'syrup',
#   'nevertheless',
#   'bomb'],
#  ['daytime',
#   'check',
#   'clinton',
#   'baking',
#   'company',
#   '10am',
#   'reason',
#   'waitlist',
#   'working',
#   'hostess',
#   'minute',
#   'ended',
#   '10',
#   'interior',
#   'popular',
#   'trendy',
#   'upscale',
#   'diner',
#   'country',
#   'eggs',
#   'ham',
#   'hash',
#   'brown',
#   'biscuit',
#   '15',
#   'substituted',
#   'ham',
#   'bacon',
#   'blueberry',
#   'pancakes',
#   '15',
#   'chicken',
#   'waffles',
#   '17',
#   'country',
#   'eggs',
#   'buttery',
#   'hash',
#   'brown',
#   'seasoned',
#   'lump',
#   'potato',
#   'biscuit',
#   'dry',
#   'sugar',
#   'cured',
#   'bacon',
#   'sinfully',
#   'heavier',
#   'chicken',
#   'drier',
#   'seasoning',
#   'chicken',
#   'advertises',
#   'waffle',
#   'waffle',
#   'soft',
#   'soft',
#   'waffle',
#   'preference',
#   'mind',
#   'blueberry',
#   'pancakes',
#   'pancakes',
#   'life',
#   'fluffy',
#   'moist',
#   'blueberry',
#   'without',
#   'artificial',
#   'agreed',
#   'maple',
#   'butter',
#   'pancakes',
#   'stand',
#   'service',
#   'offday',
#   'seemed',
#   'host',
#   'doubling',
#   'server',
#   'bussers',
#   'refill',
#   'extra',
#   'plates',
#   'popular',
#   'staff',
#   'service',
#   'contributes',
#   'longer',
#   'items',
#   'overpriced',
#   'honestly',
#   'believe',
#   'pancakes',
#   '15'],
#  ['honestly',
#   'thought',
#   'hype',
#   'stupid',
#   'pride',
#   'seat',
#   'seen',
#   'timeout',
#   'market',
#   'near',
#   'bridge',
#   'planted',
#   'seed',
#   'originaltoday',
#   'blew',
#   'expectations',
#   'lesson',
#   'learned',
#   'reveling',
#   'foodim',
#   'kind',
#   'pancake',
#   'guy',
#   'today',
#   'chicken',
#   'waffleseven',
#   'rainy',
#   'wednesday',
#   'solo',
#   '1',
#   'minute',
#   'dropped',
#   '1',
#   'minute',
#   'food',
#   '10',
#   'speed',
#   'service',
#   'tastei',
#   'honestly',
#   'savored',
#   'highlights',
#   'maple',
#   'seemed',
#   'slight',
#   'hint',
#   'coconut',
#   'ill',
#   'near',
#   'future'],
#  ['experienced',
#   'clinton',
#   'baking',
#   'company',
#   'ate',
#   'famous',
#   'blueberry',
#   'pancakes',
#   'expectations',
#   'pancakes',
#   'expectations',
#   'met',
#   '7',
#   'tuesday',
#   'afternoon',
#   'limited',
#   'anticipated',
#   'happen',
#   'shared',
#   'blueberry',
#   'pancakes',
#   'banana',
#   'walnut',
#   'pancakes',
#   'maple',
#   'butter',
#   'put',
#   'service',
#   'asap',
#   'pancakes',
#   'available',
#   'pancakes'],
#  ['clinton',
#   '10',
#   'ardent',
#   'pancake',
#   'lover',
#   'meaning',
#   'clinton',
#   'streets',
#   'famous',
#   'pancakes',
#   '10',
#   '45',
#   'minute',
#   'plan',
#   'intend',
#   'weekend',
#   'peak',
#   'hours',
#   'atm',
#   'across',
#   'cashwe',
#   'given',
#   '50',
#   'bakery',
#   'service',
#   'quick',
#   'soon',
#   'ready',
#   'taken',
#   'food',
#   'within',
#   '15',
#   'orderinghowever',
#   'pancakes',
#   'opinion',
#   'chocolate',
#   'blueberry',
#   'aggressive',
#   'chocolate',
#   'found',
#   'almost',
#   'difficult',
#   'distinguish',
#   'pancakes',
#   'toppings',
#   'impressed',
#   'pancakes',
#   'hoping',
#   'believed',
#   'pancakes',
#   'overpriced',
#   'upon',
#   'trying',
#   'service',
#   'food'],
#  ['godsend',
#   'dramatic',
#   'damn',
#   'yesterday',
#   'surprisingly',
#   'empty',
#   'quickly',
#   'service',
#   'waiter',
#   'quick',
#   'accommodating',
#   'needed',
#   'help',
#   'anything',
#   'food',
#   'part',
#   'instead',
#   'opted',
#   'chicken',
#   'sandwich',
#   'fries',
#   'coleslaw',
#   'dill',
#   'pickle',
#   'enormous',
#   'food',
#   'expecting',
#   'pics',
#   'chicken',
#   'waffles',
#   'changed',
#   'mind',
#   'min',
#   'plain',
#   'pancakes',
#   'omg',
#   'pancakes',
#   'syrup',
# ...
#   'seem',
#   'upsell',
#   'process',
#   'soft',
#   'shell',
#   'crab',
#   'uni',
#   'lucky',
#   'noodles',
#   'popcorn',
#   'chicken',
#   'steak',
#   'earl',
#   'gray',
#   'flan',
#   'additionally',
#   'soju',
#   'soju',
#   'rose',
#   'fashioned',
#   'food',
#   'pick',
#   'liked',
#   'sad',
#   'truffle',
#   'cheese',
#   'gimmicky',
#   'saw',
#   'instagram',
#   'representative',
#   'experience',
#   'whole',
#   'instead',
#   'juxtaposition',
#   'food',
#   'servicebut',
#   'honestly',
#   '45',
#   '100',
#   'suggest',
#   'close',
#   'exactly',
#   'imagine',
#   'hip',
#   'innovative',
#   'experience'],
#  ['wednesday',
#   'found',
#   'shorter',
#   'anticipatedwe',
#   'kimchi',
#   'paella',
#   'popcorn',
#   'chicken',
#   'lucky',
#   'noodle',
#   'pork',
#   'fritathe',
#   'kimchi',
#   'paella',
#   'subtle',
#   'somehow',
#   'somehow',
#   'memorable',
#   'popcorn',
#   'chicken',
#   'crunchiness',
#   'lucky',
#   'noodle',
#   'spice',
#   'without',
#   'overpowering',
#   'getting',
#   'pork',
#   'frita',
#   'burnt',
#   'somehow',
#   'beef',
#   'porkthe',
#   'smaller',
#   'negative',
#   'ambiance',
#   'service',
#   'truffle',
#   'cheese',
#   'adult',
#   'capri',
#   'sun'],
#  ['hands',
#   'tried',
#   'single',
#   'wish',
#   'describe',
#   'yummy',
#   'got',
#   'ta',
#   'mention',
#   'adult',
#   'caprisuns',
#   'omg',
#   'especially',
#   'lychee',
#   'strawberry',
#   'ones',
#   'servers',
#   'energetic',
#   'baffles',
#   'bc',
#   'received',
#   'service',
#   'anywhere',
#   'else',
#   'finish',
#   'entire'],
#  ['food',
#   '9510service',
#   '1010location910ambience',
#   '1010went',
#   'thursday',
#   'kitchen',
#   'thursday',
#   'fusion',
#   'spanish',
#   'share',
#   'food',
#   'ur',
#   'friendstruffle',
#   'cheese',
#   'clams',
#   '1010great',
#   'clam',
#   'work',
#   'truffle',
#   'combo',
#   'torched',
#   'cheese',
#   'smokeysteak',
#   'polenta',
#   '9510the',
#   'highlight',
#   'polenta',
#   'amazingly',
#   'rich',
#   'smooth',
#   'creamy',
#   'steak',
#   'salty',
#   'saltykimchi',
#   'paella',
#   '810the',
#   'kimchi',
#   'combination',
#   'especially',
#   'incorporate',
#   'saffron',
#   'tho',
#   'risotto',
#   'actual',
#   'paella',
#   'lastmatcha',
#   'pudding',
#   '1010its',
#   'chocolate',
#   'chip',
#   'pudding',
#   'vanilla',
#   'part',
#   'matcha',
#   'underneath',
#   'balance',
#   'sweetness',
#   'chocolate',
#   'bitterness',
#   'gooey',
#   'pudding',
#   'cold',
#   'creamall',
#   'service',
#   'matcha',
#   'pudding'],
#  ['generally',
#   'moves',
#   'fairly',
#   'quickly',
#   'food',
#   'service',
#   'lots',
#   'vegetarian',
#   'relatively',
#   'close',
#   'tight',
#   'talk',
#   'fairly',
#   'environment',
#   'vibes',
#   'def',
#   'return'],
#  ['jacks',
#   'freda',
#   'lived',
#   'hype',
#   'expecting',
#   'experience',
#   'badlets',
#   'start',
#   'negative',
#   'forget',
#   'review1',
#   'crowd',
#   'noise',
#   'level',
#   'unpleasant',
#   'couldnt',
#   'hear',
#   'reverberating',
#   'head',
#   'choice',
#   'loud2',
#   'crowd',
#   'patrons',
#   'servers',
#   'brush',
#   'serve',
#   'others',
#   'aside',
#   'experience',
#   'goodthe',
#   'food',
#   'mediterranean',
#   'overhard',
#   'eggs',
#   'pita',
#   'med',
#   'salad',
#   'labneh',
#   'labneh',
#   'mint',
#   'lemonade',
#   'refreshing',
#   'offer',
#   'paper',
#   'straws',
#   'tooservice',
#   'despite',
#   'crowd',
#   'managed',
#   'service',
#   'upbeat',
#   'experience',
#   'server',
#   'postcards',
#   'matchbooks',
#   'wrapping',
#   'experiencereally',
#   'experience',
#   'chance',
#   'prepared',
#   '45',
#   'minute',
#   'especially'],
#  ['food',
#   'service',
#   'sizes',
#   'provide',
#   'borderline',
#   'embarrassing',
#   'picture',
#   'attached',
#   'chicken',
#   'kebab',
#   'entree',
#   '18',
#   'picture',
#   'brings',
#   'pieces',
#   'bitesize',
#   'chicken',
#   'put',
#   'fork',
#   'picture',
#   'provide',
#   'context',
#   'chicken',
#   'pieces',
#   'container',
#   'comes',
#   'blatant',
#   'attempt',
#   'save',
#   'dollars',
#   'overcharging',
#   'customers',
#   'prevents',
#   'giving',
#   'higher',
#   'rating',
#   'chance',
#   'benefit',
#   'doubt',
#   'smaller',
#   'usual',
#   'sadly',
#   'lackluster',
#   'chicken'],
#  ['rainy',
#   'morning',
#   'opinion',
#   'quick',
#   'shakshuka',
#   'house',
#   'cured',
#   'duck',
#   'bacon',
#   'rosewater',
#   'waffle',
#   'shakshuka',
#   'fact',
#   'shock',
#   'difficult',
#   'consume',
#   'gone',
#   'drinking',
#   'souphouse',
#   'cured',
#   'duck',
#   'bacon',
#   'three',
#   'sammich',
#   'ingredientsrosewater',
#   'waffle',
#   'use',
#   'help',
#   'waffle',
#   'soggy',
#   'soft',
#   'honey',
#   'syrup',
#   'goodservice'],
#  ['overhyped',
#   'inconsistencies',
#   'lack',
#   'control',
#   'taken',
#   'hostess',
#   'notepad',
#   'doesnt',
#   'necessarily',
#   'follow',
#   'parties',
#   'friendlier',
#   'believe',
#   'hangrily',
#   '75',
#   'heat',
#   'familiar',
#   'notice',
#   'service',
#   'poor',
#   'cup',
#   'tepid',
#   'piping',
#   'allthe',
#   'food',
#   'inconsistent',
#   'redeeming',
#   'qualities',
#   'cancelled',
#   'rest',
#   'experience',
#   'tried',
#   'poached',
#   'egg',
#   'tomato',
#   'halloumi',
#   'housemade',
#   'poached',
#   'egg',
#   'fully',
#   'solid',
#   'runny',
#   'yolk',
#   'accompanying',
#   'slice',
#   'given',
#   'smaller',
#   'palm',
#   'hand',
#   'whereas',
#   'neighboring',
#   'customer',
#   'eating',
#   'hearty',
#   'middle',
#   'piece',
#   'sensing',
#   'pattern',
#   'herefor',
#   'prices',
#   'lack',
#   'control'],
#  ['90',
#   'minute',
#   'three',
#   'totally',
#   'musttry',
#   'staple',
#   'teeny',
#   'tiny',
#   'might',
#   'call',
#   'homey',
#   'otherwise',
#   'might',
#   'otherwise',
#   'touching',
#   'knees',
#   'hours',
#   'corner',
#   'booth',
#   'service',
#   'sitting',
#   'middle',
#   'musical',
#   'hectic',
#   'rushmatzo',
#   'ball',
#   'soup',
#   'start',
#   'fluffy',
#   'matzo',
#   'ball',
#   'paired',
#   'rich',
#   'chicken',
#   'brothmadame',
#   'freda',
#   'duck',
#   'prosciutto',
#   'cheddar',
#   'bechamel',
#   'gruyere',
#   'sunny',
#   'egg',
#   'pressed',
#   'slices'],
#  ['jacks',
#   'freda',
#   'eatery',
#   'recommended',
#   'foodie',
#   'following',
#   'instagram',
#   'seemed',
#   'following',
#   'gram',
#   'didowners',
#   'freda',
#   'jack',
#   'south',
#   'african',
#   'jewish',
#   'respectively',
#   'drawn',
#   'histories',
#   'create',
#   'works',
#   'bistro',
#   'barely',
#   'perused',
#   'seen',
#   'instagram',
#   'shakshuka',
#   'baked',
#   'eggs',
#   'tomatillo',
#   'shakshuka',
#   'challah',
#   'watermelon',
#   'juice',
#   'challah',
#   'melt',
#   'mouthfood',
#   'aside',
#   'service',
#   'welcoming',
#   'upon',
#   'arrival',
#   'read',
#   'prepared',
#   'empty',
#   'meant',
#   'rain',
#   'raining',
#   'fyi',
#   'therei',
#   'talking',
#   'sitting',
#   'following',
#   'jacks',
#   'freda',
#   'instagram',
#   'social',
#   'media',
#   'hype'],
#  ['tinge',
#   'mediterranean',
#   'serve',
#   'madame',
#   'freda',
#   'duck',
#   'prosciutto',
#   'thought',
#   'heavy',
#   'gruyere',
#   'cheese',
#   'done',
#   'sunny',
#   'egg',
#   'truly',
#   'done',
#   'ill',
#   'getting',
#   'waffle',
#   'anything',
#   'mindblowing',
#   'satisfied',
#   'service',
#   'suggest',
#   'either',
#   'early',
#   'weekday',
#   'weekends',
#   'extremely'],
#  ['11am',
#   'monday',
#   'beat',
#   'crowd',
#   'service',
#   'food',
#   'rose',
#   'waffles',
#   'mediterranean',
#   'waffle',
#   '13',
#   'prices',
#   'food',
#   'opinion',
#   'set',
#   'accommodate',
#   'possible',
#   'close',
#   'problem',
#   'mentioning',
#   'brunchlunch'],
#  ['ago',
#   'honestly',
#   'remember',
#   'madame',
#   'freda',
#   'jacks',
#   'tight',
#   'noise',
#   'level',
#   'hard',
#   'hear',
#   'conversation',
#   'close',
#   'positioned',
#   'food',
#   'genuinely',
#   'service',
#   'speedy',
#   'manner',
#   'duck',
#   'touch',
#   'madame',
#   'freda',
#   'egg',
#   'level',
#   'soft',
#   'sunny',
#   'appreciate',
#   'steak',
#   'juicy',
#   'stop'],
#  ['meaning',
#   'ultimate',
#   'gram',
#   'reason',
#   'food',
#   'looks',
#   'combination',
#   'healthy',
#   'primed',
#   'lots',
#   'likes',
#   'myselfcame',
#   'late',
#   'particularly',
#   'rainy',
#   '45',
#   'minute',
#   'pm',
#   'fair',
#   'fast',
#   'hostess',
#   'checking',
#   'periodically',
#   'parties',
#   'aware',
#   'communal',
#   'jampacked',
#   'young',
#   'millennials',
#   'aesthetically',
#   'onpoint',
#   'noise',
#   'crazyour',
#   'waiter',
#   'surprised',
#   'without',
#   'notepad',
#   'aware',
#   'mixture',
#   'american',
#   'mediterranean',
#   'israel',
#   'italy',
#   'mint',
#   'lemonade',
#   'toasted',
#   'baguette',
#   'jam',
#   'butter',
#   'three',
#   'mediterranean',
#   'scrambled',
#   'eggs',
#   'girlfriends',
#   'poached',
#   'eggs',
#   'tomato',
#   'halloumi',
#   'service',
#   'alright',
#   'tend',
#   'chalk',
#   'staff',
#   'caught',
#   'rush',
#   'found',
#   'lemonade',
#   'tart',
#   'food',
#   'taking',
#   'photos',
#   'spread',
#   'dug',
#   'creamy',
#   'butter',
#   'jam',
#   'eggs',
#   'fluffy',
#   'runny',
#   'normally',
#   'complimented',
#   'avocado',
#   'cucumbertomato',
#   'salad',
#   'pita',
#   'toasted',
#   'delicately',
#   'getting',
#   'bites',
#   'mouth',
#   'part',
#   'labne',
#   'yogurt',
#   'couldnt',
#   'creamy',
#   'couldve',
#   'eaten',
#   'bucket',
#   'respective',
#   'feeling',
#   'stuffed',
#   'food',
#   'coma',
#   'hype',
#   '100k',
#   'instagram',
#   'follows',
#   'soon'],
#  ['soooo',
#   'dinnerwe',
#   'periperi',
#   'chicken',
#   'whole',
#   'fish',
#   'share',
#   'food',
#   'chicken',
#   'juicy',
#   'veggies',
#   'addition',
#   'werent',
#   'pudding',
#   'recommended',
#   'server',
#   'soooo',
#   'ended',
#   'bites',
#   'thoughthe',
#   'service',
#   'server',
#   'recommendations',
#   'complimentary',
#   'freshlyjuiced',
#   'watermelon',
#   'juice',
#   'summer',
#   'nightwould'],
#  ['cramped',
#   'service',
#   'food',
#   'kind',
#   'disappointment',
#   'waffles',
#   'burger',
#   'dry',
#   'shakshuka',
#   'food',
#   'generally',
#   'overpriced',
#   'pick'],
#  ['landed',
#   'red',
#   'eye',
#   'flight',
#   'shaksuka',
#   'literally',
#   'runny',
#   'eggs',
#   'topped',
#   'tomatillo',
#   'salsa',
#   'service',
#   'decently',
#   'priced',
#   'servers',
#   'recognize',
#   'leaving',
#   'help',
#   'move',
#   'without',
#   'making',
#   'mess',
#   'cramped',
#   'expected',
#   'early',
#   'row',
#   'dedicated',
#   '24',
#   'parties',
#   'general'],
#  ['mean',
#   'quick',
#   'live',
#   'block',
#   'happens',
#   'cause',
#   'tourists',
#   'wan',
#   'na',
#   'pop',
#   'hang',
#   'food',
#   'service',
#   'ill',
#   'u'],
#  ['food',
#   'disappoints',
#   'given',
#   'five',
#   'four',
#   'serve',
#   'policy',
#   'addition',
#   '45',
#   'mins',
#   'seatedthat',
#   'food',
#   'service',
#   'makes',
#   'buzzing',
#   'servers',
#   'accommodating',
#   'food'],
#  ['mediterranean',
#   'poached',
#   'eggs',
#   'avocado',
#   'pita',
#   'salad',
#   '12',
#   'reasonably',
#   'priced',
#   'brunchloved',
#   'shakshuka',
#   'reminds',
#   'salsa',
#   'egg',
#   'creamy',
#   'called',
#   'makes',
#   'wonderfulvibe',
#   'service',
#   '2ppl',
#   '11am',
#   'reasonable'],
#  ['cousin',
#   'yorker',
#   'recommended',
#   'almost',
#   'food',
#   'extremely',
#   'several',
#   'share',
#   'service',
#   'server',
#   'single',
#   'thing',
#   'forgot',
#   'food',
#   'hype',
#   'yelpers'],
#  ['honestly',
#   'hyped',
#   'lucky',
#   'longer',
#   '1015',
#   'mins',
#   'heard',
#   '45',
#   'mins',
#   'ridiculousat',
#   'least',
#   'spacious',
#   'stuck',
#   'privacy',
#   'service',
#   'food',
#   'mediocre',
#   'pricey',
#   'werent',
#   'bfast',
#   'kind',
#   'waste',
#   'sooooo',
#   'prettier',
#   'food',
#   'fraction',
#   'price'],
#  ['visiting',
#   'opening',
#   'issue',
#   'getting',
#   'crazy',
#   'atmosphere',
#   'early',
#   'quiet',
#   'service',
#   'food',
#   'refilled',
#   'quicklyi',
#   'rest',
#   'population',
#   'waking',
#   'busier',
#   'waitress',
#   'early',
#   'gon',
#   'na',
#   'experience'],
#  ['appeal',
#   'hype',
#   'morning',
#   'put',
#   'names',
#   'check',
#   '45',
#   'accurategiven',
#   'figured',
#   'food',
#   'service',
#   'decornope',
#   'hard',
#   'picking',
#   'settled',
#   'freda',
#   'duck',
#   'sausage',
#   'normally',
#   'availableit',
#   'literally',
#   'thing',
#   'anyway',
#   'service',
#   'preferred',
#   'outdoors',
#   'gawk'],
#  ['trendy',
#   'buzzing',
#   'foodhad',
#   'sandwich',
#   'egg',
#   'duck',
#   'prosciuttothe',
#   'volume',
#   'tight',
#   'issue',
#   '940am',
#   'spacious',
#   'service'],
#  ['mrs',
#   'checked',
#   'weekday',
#   'late',
#   'afternoon',
#   '345',
#   'pm',
#   'community',
#   'tablemy',
#   'complaint',
#   'limited',
#   'tight',
#   'staff',
#   'brush',
#   'serving',
#   'behind',
#   'annoying',
#   'towards',
#   'endfoodwise',
#   'lafayette',
#   'chicken',
#   'kebab',
#   '16',
#   'chicken',
#   'prego',
#   '14',
#   'chicken',
#   'kebab',
#   'deliciousservice',
#   'entire',
#   'staff',
#   'welcoming'],
#  ['bumbled',
#   'jacks',
#   'freda',
#   '930am',
#   'lucky',
#   'empty',
#   'upon',
#   'sitting',
#   'gentleman',
#   'endless',
#   'supply',
#   'healthy',
#   'morning',
#   'mediterranean',
#   'comes',
#   'eggs',
#   'yogurt',
#   'pita',
#   'chopped',
#   'salad',
#   'normally',
#   'filling',
#   'rosewater',
#   'waffle',
#   'fruit',
#   'rosewater',
#   'syrup',
#   'doesnt',
#   'waffles',
#   'tried',
#   'batter',
#   'batter',
#   'perfecti',
#   'sayings',
#   'sugar',
#   'packets',
#   'dude',
#   'latte',
#   'cookbook',
#   'tote',
#   'bag',
#   'sale',
#   'souvenir',
#   'venue',
#   'extremely',
#   'anyone',
#   'making',
#   'reseveration',
#   'advance',
#   'tourists',
#   'please',
#   'leave',
#   'backpacks',
#   'aisles',
#   'cramped',
#   'prevents',
#   'bags',
#   'hitting',
#   'food',
#   'service',
#   'makes',
#   'explains'],
#  ['mine',
#   'maryland',
#   'cramped',
#   'mean',
#   'expected',
#   'service',
#   'chicken',
#   'kebab',
#   'shakshuka',
#   'share',
#   'gon',
#   'na',
#   'food',
#   'kebabs',
#   'seasoned',
#   'chopped',
#   'salad',
#   'refreshing',
#   'shakshuka',
#   'overwhelming',
#   'eggs',
#   'hands',
#   'visitors',
#   'natives',
#   'plus',
#   'saw',
#   'supported',
#   'local',
#   'kids',
#   'soccer',
#   'team'],
#  ['food',
#   'service',
#   'beet',
#   'dip',
#   'wings',
#   'peri',
#   'peri',
#   'wings',
#   'run',
#   'owners',
#   'workers',
#   'taking',
#   'care',
#   'original'],
#  ['food',
#   'shashuka',
#   'filling',
#   'waffles',
#   'yogurtcream',
#   'topping',
#   'berries',
#   'iced',
#   'americano',
#   '45',
#   'expensive',
#   'considering',
#   'filling',
#   'thing',
#   'craving',
#   'food',
#   'food',
#   'shashuka',
#   'shared',
#   'waffles',
#   'paid',
#   '2325',
#   'total',
#   '50service',
#   'service',
#   '1pm',
#   'weekday',
#   'christmas',
#   'interior',
#   'interior',
#   'aesthetic'],
#  ['service', 'fast', 'stylefood', 'ambiance', 'nicerecommend', 'jacks'],
#  ['popular',
#   'got',
#   'ta',
#   'early',
#   'avoid',
#   'lines',
#   'weekends',
#   'names',
#   'entire',
#   'present',
#   '945',
#   'barely',
#   'missed',
#   'huge',
#   'crowd',
#   'ended',
#   '4560',
#   'mins',
#   'service',
#   'coffees',
#   'empty',
#   'waitress',
#   'accommodating',
#   'join',
#   'late',
#   'mayas',
#   'arugula',
#   'substituted',
#   'kale',
#   'filling',
#   'keep',
#   'towards',
#   'food',
#   'seemed',
#   'wet',
#   'spaghetti',
#   'squash',
#   'appetizing',
#   'towards',
#   'wish',
#   'sauces',
#   'available',
#   'food',
#   'arent',
#   'cheap',
#   'getting',
#   'sparkling',
#   'multiple',
#   'mimosas',
#   'glasses',
#   'juice',
#   'house',
#   'food',
#   'healthy',
#   'leave',
#   'feeling',
#   'gross',
#   'overly'],
#  ['weekday',
#   'lucky',
#   'window',
#   'seat',
#   'sister',
#   'service',
#   'without',
#   'rushed',
#   'food',
#   'nicely',
#   'portioned',
#   'guests',
#   'pleasant',
#   'relaxed',
#   'assume',
#   'related',
#   'weekdayill',
#   'whenever',
#   'etc'],
#  ['jacks',
#   'freda',
#   'hyped',
#   'instagram',
#   'fairly',
#   'fast',
#   'service',
#   'attentive',
#   'throughout',
#   'crab',
#   'cakes',
#   'part',
#   'experience',
#   'led',
#   'eager',
#   'entrees',
#   'ended',
#   'let',
#   'upon',
#   'taking',
#   'madame',
#   'freda',
#   'found',
#   'piece',
#   'paper',
#   'cheese',
#   'staffs',
#   'attention',
#   'apologized',
#   'offered',
#   'turned',
#   'offer',
#   'paper',
#   'plus',
#   'happen',
#   'kitchen',
#   'wouldnt',
#   'huge',
#   'cheese',
#   'imagined',
#   'look',
#   'cheesy',
#   'experience',
#   'prego',
#   'roll',
#   'bigger',
#   'let',
#   'slight',
#   'chewy',
#   'nonetheless',
#   'wish',
#   'roll',
#   'lasted',
#   'longer',
#   'slider',
#   'similar',
#   'madame',
#   'freda',
#   'baguette',
#   'aoverall',
#   'expectations',
#   'hand',
#   'story',
#   'service',
#   'bomb'],
#  ['food',
#   'mind',
#   'blowing',
#   'checking',
#   'style',
#   'service',
#   'terrible',
#   'immediately',
#   '10',
#   'yet',
#   'helped',
#   '15',
#   'min',
#   'called',
#   '\u200d',
#   'patience',
#   'pushing',
#   'limit'],
#  ['five',
#   'question',
#   'three',
#   'blows',
#   'ambience',
#   'casual',
#   'tiny',
#   'food',
#   'service',
#   'shout',
#   'pedro',
#   'server',
#   'continue',
#   'dine',
#   'toofood',
#   'guys',
#   'food',
#   'uuufthhagaikskansjdelicious',
#   'healthy',
#   'plentiful',
#   'nicely',
#   'priced',
#   'whats',
#   'mom',
#   'boyfriend',
#   'awkwardly',
#   'plans',
#   'least',
#   'food',
#   '55',
#   'improvements'],
#  ...]

# %%
import gensim
from gensim import corpora
dictionary = corpora.Dictionary(temp)
dictionary.filter_extremes(no_below=10, no_above=0.5, keep_n=8000)
doc_term_matrix = [dictionary.doc2bow(doc) for doc in temp]

# %%
# Creating the object for LDA model using gensim library
Lda = gensim.models.ldamodel.LdaModel

# Running and Trainign LDA model on the document term matrix.
ldamodel = Lda(doc_term_matrix, num_topics=10, per_word_topics=True, id2word = dictionary, passes=50, random_state=79)

# %%
ldamodel.print_topics(num_topics=10, num_words=10)
# Out:
# [(0,
#   '0.010*"atmosphere" + 0.008*"staff" + 0.007*"attentive" + 0.007*"prices" + 0.006*"quick" + 0.006*"decor" + 0.005*"ambiance" + 0.005*"experience" + 0.004*"work" + 0.004*"close"'),
#  (1,
#   '0.033*"chicken" + 0.027*"cheese" + 0.024*"burger" + 0.023*"fries" + 0.012*"tacos" + 0.011*"sandwich" + 0.011*"bacon" + 0.010*"salad" + 0.007*"chips" + 0.006*"shrimp"'),
#  (2,
#   '0.013*"chocolate" + 0.011*"duck" + 0.006*"experience" + 0.006*"foie" + 0.006*"gras" + 0.005*"butter" + 0.005*"beautifully" + 0.005*"chef" + 0.005*"rich" + 0.004*"without"'),
#  (3,
#   '0.035*"eggs" + 0.016*"egg" + 0.013*"pancakes" + 0.010*"benedict" + 0.010*"avocado" + 0.009*"salmon" + 0.008*"poached" + 0.008*"delivery" + 0.006*"morning" + 0.006*"omelette"'),
#  (4,
#   '0.034*"pork" + 0.033*"rice" + 0.024*"chicken" + 0.024*"soup" + 0.021*"noodles" + 0.019*"beef" + 0.014*"dumplings" + 0.013*"pho" + 0.010*"curry" + 0.010*"noodle"'),
#  (5,
#   '0.015*"lobster" + 0.014*"crab" + 0.013*"price" + 0.009*"shrimp" + 0.009*"oysters" + 0.008*"fish" + 0.007*"roll" + 0.006*"1" + 0.006*"prices" + 0.005*"expensive"'),
#  (6,
#   '0.011*"server" + 0.010*"experience" + 0.010*"waiter" + 0.008*"waitress" + 0.008*"check" + 0.008*"customer" + 0.006*"staff" + 0.005*"manager" + 0.005*"10" + 0.005*"someone"'),
#  (7,
#   '0.033*"ramen" + 0.018*"sushi" + 0.015*"broth" + 0.012*"fish" + 0.012*"tuna" + 0.012*"salmon" + 0.010*"uni" + 0.009*"rice" + 0.007*"sake" + 0.007*"sashimi"'),
#  (8,
#   '0.027*"pasta" + 0.026*"salad" + 0.018*"pizza" + 0.015*"lamb" + 0.011*"cheese" + 0.008*"octopus" + 0.007*"tomato" + 0.007*"oil" + 0.007*"hummus" + 0.007*"chicken"'),
#  (9,
#   '0.037*"steak" + 0.029*"experience" + 0.015*"staff" + 0.013*"attentive" + 0.012*"atmosphere" + 0.009*"ambiance" + 0.008*"server" + 0.007*"not" + 0.007*"can" + 0.007*"waiter"')]

# %%
from gensim.test.utils import datapath
# Save model to disk.

ldamodel.save('ldabest.model')

# %%
morestops = ['light', 'main', 'appetizer', 'city', 'left', 'felt', 'pot', 'chinese', 'hot', 'name', 'sure', 'walked',
            'sit', 'door', 'yelp', 'group', 'options', 'portions', 'find', 'absolutely', 'neighborhood','ice',
            'desserts', 'enjoyed', 'courses', 'busy', 'large', 'friday', '4', 'able', 'packed', 'reservations',
            'saturday', 'reservation', 'full', 'average', 'feel', 'looking', 'gave', 'brought', 'must', 'york',
            'michelin', 'not', 'can', 'tell', 'home', 'awesome', 'different', 'bbq', 'lot', 'size', 'amount', 'plate',
            'long', 'theres', 'open', 'line', 'big', 'crowded', 'seated', 'lovely', 'cozy', 'waiting', 'sat', 'seats',
            'inside', 'cool', 'wall', 'walk', 'front', 'free', 'old', 'sometimes', 'usually', 'yes', 'theyre', 'youll',
            'often', 'isnt', 'things', 'gem', 'bill', 'cash', 'bland', 'room', 'end', 'view', 'evening','waited', 
            '20', '5', 'friendly', 'loud', 'fun', 'mexican', 'coming', 'enjoy', 'greek', 'outdoor', 'warm', 'not',
            'can', 'oh', 'wrong', 'na', 'street', 'cocktail', 'beers', 'glass', 'brooklyn', 'manhattan', 'may', 'bottle',
            'started', 'tender', 'slow']

# %%
anotherstop = ['tea', 'thai', 'ask', 'arrived', 'party', 'cake', 'date', 'selection', 'cute', 'try',
              'bowl', 'probably', 'high', 'however', 'id', 'decent', 'maybe', 'places', 'village', 'east', 'tapas',
              'west', 'sangria', 'de', 'margaritas', 'dan', 'visit', 'last', 'family', 'years', 'everyone', 'thank',
              'hearing','tons','rave','finally','decided','actually','second','puts','bring','youd','impress','list', 
               'personally', 'neighborhood', 'loved', 'fantastic', 'absolutely', 'grilled', 'tasty', 'crispy',
              'portion', 'served', 'day', 'right', 'party', 'next', 'since', 'away', 'arrived', 'ok', 'however'
              'maybe', 'tip', 'star', 'okay', 'short', 'flavors', 'vegan', 'la', 'unique', 'ingredients',
              'interesting', 'cuisine']

# %%
newnewstop = ['give', 'going', 'still', 'ever', 'reviews', 'review', 'cant', 'many', 'restaurants', 'wine', 'dining',
             'top', 'beautiful', 'special', 'tasting', 'birthday', 'incredible', 'fried', 'sunday', 'water', 'friend',
             'drink', 'friends', 'super', 'music', 'cocktails', 'vibe', 'space', 'coffee', 'medium', 'meat', 'rare',
             'grill', 'cut', 'bone', 'roasted', 'fresh', 'brunch', 'breakfast', 'dessert', 'toast', 'two', 'dessert',
             'seafood']

# %%
newstop = ['perfectly', 'meal', 'dishes', 'cream', 'want', 'make', 'youre', 'eat', 'way', 'thats', 'say',
          'need', 'see', 'something', 'dinner', 'every', 'highly', 'wonderful', 'nyc', 'perfect', 'told',
          'drinks', 'wanted', 'went', 'wasnt', 'taste', 'overall', '2', '3', 'around', 'japanese', 'flavor']

# %%
# Creating the object for LDA model using gensim library
Lda = gensim.models.ldamodel.LdaModel

# Running and Trainign LDA model on the document term matrix.
ldamodel2 = Lda(doc_term_matrix, num_topics=12, per_word_topics=True, id2word = dictionary, passes=50, random_state=55)

# %%
ldamodel2.print_topics(num_topics=12, num_words=10)
# Out:
# [(0,
#   '0.012*"server" + 0.011*"waiter" + 0.009*"experience" + 0.009*"waitress" + 0.008*"check" + 0.006*"staff" + 0.006*"customer" + 0.005*"manager" + 0.005*"else" + 0.004*"10"'),
#  (1,
#   '0.037*"fish" + 0.035*"tacos" + 0.029*"oysters" + 0.019*"beer" + 0.017*"shrimp" + 0.017*"chips" + 0.014*"taco" + 0.010*"margarita" + 0.009*"corn" + 0.009*"paella"'),
#  (2,
#   '0.044*"pasta" + 0.023*"salad" + 0.013*"octopus" + 0.013*"cheese" + 0.011*"meatballs" + 0.010*"oil" + 0.009*"calamari" + 0.008*"burrata" + 0.008*"tomato" + 0.008*"olive"'),
#  (3,
#   '0.026*"steak" + 0.019*"experience" + 0.011*"duck" + 0.009*"tuna" + 0.008*"chocolate" + 0.007*"chef" + 0.007*"salmon" + 0.007*"attentive" + 0.007*"rib" + 0.006*"lobster"'),
#  (4,
#   '0.008*"can" + 0.008*"not" + 0.008*"experience" + 0.008*"customer" + 0.008*"oh" + 0.007*"staff" + 0.006*"lol" + 0.006*"owner" + 0.006*"point" + 0.006*"wife"'),
#  (5,
#   '0.057*"pizza" + 0.034*"sandwich" + 0.028*"quick" + 0.021*"fast" + 0.016*"brooklyn" + 0.015*"pancakes" + 0.015*"vietnamese" + 0.014*"sandwiches" + 0.013*"bite" + 0.008*"hash"'),
#  (6,
#   '0.056*"cheese" + 0.055*"chicken" + 0.015*"wings" + 0.009*"guacamole" + 0.009*"fries" + 0.008*"bacon" + 0.007*"n" + 0.007*"waffles" + 0.005*"grits" + 0.005*"goat"'),
#  (7,
#   '0.026*"atmosphere" + 0.019*"staff" + 0.018*"attentive" + 0.014*"decor" + 0.013*"ambiance" + 0.012*"experience" + 0.009*"prices" + 0.008*"cocktail" + 0.008*"priced" + 0.007*"ambience"'),
#  (8,
#   '0.055*"burger" + 0.044*"fries" + 0.032*"eggs" + 0.022*"bacon" + 0.020*"lobster" + 0.019*"salad" + 0.017*"egg" + 0.015*"avocado" + 0.014*"crab" + 0.013*"salmon"'),
#  (9,
#   '0.015*"price" + 0.007*"prices" + 0.007*"sushi" + 0.005*"enough" + 0.004*"although" + 0.004*"expensive" + 0.004*"expect" + 0.004*"experience" + 0.004*"per" + 0.004*"person"'),
#  (10,
#   '0.021*"chicken" + 0.014*"rice" + 0.013*"salad" + 0.009*"lamb" + 0.007*"tender" + 0.006*"flavorful" + 0.005*"green" + 0.005*"garlic" + 0.005*"tasted" + 0.005*"texture"'),
#  (11,
#   '0.041*"pork" + 0.032*"noodles" + 0.032*"soup" + 0.025*"rice" + 0.024*"ramen" + 0.023*"beef" + 0.020*"broth" + 0.018*"dumplings" + 0.016*"pho" + 0.013*"noodle"')]

# %%
newstop = ['perfectly', 'meal', 'dishes', 'cream', 'want', 'make', 'youre', 'eat', 'way', 'thats', 'say',
          'need', 'see', 'something', 'dinner', 'every', 'highly', 'wonderful', 'nyc', 'perfect', 'told',
          'drinks', 'wanted', 'went', 'wasnt', 'taste', 'overall', '2', '3', 'around', 'japanese', 'flavor', 'rib',
          'can', 'not', 'oh', 'lol', 'point', 'wife', 'brooklyn',' vietnamese', 'bite', 'n', 'enough', 'although',
          'expect', 'per', 'person', 'tender', 'flavorful', 'green', 'tasted', 'texture']
